# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing the dataset ##

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %% [markdown]
# ## importing the test data ##

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0

# %% [markdown]
# ## Merging both the dataset ##

# %%
df =  pd.merge(df_train,df_test, on='User_ID',how='left')

# %%
df
# Out:
#           User_ID Product_ID_x Gender_x  Age_x  Occupation_x City_Category_x  \
# 0         1000001    P00069042        F   0-17            10               A
# 1         1000001    P00069042        F   0-17            10               A
# 2         1000001    P00069042        F   0-17            10               A
# 3         1000001    P00069042        F   0-17            10               A
# 4         1000001    P00069042        F   0-17            10               A
# ...           ...          ...      ...    ...           ...             ...
# 50512373  1006039    P00371644        F  46-50             0               B
# 50512374  1006039    P00371644        F  46-50             0               B
# 50512375  1006039    P00371644        F  46-50             0               B
# 50512376  1006039    P00371644        F  46-50             0               B
# 50512377  1006039    P00371644        F  46-50             0               B
#
#          Stay_In_Current_City_Years_x  Marital_Status_x  Product_Category_1_x  \
# 0                                   2                 0                     3
# 1                                   2                 0                     3
# 2                                   2                 0                     3
# 3                                   2                 0                     3
# 4                                   2                 0                     3
# ...                               ...               ...                   ...
# 50512373                           4+                 1                    20
# 50512374                           4+                 1                    20
# 50512375                           4+                 1                    20
# 50512376                           4+                 1                    20
# 50512377                           4+                 1                    20
#
#           Product_Category_2_x  ...  Product_ID_y  Gender_y  Age_y  \
# 0                          NaN  ...     P00259342         F   0-17
# 1                          NaN  ...     P00216342         F   0-17
# 2                          NaN  ...     P00157542         F   0-17
# 3                          NaN  ...     P00212942         F   0-17
# 4                          NaN  ...     P00070942         F   0-17
# ...                        ...  ...           ...       ...    ...
# 50512373                   NaN  ...     P00087342         F  46-50
# 50512374                   NaN  ...     P00071442         F  46-50
# 50512375                   NaN  ...     P00086442         F  46-50
# 50512376                   NaN  ...     P00111542         F  46-50
# 50512377                   NaN  ...     P00316642         F  46-50
#
#          Occupation_y City_Category_y  Stay_In_Current_City_Years_y  \
# 0                  10               A                             2
# 1                  10               A                             2
# 2                  10               A                             2
# 3                  10               A                             2
# 4                  10               A                             2
# ...               ...             ...                           ...
# 50512373            0               B                            4+
# 50512374            0               B                            4+
# 50512375            0               B                            4+
# 50512376            0               B                            4+
# 50512377            0               B                            4+
#
#          Marital_Status_y Product_Category_1_y  Product_Category_2_y  \
# 0                       0                    5                   9.0
# 1                       0                    3                   4.0
# 2                       0                    8                  14.0
# 3                       0                    5                   NaN
# 4                       0                    3                   5.0
# ...                   ...                  ...                   ...
# 50512373                1                    5                  14.0
# 50512374                1                   15                  17.0
# 50512375                1                    8                  13.0
# 50512376                1                    2                  17.0
# 50512377                1                    4                   5.0
#
#           Product_Category_3_y
# 0                          NaN
# 1                          5.0
# 2                          NaN
# 3                          NaN
# 4                         16.0
# ...                        ...
# 50512373                  16.0
# 50512374                   NaN
# 50512375                  15.0
# 50512376                   NaN
# 50512377                   NaN
#
# [50512378 rows x 22 columns]

# %%
df_final = df_train.append(df_test)

# %%
df_final
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN    8370.0
# 1                      6.0                14.0   15200.0
# 2                      NaN                 NaN    1422.0
# 3                     14.0                 NaN    1057.0
# 4                      NaN                 NaN    7969.0
# ...                    ...                 ...       ...
# 233594                 NaN                 NaN       NaN
# 233595                 8.0                 NaN       NaN
# 233596                 5.0                12.0       NaN
# 233597                16.0                 NaN       NaN
# 233598                 5.0                 NaN       NaN
#
# [783667 rows x 12 columns]
