# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date
from sklearn.linear_model import LinearRegression
plt.style.use('classic')
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Reading the dataset ##

# %%
df = pd.read_excel('C:/Users/000K1G744/Desktop/Incident management/IKS_Inc.xlsx', sheet_name='Sheet1')

# %% [markdown]
# ## Removing the cancelled state ##

# %%
dataframe = df[df['state']!= 'Cancelled']

# %% [markdown]
# ## Removing the Columns Which is having 90% or more mising values or columns which have no relevant contribution ##

# %%
dataframe = dataframe.drop(['due_date','additional_assignee_list','order','u_external_user_name','u_qs_actual_start','u_qs_affected_date','hold_reason','u_lan_boh_time_spent','u_billing_type','sn_esign_document','u_sc_escalation_count','u_squad','u_external_user_email','group_list','u_qs_duplicate_of','universal_request','correlation_id','correlation_display','u_response_sla_criteria','u_resolve_sla_criteria','u_billing_count','user_input','time_worked','u_location_of_business_supported','sn_esign_esignature_configuration','u_external_user_location','u_reason_for_cancelling','expected_start','u_resolved_by_group','approval_history','skills','follow_up','u_known_error_problem','end','route_reason','u_qs_resolver_group','rfc','sys_tags','u_integration_transfer_group','u_ntt_status_code','caused_by','parent','u_mio_invoked_date','u_esc_acknowledgement2','u_escalation_l2_timestamp','u_esc_acknowledgement1','u_escalation_l1_timestamp','u_escalation_count','u_escalation_date','u_on_hold_reason','u_ntt_time_spent','u_sla_target','u_qs_processmanagergroup','u_qs_processmanager','problem_id','u_qs_reopened_at','reopened_time','reopened_by','watch_list','closed_by','parent_incident'],axis=1)

# %%
dataframe = dataframe.drop(['comments','description','short_description','close_notes'],axis=1)

# %%
dataframe = dataframe.drop(['u_qs_contact_number'],axis=1)

# %%
dataframe = dataframe.drop(['_id'],axis=1)

# %%
## Checking the missing value percentage ##
percent_missing = dataframe.isnull().sum() * 100 / len(dataframe)
missing_value = pd.DataFrame({'column_name': dataframe.columns,
                                 'percent_missing': percent_missing})

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100000)

# %%
missing_value['percent_missing'].sort_values(ascending=False)
# Out:
# company                       78.242903
# u_qs_opened_by_group          68.535924
# subcategory                   32.542465
# assigned_to                   28.726116
# u_location_details            28.509554
# service_offering              28.194287
# business_service              28.194287
# category                      27.042237
# location                      25.586706
# u_warranty_expired            10.521664
# u_end_of_support              10.520927
# cmdb_ci                       10.478204
# work_end                       8.126961
# work_start                     4.802664
# u_cause                        1.386290
# resolved_by                    0.657788
# closed_at                      0.603279
# create_closed_days             0.603279
# month_year_closed              0.603279
# year_of_closed                 0.603279
# open_closed_seconds            0.603279
# open_closed_age                0.603279
# hour_of_day_closed             0.603279
# day_of_week_closed             0.603279
# day_of_month_closed            0.603279
# month_of_closed                0.603279
# open_closed_days               0.603279
# create_closed_seconds          0.603279
# create_closed_age              0.603279
# close_code                     0.587074
# open_resolved_days             0.576762
# year_of_resolved               0.576762
# month_year_resolved            0.576762
# day_of_month_resolved          0.576762
# day_of_week_resolved           0.576762
# resolved_at                    0.576762
# month_of_resolved              0.576762
# open_resolved_age              0.576762
# create_resolved_days           0.576762
# create_resolved_age            0.576762
# create_resolved_seconds        0.576762
# open_resolved_seconds          0.576762
# calendar_duration              0.563503
# business_stc                   0.563503
# calendar_stc                   0.563503
# business_duration              0.563503
# calendar_duration_mins         0.035357
# business_duration_mins         0.035357
# month_of_created               0.000000
# day_of_week_created            0.000000
# hour_of_day_created            0.000000
# year_of_created                0.000000
# day_of_month_created           0.000000
# create_extracted_days          0.000000
# create_extracted_age           0.000000
# hour_of_day_opened             0.000000
# create_extracted_seconds       0.000000
# open_extracted_age             0.000000
# open_extracted_days            0.000000
# open_extracted_seconds         0.000000
# sys_created_by                 0.000000
# knowledge                      0.000000
# create_lastupdated_age         0.000000
# month_year_created             0.000000
# reassignment_count             0.000000
# day_of_week_opened             0.000000
# number                         0.000000
# _score                         0.000000
# u_qs_times_reassigned          0.000000
# upon_reject                    0.000000
# reassignment_count_range       0.000000
# reopen_count_range             0.000000
# sys_updated_on                 0.000000
# u_qs_major_incident            0.000000
# u_lan_bank_of_hours            0.000000
# day_of_month_opened            0.000000
# u_qs_fcresolve                 0.000000
# state                          0.000000
# create_lastupdated_seconds     0.000000
# hour_of_day_resolved           0.000000
# month_year_opened              0.000000
# year_of_opened                 0.000000
# month_of_opened                0.000000
# create_lastupdated_days        0.000000
# xtracted_on                    0.000000
# open_lastupdated_age           0.000000
# assignment_group               0.000000
# sys_domain_path                0.000000
# caller_id                      0.000000
# opened_at                      0.000000
# u_qs_type                      0.000000
# notify                         0.000000
# sys_domain                     0.000000
# sys_created_on                 0.000000
# opened_by                      0.000000
# sys_updated_by                 0.000000
# sys_class_name                 0.000000
# task_effective_number          0.000000
# child_incidents                0.000000
# u_sla_held                     0.000000
# u_escalation_level_1           0.000000
# made_sla                       0.000000
# u_escalation_level_2           0.000000
# u_sc_escalation                0.000000
# upon_approval                  0.000000
# escalation                     0.000000
# u_escalation                   0.000000
# u_mio_invoked                  0.000000
# u_vip_gold_room_service        0.000000
# u_qs_reported_by               0.000000
# open_lastupdated_days          0.000000
# sys_id                         0.000000
# open_lastupdated_seconds       0.000000
# sla_due                        0.000000
# account_domain                 0.000000
# account_name                   0.000000
# account_prefix                 0.000000
# impact                         0.000000
# active                         0.000000
# reopen_count                   0.000000
# priority                       0.000000
# sys_mod_count                  0.000000
# approval                       0.000000
# u_qs_times_reopened            0.000000
# severity                       0.000000
# activity_due                   0.000000
# u_callback_netcool             0.000000
# _type                          0.000000
# u_preferred_language           0.000000
# urgency                        0.000000
# u_qs_rca_required              0.000000
# incident_state                 0.000000
# contact_type                   0.000000
# _index                         0.000000
# Name: percent_missing, dtype: float64

# %% [markdown]
# ## Missing Value Imputation ##

# %%
dataframe['company'] = dataframe['company'].fillna("Unknown")
dataframe['u_qs_opened_by_group'] = dataframe['u_qs_opened_by_group'].fillna("No Group")
dataframe['subcategory'] = dataframe['subcategory'].fillna("No Category")
dataframe['assigned_to'] = dataframe['assigned_to'].fillna("Non_Assigned")
dataframe['u_location_details'] = dataframe['u_location_details'].fillna("No Location")
dataframe['business_service'] = dataframe['business_service'].fillna("No Business")
dataframe['service_offering'] = dataframe['service_offering'].fillna("No Service")
dataframe['category'] = dataframe['category'].fillna("No Category")
dataframe['category'] = dataframe['category'].fillna("No Category")
dataframe['location'] = dataframe['location'].fillna("location")
dataframe['u_warranty_expired'] = dataframe['u_warranty_expired'].fillna("No Warranty")
dataframe['cmdb_ci'] = dataframe['cmdb_ci'].fillna("Unknown")
dataframe['work_end'] = dataframe['work_end'].fillna("2021-06-27 16:00:19")
dataframe['work_start'] = dataframe['work_start'].fillna("2021-03-01 13:26:05")
dataframe['u_cause'] = dataframe['u_cause'].fillna("No Cause")
dataframe['resolved_by'] = dataframe['resolved_by'].fillna("No Resolved")
dataframe['open_closed_age'] = dataframe['open_closed_age'].fillna("No age")
dataframe['closed_at'] = dataframe['closed_at'].fillna("2021-06-04 17:00:13")
dataframe['create_closed_age'] = dataframe['create_closed_age'].fillna("No Closed")
dataframe['day_of_week_closed'] = dataframe['day_of_week_closed'].fillna("Unknown")
dataframe['month_year_closed'] = dataframe['month_year_closed'].fillna("Jul 2021")
dataframe['close_code'] = dataframe['close_code'].fillna("Unknown")
dataframe['day_of_week_resolved'] = dataframe['day_of_week_resolved'].fillna("Unknown")
dataframe['create_resolved_age'] = dataframe['create_resolved_age'].fillna("Unknown")
dataframe['resolved_at'] = dataframe['resolved_at'].fillna("2021-05-30 04:46:16")
dataframe['month_year_resolved'] = dataframe['month_year_resolved'].fillna("Jul 2021")
dataframe['open_resolved_age'] = dataframe['open_resolved_age'].fillna("Unknown")
dataframe['calendar_duration'] = dataframe['calendar_duration'].fillna("Unknown")
dataframe['business_stc'] = pd.to_numeric(dataframe['business_stc'],errors = 'coerce')
dataframe['calendar_stc'] = pd.to_numeric(dataframe['calendar_stc'],errors = 'coerce')
dataframe['year_of_closed'] = dataframe['year_of_closed'].fillna(dataframe['year_of_closed'].mode()[0])
dataframe['month_of_closed'] = dataframe['month_of_closed'].fillna(dataframe['month_of_closed'].mode()[0])
dataframe['create_closed_days'] = dataframe['create_closed_days'].fillna(dataframe['create_closed_days'].mean())
dataframe['create_closed_days'] = dataframe['create_closed_days'].fillna(dataframe['create_closed_days'].mean())
dataframe['open_closed_days'] = dataframe['open_closed_days'].fillna(dataframe['open_closed_days'].mean())
dataframe['create_closed_seconds'] = dataframe['create_closed_seconds'].fillna(dataframe['create_closed_seconds'].mean())
dataframe['open_closed_seconds'] = dataframe['open_closed_seconds'].fillna(dataframe['open_closed_seconds'].mean())
dataframe['hour_of_day_closed'] = dataframe['hour_of_day_closed'].fillna(dataframe['hour_of_day_closed'].mode()[0])
dataframe['day_of_month_closed'] = dataframe['day_of_month_closed'].fillna(dataframe['day_of_month_closed'].mode()[0])
dataframe['day_of_month_resolved'] = dataframe['day_of_month_resolved'].fillna(dataframe['day_of_month_resolved'].mode()[0])
dataframe['month_of_resolved'] = dataframe['month_of_resolved'].fillna(dataframe['month_of_resolved'].mode()[0])
dataframe['year_of_resolved'] = dataframe['year_of_resolved'].fillna(dataframe['year_of_resolved'].mode()[0])
dataframe['open_resolved_seconds'] = dataframe['open_resolved_seconds'].fillna(dataframe['open_resolved_seconds'].mean())
dataframe['create_resolved_seconds'] = dataframe['create_resolved_seconds'].fillna(dataframe['create_resolved_seconds'].mean())
dataframe['open_resolved_days'] = dataframe['open_resolved_days'].fillna(dataframe['open_resolved_days'].mode()[0])
dataframe['create_resolved_days'] = dataframe['create_resolved_days'].fillna(dataframe['create_resolved_days'].mode()[0])
dataframe['business_duration'] =  dataframe['business_duration'].fillna("Unknown")   
dataframe['business_duration_mins'] = dataframe['business_duration_mins'].fillna(dataframe['business_duration_mins'].mean())
dataframe['calendar_duration_mins'] = dataframe['calendar_duration_mins'].fillna(dataframe['calendar_duration_mins'].mean())
dataframe['calendar_stc'] = dataframe['calendar_stc'].fillna(dataframe['calendar_stc'].mode()[0])
dataframe['business_stc'] = dataframe['business_stc'].fillna(dataframe['business_stc'].mode()[0])
dataframe['u_end_of_support'] = dataframe['u_end_of_support'].fillna("No Support")
dataframe['child_incidents'] = pd.to_numeric(dataframe['child_incidents'],errors='coerce').fillna(0)
dataframe['sys_mod_count'] = pd.to_numeric(dataframe['sys_mod_count'],errors='coerce').fillna(0)

# %% [markdown]
# ## Converting the datetime object to datetime data type ##

# %%
dataframe['opened_at'] = pd.to_datetime(dataframe['opened_at'])
dataframe['resolved_at'] = pd.to_datetime(dataframe['resolved_at'])
dataframe['work_end'] = pd.to_datetime(dataframe['work_end'])
dataframe['work_start']= pd.to_datetime(dataframe['work_start'])
dataframe['closed_at'] = pd.to_datetime(dataframe['closed_at'])

# %% [markdown]
# ## Segregating the datasets into four subsets based on their priority ##

# %%
dataframe_p1 = dataframe[dataframe['priority'] == 'P1 - Critical']
dataframe_p2 = dataframe[dataframe['priority'] == 'P2 - High']
dataframe_p3 = dataframe[dataframe['priority'] == 'P3 - Medium']
dataframe_p4 = dataframe[dataframe['priority'] == 'P4 - Low']

# %% [markdown]
# ## MTTR Calculation ##

# %%
import datetime
ct = datetime.datetime.now()
from datetime import datetime
now = datetime.now()
today = pd.to_datetime("now")

# %%
dataframe_p1['diff_seconds'] = ((dataframe_p1['resolved_at'] - dataframe_p1['opened_at'])/np.timedelta64(1,'h'))
dataframe_p2['diff_seconds'] = ((dataframe_p2['resolved_at'] - dataframe_p2['opened_at'])/np.timedelta64(1,'h'))
dataframe_p3['diff_seconds'] = ((dataframe_p3['resolved_at'] - dataframe_p3['opened_at'])/np.timedelta64(1,'h'))
dataframe_p4['diff_seconds'] = ((dataframe_p4['resolved_at'] - dataframe_p4['opened_at'])/np.timedelta64(1,'h'))
dataframe_p1['diff_seconds_1'] = ((today - dataframe_p1['opened_at']) / np.timedelta64(1,'h'))
dataframe_p2['diff_seconds_1'] = ((today - dataframe_p2['opened_at']) / np.timedelta64(1,'h'))
dataframe_p3['diff_seconds_1'] = ((today - dataframe_p3['opened_at']) / np.timedelta64(1,'h'))
dataframe_p4['diff_seconds_1'] = ((today - dataframe_p4['opened_at']) / np.timedelta64(1,'h'))
# Out:
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/3422141719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p1['diff_seconds'] = ((dataframe_p1['resolved_at'] - dataframe_p1['opened_at'])/np.timedelta64(1,'h'))
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/3422141719.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p2['diff_seconds'] = ((dataframe_p2['resolved_at'] - dataframe_p2['opened_at'])/np.timedelta64(1,'h'))
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/3422141719.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p3['diff_seconds'] = ((dataframe_p3['resolved_at'] - dataframe_p3['opened_at'])/np.timedelta64(1,'h'))
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/3422141719.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p4['diff_seconds'] = ((dataframe_p4['resolved_at'] - dataframe_p4['opened_at'])/np.timedelta64(1,'h'))
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/3422141719.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p1['diff_seconds_1'] = ((today - dataframe_p1['opened_at']) / np.timedelta64(1,'h'))
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/3422141719.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p2['diff_seconds_1'] = ((today - dataframe_p2['opened_at']) / np.timedelta64(1,'h'))
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/3422141719.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p3['diff_seconds_1'] = ((today - dataframe_p3['opened_at']) / np.timedelta64(1,'h'))
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/3422141719.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p4['diff_seconds_1'] = ((today - dataframe_p4['opened_at']) / np.timedelta64(1,'h'))

# %%
def derived_column(dataframe_p1):
    if dataframe_p1['state'] == 'Resolved':
        return dataframe_p1.diff_seconds
    elif dataframe_p1['state'] == 'Closed':
        return dataframe_p1.diff_seconds
    elif dataframe_p1['state'] == 'In Progress':
        return dataframe_p1.diff_seconds_1
    elif dataframe_p1['state'] == 'SLA Hold':
        return dataframe_p1.diff_seconds_1
    else:
        return dataframe_p1.diff_seconds_1

# %%
dataframe_p1['MTTR'] = dataframe_p1.apply(derived_column,axis=1)
dataframe_p2['MTTR'] = dataframe_p2.apply(derived_column,axis=1)
dataframe_p3['MTTR'] = dataframe_p3.apply(derived_column,axis=1)
dataframe_p4['MTTR'] = dataframe_p4.apply(derived_column,axis=1)
# Out:
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/479008129.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p1['MTTR'] = dataframe_p1.apply(derived_column,axis=1)
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/479008129.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p2['MTTR'] = dataframe_p2.apply(derived_column,axis=1)
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/479008129.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p3['MTTR'] = dataframe_p3.apply(derived_column,axis=1)
# C:\Users\000K1G~1\AppData\Local\Temp/ipykernel_18412/479008129.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_p4['MTTR'] = dataframe_p4.apply(derived_column,axis=1)

# %% [markdown]
# ## Deleting Redundant Columns ##

# %%
dataframe_p1 = dataframe_p1.drop(['number','sys_created_by','task_effective_number','sys_updated_by','opened_by','sys_created_on','caller_id','u_qs_reported_by','sys_id','activity_due','xtracted_on','diff_seconds','diff_seconds_1','sys_updated_on','opened_at','resolved_at','work_end','work_start','closed_at'],axis=1)

# %%
cat_columns = list(dataframe_p1.select_dtypes(['object']).columns)

# %%
cat_columns
# Out:
# ['_index',
#  '_type',
#  'upon_reject',
#  'u_end_of_support',
#  'u_qs_opened_by_group',
#  'u_warranty_expired',
#  'state',
#  'cmdb_ci',
#  'impact',
#  'priority',
#  'sys_domain_path',
#  'business_duration',
#  'u_qs_type',
#  'notify',
#  'service_offering',
#  'sys_class_name',
#  'assigned_to',
#  'sla_due',
#  'u_escalation',
#  'escalation',
#  'upon_approval',
#  'u_sc_escalation',
#  'u_location_details',
#  'resolved_by',
#  'sys_domain',
#  'business_service',
#  'subcategory',
#  'close_code',
#  'assignment_group',
#  'calendar_duration',
#  'contact_type',
#  'incident_state',
#  'urgency',
#  'u_preferred_language',
#  'company',
#  'severity',
#  'approval',
#  'u_cause',
#  'location',
#  'category',
#  'account_prefix',
#  'account_name',
#  'account_domain',
#  'open_lastupdated_age',
#  'create_lastupdated_age',
#  'open_extracted_age',
#  'create_extracted_age',
#  'day_of_week_created',
#  'month_year_created',
#  'day_of_week_opened',
#  'month_year_opened',
#  'day_of_week_resolved',
#  'month_year_resolved',
#  'day_of_week_closed',
#  'month_year_closed',
#  'reopen_count_range',
#  'reassignment_count_range',
#  'open_resolved_age',
#  'create_resolved_age',
#  'open_closed_age',
#  'create_closed_age']

# %%
import seaborn as sns

# %%
for col in cat_columns:
    plt.xticks(rotation=90)
    sns.countplot(x=col,data=dataframe_p1)
    plt.show()

# %%
dataframe_p1 = dataframe_p1.drop(['_index','_type','upon_reject','state','priority','sys_domain_path','u_qs_type','notify','sys_class_name','sla_due','u_escalation','escalation','upon_approval','u_sc_escalation','sys_domain','incident_state','severity','approval','account_prefix','account_name','account_domain','open_extracted_age','create_extracted_age'],axis=1)

# %% [markdown]
# ## Splitting the dataframe based on training and testing ##

# %%
X1 = dataframe_p1[[i for i in list(dataframe_p1.columns) if i!='MTTR']]
y1 = dataframe_p1['MTTR']

# %%
## Split into train and test sets ##
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X1, y1, test_size=0.33, random_state=1)

# %%
X1.shape, X_train_1.shape,X_test_1.shape,y_train_1.shape,y_test_1.shape
# Out:
# ((381, 94), (255, 94), (126, 94), (255,), (126,))

# %% [markdown]
# ## One Hot Encoding ##

# %%
pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\000k1g744\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\000k1g744\anaconda3\lib\site-packages (from category_encoders) (0.24.2)
# Requirement already satisfied: pandas>=0.21.1 in c:\users\000k1g744\anaconda3\lib\site-packages (from category_encoders) (1.3.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\000k1g744\anaconda3\lib\site-packages (from category_encoders) (1.7.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\000k1g744\anaconda3\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\000k1g744\anaconda3\lib\site-packages (from category_encoders) (0.12.2)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: numpy>=1.14.0 in c:\users\000k1g744\anaconda3\lib\site-packages (from category_encoders) (1.20.3)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\000K1G744\Anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pytz>=2017.3 in c:\users\000k1g744\anaconda3\lib\site-packages (from pandas>=0.21.1->category_encoders) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\000k1g744\anaconda3\lib\site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: six in c:\users\000k1g744\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\000k1g744\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\000k1g744\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)

# %%
import category_encoders as ce
import pandas as pd

# %%
cat_columns_1 = list(X_train_1.select_dtypes(['object']).columns)

# %%
cat_columns_2 = list(X_test_1.select_dtypes(['object']).columns)

# %%
cat_columns_1
# Out:
# ['u_end_of_support',
#  'u_qs_opened_by_group',
#  'u_warranty_expired',
#  'cmdb_ci',
#  'impact',
#  'business_duration',
#  'service_offering',
#  'assigned_to',
#  'u_location_details',
#  'resolved_by',
#  'business_service',
#  'subcategory',
#  'close_code',
#  'assignment_group',
#  'calendar_duration',
#  'contact_type',
#  'urgency',
#  'u_preferred_language',
#  'company',
#  'u_cause',
#  'location',
#  'category',
#  'open_lastupdated_age',
#  'create_lastupdated_age',
#  'day_of_week_created',
#  'month_year_created',
#  'day_of_week_opened',
#  'month_year_opened',
#  'day_of_week_resolved',
#  'month_year_resolved',
#  'day_of_week_closed',
#  'month_year_closed',
#  'reopen_count_range',
#  'reassignment_count_range',
#  'open_resolved_age',
#  'create_resolved_age',
#  'open_closed_age',
#  'create_closed_age']

# %%
#Create object for one-hot encoding
encoder=ce.OneHotEncoder(cols=['u_end_of_support','u_qs_opened_by_group','u_warranty_expired','cmdb_ci','impact','business_duration','service_offering','assigned_to','u_location_details','resolved_by','business_service','subcategory','close_code','assignment_group','calendar_duration','contact_type','urgency','u_preferred_language','company','u_cause','location','category','open_lastupdated_age','create_lastupdated_age','day_of_week_created','month_year_created','day_of_week_opened','month_year_opened','day_of_week_resolved','month_year_resolved','day_of_week_closed','month_year_closed','reopen_count_range','reassignment_count_range','open_resolved_age','create_resolved_age','open_closed_age','create_closed_age'],handle_unknown='return_nan',return_df=True,use_cat_names=True)

# %%
X_train_1_new = encoder.fit_transform(X_train_1)

# %%
X_train_1_new.shape
# Out:
# (255, 1200)

# %%
X_test_1_new = encoder.transform(X_test_1)

# %%
X_test_1_new.shape
# Out:
# (126, 1200)

# %%
X_train_1_new.columns[X_train_1_new.isna().any()].tolist()
# Out:
# []

# %%
X_test_1_new.columns[X_test_1_new.isna().any()].tolist()
# Out:
# ['u_qs_opened_by_group_No Group',
#  'u_qs_opened_by_group_IBM-SD-India SD L1-Rail',
#  'u_qs_opened_by_group_BT-IBM-APPR-SAP-Basis-Rail',
#  'u_qs_opened_by_group_BT-IBM-SI-Asset Governance-Rail',
#  'u_qs_opened_by_group_IBM-SD-IN',
#  'u_qs_opened_by_group_IBM-SD-Italy Turin SD L1-Rail',
#  'u_qs_opened_by_group_IBM-SD-French-Aero',
#  'u_qs_opened_by_group_IBM-AP-Asset Management',
#  'u_qs_opened_by_group_IBM-SD-India CTS-Rail',
#  'u_qs_opened_by_group_IBM-SD-Italy Naples SD L1-Rail',
#  'u_qs_opened_by_group_IBM-AP-COTS-Maximo-Rail',
#  'cmdb_ci_Unknown',
#  'cmdb_ci_BTIS1000096836',
#  'cmdb_ci_McAfee Complete Data Protection',
#  'cmdb_ci_iPhone',
#  'cmdb_ci_windows',
#  'cmdb_ci_a010065p211',
#  'cmdb_ci_eMail Service',
#  'cmdb_ci_MSAF@IDM0018',
#  'cmdb_ci_Computer Hardware',
#  'cmdb_ci_Finance Monthly Closing',
#  'cmdb_ci_Other Quality d/b',
#  'cmdb_ci_SAP DWA/VCM-Finance PROD',
#  'cmdb_ci_a010357p210',
#  'cmdb_ci_Computer Software',
#  'cmdb_ci_Active Directory Certificate Services',
#  'cmdb_ci_Application / System Access Management',
#  'cmdb_ci_MAXIMO BT EMEA PROD',
#  'cmdb_ci_Enovia',
#  'cmdb_ci_P2178047',
#  'cmdb_ci_Concur Interface',
#  'cmdb_ci_ServiceNow Dev',
#  'cmdb_ci_a010760p100',
#  'cmdb_ci_P2126922',
#  'cmdb_ci_LL210306010',
#  'cmdb_ci_Mobile Pass - (Cloud SAS)',
#  'cmdb_ci_Meetings / Video Conferencing / Webex',
#  'cmdb_ci_Bombardier Aerospace',
#  'cmdb_ci_Email and Calendar',
#  'cmdb_ci_PulseSecure',
#  'cmdb_ci_Epayable PROD',
#  'cmdb_ci_mtlbdirect10',
#  'cmdb_ci_DBP - SAP IMPULS PROD',
#  'cmdb_ci_Team',
#  'cmdb_ci_Phone and Mobile',
#  'cmdb_ci_Baan  - Vaesteras PROD',
#  'cmdb_ci_Printing and Fax Services',
#  'cmdb_ci_iflybombardier.com',
#  'cmdb_ci_A011262P017',
#  'cmdb_ci_Phone and Mobile Offerings',
#  'cmdb_ci_Computer Hardware Offerings',
#  'cmdb_ci_MAXIMO BT APAC PROD',
#  'cmdb_ci_Office Online',
#  'cmdb_ci_BUSPLB02FWD00',
#  'cmdb_ci_ServiceNow PROD',
#  'cmdb_ci_Windows',
#  'cmdb_ci_Planner',
#  'cmdb_ci_BGBDXY01SWA00-0',
#  'cmdb_ci_P2127356',
#  'cmdb_ci_Other',
#  'cmdb_ci_Interflex - Brugges',
#  'cmdb_ci_Computer Software Offerings',
#  'cmdb_ci_0003901990EX2200 RT',
#  'cmdb_ci_iaa0001',
#  'cmdb_ci_SAP - GUI',
#  'cmdb_ci_(Automation Only) Access Authorisation Tool Offerings',
#  'cmdb_ci_supplier.aero.bombardier.com',
#  'cmdb_ci_SAP PSI Global',
#  'cmdb_ci_TUCWPRINT001',
#  'cmdb_ci_BGBMBY01SWA01',
#  'cmdb_ci_MTLCICON701',
#  'cmdb_ci_P2190298',
#  'cmdb_ci_eRAF - Request Authorization Database',
#  'cmdb_ci_Metalag PROD',
#  'cmdb_ci_LOTUS NOTES PROD',
#  'cmdb_ci_Alstom-Password reset',
#  'cmdb_ci_Service Now',
#  'cmdb_ci_Email Offerings',
#  'cmdb_ci_SAP BASIS PROD',
#  'cmdb_ci_Network',
#  'cmdb_ci_Application / System Access Management Offerings',
#  'cmdb_ci_Alstom-PC Refresh',
#  'cmdb_ci_Baan Australia PROD',
#  'cmdb_ci_BTIS1000067892',
#  'cmdb_ci_sFTP PROD',
#  'cmdb_ci_McAfee Endpoint Protection, Advanced Suite',
#  'cmdb_ci_DHDCAM',
#  'cmdb_ci_P2180894',
#  'cmdb_ci_Enterprise',
#  'cmdb_ci_MTLLASMS001',
#  'cmdb_ci_BTIS1000004321',
#  'cmdb_ci_iem0000',
#  'cmdb_ci_Information Technology Management',
#  'cmdb_ci_dorca-023-dr03.bombardier',
#  'cmdb_ci_P2183541',
#  'cmdb_ci_Teams',
#  'cmdb_ci_BTalent',
#  'cmdb_ci_IZM0119',
#  'cmdb_ci_P2175112',
#  'cmdb_ci_a010357p302',
#  'cmdb_ci_ServiceNow Instance - PROD',
#  'cmdb_ci_Mobile Pass - LDAP',
#  'cmdb_ci_Catia 3Dcom DEV',
#  'cmdb_ci_Maximo for Aviation PROD',
#  'cmdb_ci_Internet and Network',
#  'cmdb_ci_BBTSWHBRU002_2',
#  'cmdb_ci_bdefra00lic02',
#  'cmdb_ci_SAP PR2 Interface',
#  'cmdb_ci_ BTIS1000007049',
#  'cmdb_ci_Lotus Notes',
#  'cmdb_ci_MobilePass Cloud Service',
#  'cmdb_ci_Alstom -APP Office 365',
#  'cmdb_ci_sunpa016',
#  'cmdb_ci_FAB6',
#  'cmdb_ci_PASSWORD MANAGER',
#  'cmdb_ci_BTIS1000091084',
#  'cmdb_ci_Sharepoint EU PROD',
#  'cmdb_ci_Kronos',
#  'cmdb_ci_BTIS1000007376',
#  'cmdb_ci_P2126988',
#  'cmdb_ci_PSR - SAP eBuy PROD',
#  'cmdb_ci_Print and Fax Offerings',
#  'cmdb_ci_Rational_SYNERGY_PROD',
#  'cmdb_ci_a011179p300',
#  'cmdb_ci_Others',
#  'cmdb_ci_ZIA - Zscaler  - BT',
#  'cmdb_ci_eRoom_01-CommunityAdministration-QA@MTLSQLERM501',
#  'cmdb_ci_P2155924',
#  'cmdb_ci_P2184372',
#  'cmdb_ci_Makino PROD',
#  'business_duration_3 Minutes',
#  'business_duration_0 Seconds',
#  'business_duration_9 Days 16 Hours',
#  'business_duration_2 Minutes',
#  'business_duration_6 Hours 24 Minutes',
#  'business_duration_39 Days 8 Hours',
#  'business_duration_16 Minutes',
#  'business_duration_6 Days 16 Hours',
#  'business_duration_30 Days 5 Hours 6 Minutes',
#  'business_duration_16 Hours',
#  'business_duration_2 Days 1 Hour 20 Minutes',
#  'business_duration_1 Day',
#  'business_duration_8 Hours',
#  'business_duration_5 Hours 28 Minutes',
#  'business_duration_1 Day 8 Hours',
#  'business_duration_1 Day 16 Hours',
#  'business_duration_12 Hours 35 Minutes',
#  'business_duration_2 Days 8 Hours',
#  'business_duration_4 Minutes',
#  'business_duration_11 Days 16 Hours',
#  'business_duration_9 Minutes',
#  'business_duration_13 Minutes',
#  'business_duration_2 Hours 32 Minutes',
#  'business_duration_38 Days 16 Hours',
#  'business_duration_2 Hours 57 Minutes',
#  'business_duration_8 Minutes',
#  'business_duration_2 Days 7 Hours 44 Minutes',
#  'business_duration_6 Hours 19 Minutes',
#  'business_duration_5 Hours 30 Minutes',
#  'business_duration_14 Days 8 Hours 29 Minutes',
#  'business_duration_6 Hours 40 Minutes',
#  'business_duration_14 Minutes',
#  'business_duration_5 Days 17 Hours 29 Minutes',
#  'business_duration_20 Hours 43 Minutes',
#  'business_duration_37 Minutes',
#  'business_duration_1 Hour 18 Minutes',
#  'business_duration_1 Hour 33 Minutes',
#  'business_duration_5 Hours 35 Minutes',
#  'business_duration_1 Hour 19 Minutes',
#  'business_duration_5 Minutes',
#  'business_duration_3 Hours 40 Minutes',
#  'business_duration_2 Hours 7 Minutes',
#  'business_duration_2 Days 16 Hours',
#  'business_duration_4 Hours 3 Minutes',
#  'business_duration_36 Days 8 Hours',
#  'business_duration_17 Minutes',
#  'business_duration_9 Hours 24 Minutes',
#  'business_duration_2 Hours 26 Minutes',
#  'business_duration_2 Days 7 Hours 43 Minutes',
#  'business_duration_39 Days 8 Hours 16 Minutes',
#  'business_duration_1 Day 18 Hours 28 Minutes',
#  'business_duration_3 Days 6 Hours 15 Minutes',
#  'business_duration_33 Days 8 Hours',
#  'business_duration_4 Days',
#  'business_duration_1 Day 5 Hours 16 Minutes',
#  'business_duration_5 Days 19 Hours 2 Minutes',
#  'business_duration_2 Days 1 Hour 32 Minutes',
#  'business_duration_18 Days 19 Hours 26 Minutes',
#  'business_duration_1 Hour 31 Minutes',
#  'business_duration_1 Day 9 Hours 18 Minutes',
#  'business_duration_4 Days 5 Hours 55 Minutes',
#  'business_duration_1 Day 3 Hours 26 Minutes',
#  'business_duration_79 Days',
#  'business_duration_6 Minutes',
#  'business_duration_21 Hours 5 Minutes',
#  'business_duration_1 Hour 2 Minutes',
#  'business_duration_1 Hour 22 Minutes',
#  'business_duration_48 Days 8 Hours 23 Minutes',
#  'business_duration_2 Days 5 Hours 17 Minutes',
#  'business_duration_3 Hours 7 Minutes',
#  'business_duration_1 Minute',
#  'business_duration_11 Days',
#  'business_duration_3 Days 11 Hours 15 Minutes',
#  'business_duration_56 Minutes',
#  'business_duration_3 Days 8 Hours',
#  'business_duration_2 Hours 5 Minutes',
#  'business_duration_2 Hours 22 Minutes',
#  'business_duration_9 Hours 54 Minutes',
#  'business_duration_14 Hours 30 Minutes',
#  'business_duration_1 Hour 13 Minutes',
#  'business_duration_7 Minutes',
#  'business_duration_1 Hour 48 Minutes',
#  'business_duration_7 Days 11 Hours 7 Minutes',
#  'business_duration_39 Minutes',
#  'business_duration_12 Hours 24 Minutes',
#  'business_duration_27 Minutes',
#  'business_duration_28 Minutes',
#  'business_duration_55 Minutes',
#  'business_duration_21 Minutes',
#  'business_duration_2 Days 15 Hours',
#  'business_duration_7 Hours',
#  'assigned_to_Sébastien St-Denis (IBM-BA)',
#  'assigned_to_Reema SHARMA (Bombardier - Transportation)',
#  'assigned_to_Manikandan Sakthivelu (IBM-BT)',
#  'assigned_to_David Ferrante (Innovaway spa-BA)',
#  'assigned_to_Hitesh Patel (IBM-BA)',
#  'assigned_to_Srinivas SAILA (Bombardier - Transportation)',
#  'assigned_to_Pranita Ralla (IBM-BA)',
#  'assigned_to_Kamo St-Dic (IBM-BA)',
#  'assigned_to_External Tool Assignment (IBM-BA)',
#  'assigned_to_Filipe leite REIS (Bombardier - Transportation)',
#  'assigned_to_Sebastian Wagenbreth (NTT-BT)',
#  'assigned_to_Codruta ALEXANDRU (Bombardier - Transportation)',
#  'assigned_to_Varsha Bose (IBM-BA)',
#  'assigned_to_Tushar Tiwari (IBM-BA)',
#  'assigned_to_Rajesh Reddy Santhakudlur (IBM-BT)',
#  'assigned_to_Mark Thompson (NTT-BA)',
#  'assigned_to_Snigdha Verma (IBM-BA)',
#  'assigned_to_Bankova ATANASKA (Bombardier - Transportation)',
#  'assigned_to_Deepak Rana (IBM-BA)',
#  "assigned_to_Christopher O'Neill (IBM-BA)",
#  'assigned_to_Teodora Paula Ciulu (IBM-BT)',
#  'assigned_to_Naresh Rajoju (IBM-BA)',
#  'assigned_to_Milosz KOWALSKI (Bombardier - Transportation)',
#  'assigned_to_Ilaria Rossi (Innovaway spa-BA)',
#  'assigned_to_Botev PLAMEN (Bombardier - Transportation)',
#  'assigned_to_Grishma RAJ (Bombardier - Transportation)',
#  'assigned_to_Richa Satsangi (IBM-BA)',
#  'assigned_to_Kashyap Mishra (IBM-BA)',
#  'assigned_to_Claude Dekany (IBM-BA)',
#  'assigned_to_Puran Dudhane (IBM-BA)',
#  'assigned_to_Rishi DIWAN (Bombardier - Transportation)',
#  'assigned_to_Krzysztof OGRODNIK (Bombardier - Transportation)',
#  'assigned_to_Joseph McDonough (IBM-BA)',
#  'assigned_to_Damodharan M (IBM-BT)',
#  'assigned_to_Harish Chikkamuniswamappa (IBM-BA)',
#  'assigned_to_Abhishek Reddy Gangireddy (IBM-BT)',
#  'assigned_to_Wing Hong Yau (IBM-BA)',
#  'assigned_to_Sreekala KC (Bombardier - Transportation)',
#  'assigned_to_Ankit JAIN (Bombardier - Transportation)',
#  'assigned_to_Nagaraju Pitla (IBM-BA)',
#  'assigned_to_Sumit Nautiyal (IBM-BA)',
#  'assigned_to_Tushar TIWARI (Bombardier - Transportation)',
#  'assigned_to_Mahesh Gopal (IBM-BA)',
#  'assigned_to_Brian Speas (IBM-BA)',
#  'assigned_to_Ciprian BOGOIU (Bombardier - Transportation)',
#  'assigned_to_Tomasz MARCINISZYN (Bombardier - Transportation)',
#  'assigned_to_Mahanthesh PATIL (Bombardier - Transportation)',
#  'assigned_to_Neetu SINGH (Bombardier - Transportation)',
#  'assigned_to_Shagun Yadav (IBM-BA)',
#  'assigned_to_Debjit Bhowmick (IBM-BA)',
#  'assigned_to_Alexander Crigler (IBM-BA)',
#  'assigned_to_Abhishek Kumar (IBM-BA)',
#  'assigned_to_Armando Chioccarelli (IBM-BA)',
#  'assigned_to_Akash Sharma (TCS-BT)',
#  'assigned_to_Nandan Devadas Jois (IBM-BA)',
#  'assigned_to_Anil Kumar (IBM-BA)',
#  'assigned_to_Yathish K S (IBM-BT)',
#  'assigned_to_Ernest DUDA (Bombardier - Transportation)',
#  'assigned_to_Irina Talpan (IBM-BT)',
#  'assigned_to_Mihai COSTIN (Bombardier - Transportation)',
#  'assigned_to_Vincenzo Pettograsso (Innovaway spa-BA)',
#  'assigned_to_Umberto Vigliano (IBM-BT)',
#  'assigned_to_Priya DODEJA (Bombardier - Transportation)',
#  'assigned_to_Amala Shruti Joseph (IBM-BT)',
#  'assigned_to_Ravi Gaureddy (IBM-BA)',
#  'assigned_to_Pratap M Phani (IBM-BA)',
#  'assigned_to_James Huggins (Bombardier - Aerospace)',
#  'assigned_to_Mahesh Singamsetty (IBM-BT)',
#  'assigned_to_Gurpreet Singh2 (NTT-BT)',
#  'assigned_to_Nithyananda J S (IBM-BT)',
#  'assigned_to_Frank WEILAND (Bombardier - Transportation)',
#  'assigned_to_Melodie Boudreau (Bombardier - Aerospace)',
#  'assigned_to_Non_Assigned',
#  'assigned_to_Przemysław GRZYBOWSKI (Bombardier - Transportation)',
#  'assigned_to_Bhimesh M (IBM-BT)',
#  'assigned_to_Armando CHIOCCARELLI (Bombardier - Transportation)',
#  'assigned_to_Hareesh Yerrajennu (IBM-BA)',
#  'assigned_to_Tomasz Marciniszyn (IBM-BA)',
#  'assigned_to_Lucia Cinzia Massimo (Innovaway spa-BA)',
#  'assigned_to_Rituparna Mitra (IBM-BA)',
#  'assigned_to_Lukasz ANDRASIAK (Bombardier - Transportation)',
#  'assigned_to_Waleed Abou Waleed Abou (IBM-BT)',
#  'assigned_to_Prashanth Gudipati (IBM-BA)',
#  'assigned_to_Praful Raikar (IBM-BA)',
#  'assigned_to_Rupal Raj (IBM-BA)',
#  'assigned_to_Praween POOMIEIAM (Bombardier - Transportation)',
#  'assigned_to_Lalit Raina (Bombardier - Transportation)',
#  'assigned_to_Deepika Choubey (IBM-BA)',
#  'assigned_to_Sangeetha N (IBM-BT)',
#  'assigned_to_Egavinti SHRAVAN KUMAR (Bombardier - Transportation)',
#  'assigned_to_Dharmarajan Sundaresan (IBM-BA)',
#  'assigned_to_Vanshika MADHOK (Bombardier - Transportation)',
#  'assigned_to_Divya Bakshi (IBM-BA)',
#  'assigned_to_Alan Miller (Bombardier - Aerospace)',
#  'assigned_to_Venkata Satya Krishna Prasad Eranki (IBM-BA)',
#  'assigned_to_Heloisa Gobi (IBM-BT)',
#  'assigned_to_Filip TSEDRYK (Bombardier - Transportation)',
#  'assigned_to_Eleonora Gambardella (Innovaway spa-BA)',
#  'assigned_to_Mansi Srivastav (Bombardier - Transportation)',
#  'assigned_to_Isaac ZONUNMAWIA (Bombardier - Transportation)',
#  'assigned_to_Ajit ANTO (Bombardier - Transportation)',
#  'assigned_to_Mounica Yallapragada (IBM-BA)',
#  'assigned_to_Arun Prasad (IBM-BA)',
#  'assigned_to_Padmashree Patil (IBM-BA)',
#  'assigned_to_Anju PRABHAKARAN (Bombardier - Transportation)',
#  'assigned_to_Alexandra BALBAE (Bombardier - Transportation)',
#  'assigned_to_Dipankar SOME (Bombardier - Transportation)',
#  'assigned_to_Syed Ziauddin (IBM-BA)',
#  'assigned_to_Mohammed Basha (IBM-BA)',
#  'assigned_to_Ritu Raj (Bombardier - Transportation)',
#  'assigned_to_Indira Sahai (IBM-BA)',
#  'assigned_to_Giuseppe DI MATTEO (Bombardier - Transportation)',
#  'assigned_to_Pani PDP (Bombardier - Transportation)',
#  'assigned_to_Milosz Kowalski (IBM-BA)',
#  'assigned_to_Avinash Kumar Thakur (IBM-BA)',
#  'assigned_to_Ilaria Pareti (Innovaway spa-BA)',
#  'assigned_to_Filip MALISZAK (Bombardier - Transportation)',
#  'assigned_to_Haridoss Sithambaram (IBM-BA)',
#  'assigned_to_Krishna Petkar (IBM-BA)',
#  'assigned_to_Jürgen TEMPEL (Bombardier - Transportation)',
#  'assigned_to_Vikas Mehta (Bombardier - Aerospace)',
#  'assigned_to_Muntaz BEGUM (Bombardier - Transportation)',
#  'assigned_to_Arunima SRIVASTAVA (Bombardier - Transportation)',
#  'assigned_to_Maratilov DRAGOMIR (Bombardier - Transportation)',
#  'assigned_to_Giulia Rinaldi (IBM-BT)',
#  'assigned_to_Gurdeep BANVAIT (Bombardier - Transportation)',
#  'u_location_details_9th floor CA',
#  'u_location_details_Derby',
#  'u_location_details_182 - Siegen',
#  'u_location_details_-',
#  'u_location_details_506 - Dorval Administrative Centre (CA)',
#  'u_location_details_CA Dorval',
#  'u_location_details_CA, 8th floor',
#  'u_location_details_remote',
#  'u_location_details_Hortolândia/SP',
#  'u_location_details_5th floor',
#  'u_location_details_241 - Cebu',
#  'u_location_details_551 - Casablanca Aeropole',
#  'u_location_details_Home Office',
#  'u_location_details_BT',
#  'u_location_details_Bay 9, 2nd floor',
#  'u_location_details_514 - Toronto De Havilland Inc.',
#  'u_location_details_154 - Zurich Oerlikon Toro 1',
#  'u_location_details_Old oak common depot NW10 6DW LONDON',
#  'u_location_details_Montreal',
#  'u_location_details_9th floor',
#  'u_location_details_Paris',
#  'u_location_details_toronto ',
#  'u_location_details_Toronto',
#  'u_location_details_Bangalore',
#  'u_location_details_WFH',
#  'u_location_details_187 - Hennigsdorf',
#  'u_location_details_Working from home',
#  'u_location_details_Hennigsdorf',
#  'u_location_details_from home',
#  'u_location_details_4th floor',
#  'u_location_details_1',
#  'u_location_details_Brasov',
#  'u_location_details_mtl',
#  'u_location_details_M43 R120',
#  'u_location_details_250 - Kuala Lumpur',
#  'u_location_details_6G',
#  'u_location_details_Cebu Philippines',
#  'u_location_details_CA',
#  'u_location_details_8th Floor',
#  'u_location_details_520 - Wichita Learjet',
#  'u_location_details_cairo',
#  'u_location_details_N329-196-3e',
#  'u_location_details_Admin Office',
#  'u_location_details_working from home',
#  'u_location_details_508 - Mirabel Manufacturing',
#  'u_location_details_Plattsburgh',
#  'u_location_details_9TH FLOOR CA',
#  'u_location_details_Work From Home',
#  'u_location_details_6th floor',
#  'u_location_details_1-1079, cube 56',
#  'u_location_details_29e étage',
#  'u_location_details_4B',
#  'u_location_details_426 - Berlin New HQ',
#  'u_location_details_Dandenong',
#  'u_location_details_CA, 2nd floor, J9 23 02',
#  'u_location_details_Building 6G, 2nd floor',
#  'u_location_details_Tucson Facility',
#  'u_location_details_121 - Welby Asfordby',
#  'u_location_details_Bombardier Aerospace',
#  'u_location_details_Office.',
#  'u_location_details_Exec Offices - top floor K Shop Main office block',
#  'u_location_details_Vienna',
#  'u_location_details_516 - Dorval Completion Centre',
#  'u_location_details_Zurich',
#  'u_location_details_Currently WFH',
#  'u_location_details_200 Cote-Vertu Ouest, 3rd floor, Customer Response Center',
#  'u_location_details_521 - Fort Lauderdale',
#  'u_location_details_CA - 9th Floor',
#  'u_location_details_Katrin Luger',
#  'u_location_details_Gurgaon',
#  'u_location_details_India',
#  'u_location_details_Office',
#  'u_location_details_L442',
#  'u_location_details_CA 7th floor E3-57-07',
#  'u_location_details_presidents office',
#  'u_location_details_Bangkok sites',
#  'u_location_details_3rd Floor',
#  'u_location_details_Kolkata, India',
#  'u_location_details_BA',
#  'u_location_details_106 Gold Room ',
#  'u_location_details_bt',
#  'u_location_details_Berlin, HQ',
#  'u_location_details_6G-2604',
#  'u_location_details_Dorval - CA',
#  'u_location_details_236 - Bangkok Klongtoey',
#  'u_location_details_147 - Derby Litchurch Lane',
#  'u_location_details_7th floor - C side office F2-72-07',
#  'u_location_details_3B-022',
#  'u_location_details_INDIA ',
#  'u_location_details_94 - St-Bruno',
#  'u_location_details_Am Rathenaupark 1, @home',
#  'u_location_details_Dallas sales',
#  'u_location_details_Remote',
#  'u_location_details_Gurugram',
#  'u_location_details_crespin',
#  'u_location_details_Working From home',
#  'u_location_details_Service Desk Italy Turin -  Quality Team',
#  'u_location_details_home office; Berlin HQ - 5th floor',
#  'u_location_details_dorval',
#  'u_location_details_189 - Hyderabad Engineering Center',
#  'u_location_details_559 - Montreal Head Office',
#  'u_location_details_Berlin ',
#  'u_location_details_Client Section - Near Showroom',
#  'u_location_details_Garches',
#  'u_location_details_199 - Gurgaon (RCS & IS Hub)',
#  'u_location_details_Eichhornstrasse 3, (4th and 5th floor)',
#  'u_location_details_Mirabel',
#  'u_location_details_banglore',
#  'u_location_details_OPTO : 1st Floor',
#  'u_location_details_Uk/ United Kingdome',
#  'u_location_details_DERBY',
#  'u_location_details_28e étage',
#  'u_location_details_92 - Thunder Bay',
#  'u_location_details_Next to Showroom - Client Section',
#  'u_location_details_29',
#  'u_location_details_3 ieme étage Bureau N329-204-3E',
#  'u_location_details_9TH FLOOR',
#  'u_location_details_E6-58-04',
#  'u_location_details_Canada',
#  'u_location_details_Mannheim',
#  'u_location_details_426',
#  'u_location_details_185',
#  'u_location_details_Queens island',
#  'u_location_details_Client Side - 4th Floor',
#  'u_location_details_Bruges, Belgium',
#  'u_location_details_521_Gold_Room_106 - Completion Center - Room 106 - Conference',
#  'u_location_details_Derby, UK',
#  'u_location_details_brasov',
#  'u_location_details_Frankfurt Site',
#  'u_location_details_Bautzen',
#  'u_location_details_Organisation Materielle',
#  'u_location_details_510 - Saint-Laurent BAN 2',
#  'resolved_by_Sébastien St-Denis (IBM-BA)',
#  'resolved_by_Reema SHARMA (Bombardier - Transportation)',
#  'resolved_by_Manikandan Sakthivelu (IBM-BT)',
#  'resolved_by_David Ferrante (Innovaway spa-BA)',
#  'resolved_by_Hitesh Patel (IBM-BA)',
#  'resolved_by_SivaleelaKumari Katta (IBM-BT)',
#  'resolved_by_Pranita Ralla (IBM-BA)',
#  'resolved_by_Kamo St-Dic (IBM-BA)',
#  'resolved_by_Bhavani Elangovan (IBM-BA)',
#  'resolved_by_Filipe leite REIS (Bombardier - Transportation)',
#  'resolved_by_Sebastian Wagenbreth (NTT-BT)',
#  'resolved_by_Mayur PALHERKAR (Bombardier - Transportation)',
#  'resolved_by_Varsha Bose (IBM-BA)',
#  'resolved_by_Anusha SUNKARA (Bombardier - Transportation)',
#  'resolved_by_Nithyananda J S (IBM-BT)',
#  'resolved_by_Mark Thompson (NTT-BA)',
#  'resolved_by_Snigdha Verma (IBM-BA)',
#  'resolved_by_Bankova ATANASKA (Bombardier - Transportation)',
#  'resolved_by_Deepak Rana (IBM-BA)',
#  "resolved_by_Christopher O'Neill (IBM-BA)",
#  'resolved_by_Teodora Paula Ciulu (IBM-BT)',
#  'resolved_by_Naresh Rajoju (IBM-BA)',
#  'resolved_by_Srinivas SAILA (Bombardier - Transportation)',
#  'resolved_by_Milosz KOWALSKI (Bombardier - Transportation)',
#  'resolved_by_Ilaria Rossi (Innovaway spa-BA)',
#  'resolved_by_Botev PLAMEN (Bombardier - Transportation)',
#  'resolved_by_Grishma RAJ (Bombardier - Transportation)',
#  'resolved_by_Richa Satsangi (IBM-BA)',
#  'resolved_by_Eleonora Gambardella (Innovaway spa-BA)',
#  'resolved_by_Claude Dekany (IBM-BA)',
#  'resolved_by_Puran Dudhane (IBM-BA)',
#  'resolved_by_Rajesh Reddy Santhakudlur (IBM-BT)',
#  'resolved_by_Rishi DIWAN (Bombardier - Transportation)',
#  'resolved_by_Krzysztof OGRODNIK (Bombardier - Transportation)',
#  'resolved_by_Joseph McDonough (IBM-BA)',
#  'resolved_by_Shilpashree B S (Bombardier - Transportation)',
#  'resolved_by_Harish Chikkamuniswamappa (IBM-BA)',
#  'resolved_by_Abhishek Reddy Gangireddy (IBM-BT)',
#  'resolved_by_Wing Hong Yau (IBM-BA)',
#  'resolved_by_Nikhil TALWAR (Bombardier - Transportation)',
#  'resolved_by_Anshika Dixit1 (TCS-BT)',
#  'resolved_by_Nagaraju Pitla (IBM-BA)',
#  'resolved_by_Sumit Nautiyal (IBM-BA)',
#  'resolved_by_Ninad KSHIRSAGAR (Bombardier - Transportation)',
#  'resolved_by_Brian Speas (IBM-BA)',
#  'resolved_by_Ciprian BOGOIU (Bombardier - Transportation)',
#  'resolved_by_Tomasz MARCINISZYN (Bombardier - Transportation)',
#  'resolved_by_Mahanthesh PATIL (Bombardier - Transportation)',
#  'resolved_by_Neetu SINGH (Bombardier - Transportation)',
#  'resolved_by_Shagun Yadav (IBM-BA)',
#  'resolved_by_Debjit Bhowmick (IBM-BA)',
#  'resolved_by_Alexander Crigler (IBM-BA)',
#  'resolved_by_Abhishek Kumar (IBM-BA)',
#  'resolved_by_Armando Chioccarelli (IBM-BA)',
#  'resolved_by_Geetika Saxena (TCS-BT)',
#  'resolved_by_Nandan Devadas Jois (IBM-BA)',
#  'resolved_by_Anil Kumar (IBM-BA)',
#  'resolved_by_Sunil Kumar Thulasiramkrishnamurthy (IBM-BT)',
#  'resolved_by_Ernest DUDA (Bombardier - Transportation)',
#  'resolved_by_Irina Talpan (IBM-BT)',
#  'resolved_by_Mihai COSTIN (Bombardier - Transportation)',
#  'resolved_by_Luisa Ratti (Innovaway spa-BA)',
#  'resolved_by_Umberto Vigliano (IBM-BT)',
#  'resolved_by_Priya DODEJA (Bombardier - Transportation)',
#  'resolved_by_Amala Shruti Joseph (IBM-BT)',
#  'resolved_by_Ravi Gaureddy (IBM-BA)',
#  'resolved_by_Kashyap Mishra (IBM-BA)',
#  'resolved_by_Pratap M Phani (IBM-BA)',
#  'resolved_by_James Huggins (Bombardier - Aerospace)',
#  'resolved_by_Mahesh Singamsetty (IBM-BT)',
#  'resolved_by_Mohit Sharma (NTT-BT)',
#  'resolved_by_Frank WEILAND (Bombardier - Transportation)',
#  'resolved_by_Melodie Boudreau (Bombardier - Aerospace)',
#  'resolved_by_Automated ID for AT&T IPcenter - Aero (AT&T-BA)',
#  'resolved_by_Przemysław GRZYBOWSKI (Bombardier - Transportation)',
#  'resolved_by_Bhimesh M (IBM-BT)',
#  'resolved_by_Armando CHIOCCARELLI (Bombardier - Transportation)',
#  'resolved_by_Hareesh Yerrajennu (IBM-BA)',
#  'resolved_by_Tomasz Marciniszyn (IBM-BA)',
#  'resolved_by_Lucia Cinzia Massimo (Innovaway spa-BA)',
#  'resolved_by_Rituparna Mitra (IBM-BA)',
#  'resolved_by_Lukasz ANDRASIAK (Bombardier - Transportation)',
#  'resolved_by_Yara MOHAMED (Bombardier - Transportation)',
#  'resolved_by_Ahmed Abulibdeh (IBM-BA)',
#  'resolved_by_Janardhan Kommineni (IBM-BA)',
#  'resolved_by_Praful Raikar (IBM-BA)',
#  'resolved_by_Rupal Raj (IBM-BA)',
#  'resolved_by_Praween POOMIEIAM (Bombardier - Transportation)',
#  'resolved_by_Lalit Raina (Bombardier - Transportation)',
#  'resolved_by_Deepika Choubey (IBM-BA)',
#  'resolved_by_Egavinti SHRAVAN KUMAR (Bombardier - Transportation)',
#  'resolved_by_Dharmarajan Sundaresan (IBM-BA)',
#  'resolved_by_Vanshika MADHOK (Bombardier - Transportation)',
#  'resolved_by_Divya Bakshi (IBM-BA)',
#  'resolved_by_Alan Miller (Bombardier - Aerospace)',
#  'resolved_by_Yasir H Khan (IBM-BT)',
#  'resolved_by_Sanket SHANKAR (Bombardier - Transportation)',
#  'resolved_by_Tejaswini Lakshminarayana (IBM-BA)',
#  'resolved_by_Heloisa Gobi (IBM-BT)',
#  'resolved_by_Andrew FLETT (Bombardier - Transportation)',
#  'resolved_by_Sumana R (Bombardier - Transportation)',
#  'resolved_by_Mansi Srivastav (Bombardier - Transportation)',
#  'resolved_by_Isaac ZONUNMAWIA (Bombardier - Transportation)',
#  'resolved_by_Ajit ANTO (Bombardier - Transportation)',
#  'resolved_by_Mounica Yallapragada (IBM-BA)',
#  'resolved_by_Ramakrishna Chirumalla (IBM-BA)',
#  'resolved_by_Prashanth Gudipati (IBM-BA)',
#  'resolved_by_Padmashree Patil (IBM-BA)',
#  'resolved_by_Automated ID for Dimension Data (IBM-BA)',
#  'resolved_by_Anju PRABHAKARAN (Bombardier - Transportation)',
#  'resolved_by_Alexandra BALBAE (Bombardier - Transportation)',
#  'resolved_by_Dipankar SOME (Bombardier - Transportation)',
#  'resolved_by_Syed Ziauddin (IBM-BA)',
#  'resolved_by_Mohammed Basha (IBM-BA)',
#  'resolved_by_Ritu Raj (Bombardier - Transportation)',
#  'resolved_by_Indira Sahai (IBM-BA)',
#  'resolved_by_Giuseppe DI MATTEO (Bombardier - Transportation)',
#  'resolved_by_Prince KUMAR (Bombardier - Transportation)',
#  'resolved_by_Milosz Kowalski (IBM-BA)',
#  'resolved_by_Avinash Kumar Thakur (IBM-BA)',
#  'resolved_by_Ilaria Pareti (Innovaway spa-BA)',
#  'resolved_by_Filip MALISZAK (Bombardier - Transportation)',
#  'resolved_by_Haridoss Sithambaram (IBM-BA)',
#  'resolved_by_Codruta ALEXANDRU (Bombardier - Transportation)',
#  'resolved_by_Krishna Petkar (IBM-BA)',
#  'resolved_by_Jürgen TEMPEL (Bombardier - Transportation)',
#  'resolved_by_Muntaz BEGUM (Bombardier - Transportation)',
#  'resolved_by_Arunima SRIVASTAVA (Bombardier - Transportation)',
#  'resolved_by_Maratilov DRAGOMIR (Bombardier - Transportation)',
#  'resolved_by_Giulia Rinaldi (IBM-BT)',
#  'resolved_by_Gurdeep BANVAIT (Bombardier - Transportation)',
#  'subcategory_Laptop - Issue / Error',
#  'subcategory_Email - Issue / Error',
#  'subcategory_Certificates/Encryption',
#  'subcategory_General Application Support Issue / Error',
#  'subcategory_Login / Password - Issue / Error',
#  'subcategory_No Category',
#  'subcategory_General Software - Issue / Error',
#  'subcategory_Shared Folder / Network Drive - Issue / Error',
#  'subcategory_Wireless',
#  'subcategory_Application - Issue / Error',
#  'subcategory_Application - All Other Issues',
#  'subcategory_Meeting Room - Issue / Error',
#  'subcategory_Active Directory - Password Reset',
#  'subcategory_Login Issue  - User Access',
#  'subcategory_Data Issue - Data Issue / Error',
#  'subcategory_Workstation - Other Issue / Error',
#  'subcategory_Desk / Conference Phone - Issue / Error',
#  'subcategory_Availability - Application Not Available',
#  'subcategory_Sharepoint - Issue / Error',
#  'subcategory_iPhone - Issue / Error',
#  'subcategory_VPN / 2FA - Issue / Error',
#  'subcategory_Video Conferencing - Issue / Error',
#  'subcategory_Network Security - Issue / Error',
#  'subcategory_General Printer - Issue / Error',
#  'subcategory_Monitor - Issue / Error',
#  'subcategory_Web Browser / Internet - Issue / Error',
#  'subcategory_Network Data - Issue / Error',
#  'subcategory_Docking Station - Issue / Error',
#  'subcategory_Interface Issues - Fix Interface',
#  'subcategory_Network Printer - Error',
#  'subcategory_Laptop - Performance',
#  'subcategory_Desktop - Performance',
#  'subcategory_Mobile e-Mail Client Assistance',
#  'subcategory_Network Other - Issue / Error',
#  'subcategory_Other General - Issue / Error',
#  'subcategory_Performance - Application Slow Down',
#  'subcategory_Availability - Application Outage',
#  'subcategory_Desktop - Issue / Error',
#  'subcategory_Application Installation - Issue / Error',
#  'subcategory_Lan Cable - Issue / Error',
#  'subcategory_Browser Chrome - Configuration Issue / Error',
#  'subcategory_Active Directory - Account Locked',
#  'subcategory_Voice - Issue / Error',
#  'subcategory_Netcool Event',
#  'subcategory_Intercall - Issue / Error',
#  'subcategory_Browser Internet Explorer - Configuration Issue / Error',
#  'subcategory_Job Failures - Web Transaction Issues',
#  'assignment_group_IBM-DS-Platinum Support-CA-AERO',
#  'assignment_group_IBM-SD-India SD Self Service-Rail',
#  'assignment_group_IBM-AS-Malware Endpoints-Rail',
#  'assignment_group_IBM-SD-French-Aero',
#  'assignment_group_IBM-DS-Gold-Silver Support-CA-AERO',
#  'assignment_group_IBM-AP-Unix-Rail',
#  'assignment_group_IBM-SI-Asset Analyst',
#  'assignment_group_VEN-DD-Dimension Data - Integration',
#  'assignment_group_BT-IBM-APPR-SAP-Mastersaf_DW_NotaFiscal-Rail',
#  'assignment_group_VEN-HEM-Staffed-Berlin-DE-RAIL',
#  'assignment_group_IBM-AP-COTS-Finance  Others Apps-Rail',
#  'assignment_group_IBM-SD-IN',
#  'assignment_group_BT-IBM-SI-MIO-Dispute Resolution-Rail',
#  'assignment_group_IBM-AP-Windows & VM-Rail',
#  'assignment_group_IBM-DS-Downsview-CA-AERO',
#  'assignment_group_IBM-SD-Italy Turin SD L1-Rail',
#  'assignment_group_BA-IBM-DL-IMI-IN-Unix-Aero',
#  'assignment_group_IBM-AP-COTS-Concur-Rail',
#  'assignment_group_IBM-AP-ServiceNowAdmin -Aero',
#  'assignment_group_VEN-HEM-GOLD-RAIL',
#  'assignment_group_IBM-SD-India SD L1-Rail',
#  'assignment_group_VEN-HEM-PLATINUM-RAIL',
#  'assignment_group_BA-INC-Vendors-Aero',
#  'assignment_group_IBM-AP-DFS-RAIL',
#  'assignment_group_IBM-AP-SAP-Manufacturing and Services-Rail',
#  'assignment_group_IBM-DS-Gold-Silver Support-US-AERO',
#  'assignment_group_IBM-DL-Configuration Librarian-Rail',
#  'assignment_group_IBM-DS-DOR-400CoteVertu-CA-AERO',
#  'assignment_group_IBM-AP-COTS-Maximo-Rail',
#  'assignment_group_BT-VEN-TCS-NW-Network Support-Rail',
#  'assignment_group_IBM-SD-Web',
#  'assignment_group_BT-INC-Vendors-Rail',
#  'assignment_group_IBM-AP-COTS-Interflex-Rail',
#  'assignment_group_IBM-AP-AD-Rail',
#  'assignment_group_IBM-AP-SAP-HR-Rail',
#  'assignment_group_BA-IBM-APPR-SAP PSI-Montreal-Aero',
#  'assignment_group_IBM-SS-Windows Server Admin - Montreal',
#  'assignment_group_BA-SS-AD Enterprise Admin-Aero',
#  'assignment_group_IBM-AS-Identity and access mgmt-Aero',
#  'assignment_group_BT-IBM-APPR-Oracle-Rail',
#  'assignment_group_IBM-AP-COTS-Metalag-Rail',
#  'assignment_group_BA-IBM-APPR-SAP Basis-Montreal-Aero',
#  'assignment_group_IBM-SD-Italy Turin SD Self Service-Rail',
#  'assignment_group_IBM-AP-Printer Support-Wichita-AERO',
#  'assignment_group_BT-IBM-DB-Database Support-RAIL',
#  'assignment_group_VEN-AVASO-CritSupp_ROW-Rail',
#  'assignment_group_BA-VEN-Xerox Printer Support-Canada',
#  'assignment_group_VEN-ATT-Integration-Telephony-Aero',
#  'assignment_group_IBM-SD-Italy Naples SD L1-Rail',
#  'assignment_group_BA-IBM-SS-Unix Admin - Montreal-Aero',
#  'assignment_group_VEN-HEM-GOLD-AERO',
#  'assignment_group_BA-IBM-AP-Middleware-AERO',
#  'assignment_group_BA-IBM-SD-Groupware Support-Aero',
#  'assignment_group_VEN-HEM-Staffed-Bangkok-TH-RAIL',
#  'assignment_group_IBM-SS-SECOPS Proxy-Aero',
#  'assignment_group_IBM-Mobile Device Management-US-AERO',
#  'assignment_group_IBM-DS-Dallas-US-AERO',
#  'assignment_group_IBM-SD-Web Non English-Aero',
#  'assignment_group_IBM-AP-COTS-Maximo-Aero',
#  'assignment_group_VEN-HEM-Staffed-Derby-UK-RAIL',
#  'assignment_group_BT-PM-Swivel-Alstom-Support',
#  'assignment_group_BT-IBM-APPR-COTS-Sharepoint-Rail',
#  'assignment_group_IBM-AP-COTS-Kronos-Rail',
#  'assignment_group_BT-IBM-APPR-SAP-Authorization-Rail',
#  'assignment_group_BT-IBM-SD-Groupware Support-Rail',
#  'assignment_group_IBM-AP-COTS-Finance Closing-Rail',
#  'assignment_group_VEN-HEM-Staffed-Bautzen-DE-RAIL',
#  'assignment_group_BT-IBM-AP-Middleware-RAIL',
#  'assignment_group_IBM-SD-Italy Turin CTS-Rail',
#  'calendar_duration_3 Minutes',
#  'calendar_duration_58 Minutes',
#  'calendar_duration_41 Days 1 Hour 12 Minutes',
#  'calendar_duration_2 Minutes',
#  'calendar_duration_22 Hours 24 Minutes',
#  'calendar_duration_10 Hours 40 Minutes',
#  'calendar_duration_163 Days 22 Hours 48 Minutes',
#  'calendar_duration_16 Minutes',
#  'calendar_duration_27 Days 23 Hours 2 Minutes',
#  'calendar_duration_126 Days 18 Hours 20 Minutes',
#  'calendar_duration_47 Minutes',
#  'calendar_duration_2 Days 6 Hours 41 Minutes',
#  'calendar_duration_7 Minutes',
#  'calendar_duration_8 Days 11 Hours 35 Minutes',
#  'calendar_duration_2 Days 19 Hours 57 Minutes',
#  'calendar_duration_22 Hours 20 Minutes',
#  'calendar_duration_2 Hours 36 Minutes',
#  'calendar_duration_3 Hours 55 Minutes',
#  'calendar_duration_1 Hour 10 Minutes',
#  'calendar_duration_21 Hours 28 Minutes',
#  'calendar_duration_4 Days 2 Hours 27 Minutes',
#  'calendar_duration_6 Days 20 Hours 16 Minutes',
#  'calendar_duration_1 Day 5 Hours 42 Minutes',
#  'calendar_duration_9 Days 2 Hours 4 Minutes',
#  'calendar_duration_1 Hour 12 Minutes',
#  'calendar_duration_4 Minutes',
#  'calendar_duration_48 Days 22 Hours 16 Minutes',
#  'calendar_duration_9 Minutes',
#  'calendar_duration_20 Minutes',
#  'calendar_duration_13 Minutes',
#  'calendar_duration_1 Hour 48 Minutes',
#  'calendar_duration_2 Days 16 Hours 58 Minutes',
#  'calendar_duration_3 Hours 9 Minutes',
#  'calendar_duration_3 Days 2 Hours 31 Minutes',
#  'calendar_duration_161 Days 21 Hours 18 Minutes',
#  'calendar_duration_2 Hours 45 Minutes',
#  'calendar_duration_11 Days 3 Hours 19 Minutes',
#  'calendar_duration_4 Hours 3 Minutes',
#  'calendar_duration_3 Hours 8 Minutes',
#  'calendar_duration_2 Hours 57 Minutes',
#  'calendar_duration_1 Day 51 Minutes',
#  'calendar_duration_26 Minutes',
#  'calendar_duration_8 Minutes',
#  'calendar_duration_2 Days 1 Hour 49 Minutes',
#  'calendar_duration_10 Days 22 Hours 15 Minutes',
#  'calendar_duration_3 Hours 10 Minutes',
#  'calendar_duration_4 Hours 9 Minutes',
#  'calendar_duration_5 Minutes',
#  'calendar_duration_18 Hours 8 Minutes',
#  'calendar_duration_2 Days 13 Hours 43 Minutes',
#  'calendar_duration_21 Hours 30 Minutes',
#  'calendar_duration_59 Days 5 Hours 55 Minutes',
#  'calendar_duration_3 Hours 2 Minutes',
#  'calendar_duration_16 Hours 15 Minutes',
#  'calendar_duration_22 Hours 16 Minutes',
#  'calendar_duration_14 Minutes',
#  'calendar_duration_23 Days 1 Hour 29 Minutes',
#  'calendar_duration_3 Days 22 Hours 26 Minutes',
#  'calendar_duration_2 Hours 49 Minutes',
#  'calendar_duration_6 Minutes',
#  'calendar_duration_2 Days 18 Hours 13 Minutes',
#  'calendar_duration_23 Hours 55 Minutes',
#  'calendar_duration_1 Day 15 Minutes',
#  'calendar_duration_3 Hours 30 Minutes',
#  'calendar_duration_37 Minutes',
#  'calendar_duration_1 Hour 52 Minutes',
#  'calendar_duration_1 Hour 18 Minutes',
#  'calendar_duration_1 Hour 33 Minutes',
#  'calendar_duration_6 Hours 7 Minutes',
#  'calendar_duration_1 Day 5 Hours 10 Minutes',
#  'calendar_duration_5 Hours 6 Minutes',
#  'calendar_duration_28 Minutes',
#  'calendar_duration_4 Hours 19 Minutes',
#  'calendar_duration_18 Hours 48 Minutes',
#  'calendar_duration_2 Hours 7 Minutes',
#  'calendar_duration_1 Minute',
#  'calendar_duration_12 Days 1 Hour 54 Minutes',
#  'calendar_duration_7 Hours 28 Minutes',
#  'calendar_duration_2 Days 3 Hours 6 Minutes',
#  'calendar_duration_9 Hours 24 Minutes',
#  'calendar_duration_12 Hours 32 Minutes',
#  'calendar_duration_48 Minutes',
#  'calendar_duration_2 Hours 30 Minutes',
#  'calendar_duration_1 Hour 21 Minutes',
#  'calendar_duration_153 Days 2 Hours 29 Minutes',
#  'calendar_duration_2 Days 22 Minutes',
#  'calendar_duration_17 Minutes',
#  'calendar_duration_29 Minutes',
#  'calendar_duration_1 Day 1 Hour 24 Minutes',
#  'calendar_duration_2 Days 17 Hours 30 Minutes',
#  'calendar_duration_2 Hours 26 Minutes',
#  'calendar_duration_10 Days 22 Hours 18 Minutes',
#  'calendar_duration_3 Days 16 Minutes',
#  'calendar_duration_5 Hours 7 Minutes',
#  'calendar_duration_164 Days 2 Hours 43 Minutes',
#  'calendar_duration_1 Day 16 Hours 23 Minutes',
#  'calendar_duration_1 Hour 26 Minutes',
#  'calendar_duration_5 Days 19 Hours 27 Minutes',
#  'calendar_duration_7 Days 13 Hours 42 Minutes',
#  'calendar_duration_13 Days 20 Hours 13 Minutes',
#  'calendar_duration_2 Hours 12 Minutes',
#  'calendar_duration_2 Hours 58 Minutes',
#  'calendar_duration_140 Days 4 Hours 7 Minutes',
#  'calendar_duration_1 Day 3 Hours 55 Minutes',
#  'calendar_duration_16 Days 3 Hours 40 Minutes',
#  'calendar_duration_5 Days 7 Hours 54 Minutes',
#  'calendar_duration_23 Days 17 Hours 31 Minutes',
#  'calendar_duration_164 Days 2 Hours 44 Minutes',
#  'calendar_duration_34 Minutes',
#  'calendar_duration_8 Days 1 Hour 32 Minutes',
#  'calendar_duration_78 Days 15 Hours 28 Minutes',
#  'calendar_duration_3 Days 1 Hour 26 Minutes',
#  'calendar_duration_1 Day 22 Minutes',
#  'calendar_duration_5 Hours 35 Minutes',
#  'calendar_duration_2 Hours 10 Minutes',
#  'calendar_duration_6 Days 15 Hours 57 Minutes',
#  'calendar_duration_18 Days 17 Hours 13 Minutes',
#  'calendar_duration_2 Days 19 Hours 56 Minutes',
#  'calendar_duration_5 Days 3 Hours 26 Minutes',
#  'calendar_duration_330 Days 22 Hours 32 Minutes',
#  'calendar_duration_4 Days 21 Hours 5 Minutes',
#  'calendar_duration_2 Hours 13 Minutes',
#  'calendar_duration_1 Hour 44 Minutes',
#  'calendar_duration_203 Days 6 Hours 52 Minutes',
#  'calendar_duration_8 Days 21 Hours 17 Minutes',
#  'calendar_duration_1 Day 23 Hours 14 Minutes',
#  'calendar_duration_1 Hour 1 Minute',
#  'calendar_duration_11 Days 2 Hours 29 Minutes',
#  'calendar_duration_22 Hours 2 Minutes',
#  'calendar_duration_3 Hours 7 Minutes',
#  'calendar_duration_5 Hours 22 Minutes',
#  'calendar_duration_46 Days 22 Hours 46 Minutes',
#  'calendar_duration_6 Days 18 Hours 31 Minutes',
#  'calendar_duration_10 Days 5 Hours 58 Minutes',
#  'calendar_duration_52 Minutes',
#  'calendar_duration_14 Days 6 Hours 6 Minutes',
#  'calendar_duration_13 Hours 51 Minutes',
#  'calendar_duration_1 Day 48 Minutes',
#  'calendar_duration_3 Hours 50 Minutes',
#  'calendar_duration_3 Hours 23 Minutes',
#  'calendar_duration_59 Minutes',
#  'calendar_duration_14 Days 2 Hours 32 Minutes',
#  'calendar_duration_2 Hours 21 Minutes',
#  'calendar_duration_1 Day 6 Hours 8 Minutes',
#  'calendar_duration_7 Hours 18 Minutes',
#  'calendar_duration_2 Hours 22 Minutes',
#  'calendar_duration_1 Day 1 Hour 54 Minutes',
#  'calendar_duration_3 Hours 20 Minutes',
#  'calendar_duration_1 Day 21 Hours',
#  'calendar_duration_1 Day 12 Minutes',
#  'calendar_duration_1 Hour 13 Minutes',
#  'calendar_duration_1 Day 5 Hours 50 Minutes',
#  'calendar_duration_1 Hour 6 Minutes',
#  'calendar_duration_53 Minutes',
#  'calendar_duration_1 Hour 30 Minutes',
#  'calendar_duration_12 Days 30 Minutes',
#  'calendar_duration_1 Day 3 Hours 38 Minutes',
#  'calendar_duration_17 Hours 35 Minutes',
#  'calendar_duration_3 Hours 38 Minutes',
#  'calendar_duration_6 Hours 8 Minutes',
#  'calendar_duration_2 Hours 24 Minutes',
#  'calendar_duration_30 Days 4 Hours 59 Minutes',
#  'calendar_duration_5 Days 21 Hours 48 Minutes',
#  'calendar_duration_39 Minutes',
#  'calendar_duration_1 Day 10 Hours 1 Minute',
#  'calendar_duration_27 Minutes',
#  'calendar_duration_6 Hours 13 Minutes',
#  'calendar_duration_28 Days 43 Minutes',
#  'calendar_duration_5 Hours 1 Minute',
#  'calendar_duration_38 Minutes',
#  'calendar_duration_6 Hours 31 Minutes',
#  'calendar_duration_21 Minutes',
#  'calendar_duration_9 Days 22 Hours 25 Minutes',
#  'calendar_duration_1 Day 3 Hours 15 Minutes',
#  'calendar_duration_2 Days 22 Hours 58 Minutes',
#  'calendar_duration_20 Hours 47 Minutes',
#  'calendar_duration_6 Days 5 Hours 14 Minutes',
#  'calendar_duration_1 Hour 37 Minutes',
#  'calendar_duration_2 Hours 17 Minutes',
#  'contact_type_Self-service',
#  'contact_type_IT Support',
#  'contact_type_Phone',
#  'contact_type_Chat',
#  'u_preferred_language_English',
#  'u_preferred_language_French Canadian',
#  'u_preferred_language_Portuguese',
#  'u_preferred_language_German',
#  'u_preferred_language_Dutch',
#  'u_preferred_language_Thai',
#  'u_cause_Access',
#  'u_cause_AntiVirus',
#  'u_cause_Knowledge/training related',
#  'u_cause_Others',
#  'u_cause_Application',
#  'u_cause_Server - Configuration',
#  'u_cause_Local System',
#  'u_cause_Database',
#  'u_cause_Server - Service',
#  'u_cause_No Cause',
#  'u_cause_Component issue',
#  'u_cause_Telephone',
#  'u_cause_e-mail and messaging',
#  'u_cause_Printer',
#  'u_cause_Security',
#  'u_cause_Connectivity WAN - Configuration',
#  'u_cause_Connectivity LAN - hardware',
#  'u_cause_Power failure - Unplanned',
#  'u_cause_Connectivity LAN - Configuration',
#  'u_cause_Backup hardware',
#  'u_cause_Connectivity LAN - utilization',
#  'u_cause_Server - Hardware',
#  'u_cause_Capacity related',
#  'location_559 - Montreal Head Office',
#  'location_147 - Derby Litchurch Lane',
#  'location_182 - Siegen',
#  'location_506 - Dorval Administrative Centre (CA)',
#  'location_508 - Mirabel Manufacturing',
#  'location_Bombardier Transportation',
#  'location_240 - Hortolandia',
#  'location_187 - Hennigsdorf',
#  'location_241 - Cebu',
#  'location_551 - Casablanca Aeropole',
#  'location_24 - Cluj-Napoca PBC',
#  'location_514 - Toronto De Havilland Inc.',
#  'location_154 - Zurich Oerlikon Toro 1',
#  'location_433 - London Old Oak Common Depot',
#  'location_509 - Saint-Laurent BAN 1',
#  'location_19 - Crespin',
#  'location_521_Gold_Room_233 - Completion Center - Room 233 - Conference',
#  'location_449 - Bangalore Quest (3rd Party)',
#  'location_426_Gold_Room_Presidents_Board_Room - Berlin New HQ',
#  'location_505 - Dorval Plant 3',
#  'location_181 - Kassel',
#  'location_250 - Kuala Lumpur',
#  'location_520 - Wichita Learjet',
#  'location_671 - Giza 6-Oct Line Depot',
#  'location_516 - Dorval Completion Centre',
#  'location_510 - Saint-Laurent BAN 2',
#  'location_294 - West Melbourne',
#  'location_60 - Plattsburgh',
#  'location_123 - Derby Etches Park',
#  'location_426 - Berlin New HQ',
#  'location_323 - London Pancras Square',
#  'location_64 - Bruges',
#  'location_521_Gold_Room_227 - Completion Center - Room 227 - Conference',
#  'location_289 - Dandenong',
#  'location_521_Gold_Room_107 - Completion Center - Room 107 - Conference',
#  'location_528 - Tucson',
#  'location_121 - Welby Asfordby',
#  'location_Bombardier Aerospace',
#  'location_377 - Wulkuraka',
#  'location_95 - Vienna',
#  'location_152 - Zurich Oerlikon PowerLab',
#  'location_521 - Fort Lauderdale',
#  'location_236 - Bangkok Klongtoey',
#  'location_199 - Gurgaon (RCS & IS Hub)',
#  'location_200 - Savli (Vadodara)',
#  'location_94 - St-Bruno',
#  'location_521_Gold_Room_221 - Completion Center - Room 221 - Conference',
#  'location_521_Gold_Room_106 - Completion Center - Room 106 - Conference',
#  'location_T14 - Montreal Viger Data Centre',
#  'location_549 - Bangalore ESO',
#  'location_523 - Dallas Learjet (Love Field)',
#  'location_189 - Hyderabad Engineering Center',
#  'location_511 - Saint-Laurent OPTO',
#  'location_532 - Belfast Queens Island',
#  'location_92 - Thunder Bay',
#  'location_506_Gold_Room_003 - Administrative Centre - Room 003',
#  'location_185 - Mannheim',
#  'location_521_Gold_Room_104 - Completion Center - Room 104 - Conference',
#  'location_531 - Frankfurt Gross-Gerau',
#  'location_183 - Bautzen',
#  'location_503 - Saint-Laurent Marcel-Laurin',
#  'category_Hardware',
#  ...]

# %%
X_test_1_new = X_test_1_new.fillna(X_test_1_new.median())

# %%
X_train_1_modified = X_train_1_new.fillna(X_test_1_new.mean())
X_test_1_modified = X_test_1_new.fillna(X_test_1_new.mean())

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
X_test_1_knn = imputer.fit_transform(X_test_1_new)

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
X_train_1_knn = imputer.fit_transform(X_train_1_new)

# %%
X_train_1_new.columns[X_train_1_new.isna().any()].tolist()
# Out:
# []

# %%
X_test_1_new.columns[X_test_1_new.isna().any()].tolist()
# Out:
# []

# %%
X_train_1_modified.columns[X_train_1_modified.isna().any()].tolist()
# Out:
# []

# %%
X_test_1_modified.columns[X_test_1_modified.isna().any()].tolist()
# Out:
# []

# %%
X_test_1_knn = pd.DataFrame(X_test_1_knn)

# %%
X_train_1_knn = pd.DataFrame(X_train_1_knn)

# %% [markdown]
# ## Standardization ##

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_1_new_scaled = scaler.fit_transform(X_train_1_new)
X_test_1_new_scaled = scaler.transform(X_test_1_new)

# %%
X_train_1_modified_scaled = scaler.fit_transform(X_train_1_modified)
X_test_1_modified_scaled = scaler.transform(X_test_1_modified)

# %%
X_train_1_knn_scaled = scaler.fit_transform(X_train_1_knn)
X_test_1_knn_scaled = scaler.transform(X_test_1_knn)

# %% [markdown]
# ## Random Forest Regression with median missing value approach ##

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_train_1_new_scaled,y_train_1)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
# Import the model we are using
#from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
#rf_without_scaled = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
#rf_without_scaled.fit(X_train_1_new,y_train_1)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
y_pred_without_scaled = rf_without_scaled.predict(X_test_1_new)

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test_1,y_pred_without_scaled))
print("RMSE",np.sqrt(mean_squared_error(y_test_1,y_pred_without_scaled)))
# Out:
# MSE 68075.27691644622
# RMSE 260.9123931829345

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test_1,y_pred_without_scaled)
print(r2)
# Out:
# 0.9266945943166779

# %%
Adj_r2 = 1 - (1-r2_score(y_test_1, y_pred_)) * (len(y1)-1)/(len(y1)-X1.shape[1]-1)
print(Adj_r2)

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test_1,y_pred_without_scaled))
# Out:
# MAE 56.59708800485065

# %%
# Calculate the absolute errors
errors = abs(y_pred_without_scaled - y_test_1)

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test_1)

# %%
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 67.28 %.

# %%
y_pred = rf.predict(X_test_1_new_scaled)

# %%
data1 = pd.DataFrame({'Actual': y_test_1, 'Predicted': y_pred})

# %%
data1
# Out:
#              Actual    Predicted
# 89813      1.415556     1.454835
# 66017      2.505556     2.444408
# 101844    47.686111    48.939244
# 66590      2.802222     2.556729
# 85433   4320.441667  3936.840273
# 118367     0.030278     0.029314
# 54720    110.670278   111.843529
# 73031      3.077222     3.113743
# 42964    144.569444   147.708499
# 111208     7.294167     7.036465
# 83385     12.380278    13.111585
# 125284     1.275278     1.284142
# 91023      0.117500     0.117230
# 82654      3.324444     3.324785
# 22575    305.258611   287.572655
# 66894     22.065556    21.904148
# 43307      2.038889     2.142640
# 32490   1029.796944  1030.498390
# 1641       2.130556     2.151963
# 54943      6.331389     6.593424
# 134173     0.120278     0.119158
# 121543     4.524444     4.237467
# 127757  1511.340556  1306.622564
# 60536      0.959167     0.961208
# 1885       2.266944     2.289534
# 43553      3.269444     3.340072
# 82384    139.738611   141.196045
# 36437    220.971389   217.572438
# 87105    314.307778   325.510606
# 1529       0.241111     0.240454
# 99890    213.186389   210.007358
# 51933     68.823611    68.569203
# 138832     2.140278     2.157533
# 27684      2.883056     2.970833
# 83481      3.166667     3.149956
# 137413    31.479167    29.534466
# 28415      2.127222     2.159195
# 126816     4.169444     4.080879
# 140418  4404.477778  4150.514250
# 64320      3.444722     3.477497
# 134161     0.279167     0.292223
# 109945   158.868611   159.861684
# 2939       2.382778     2.381672
# 52186      0.924444     0.931442
# 105892     0.041389     0.040439
# 64647      1.919444     1.874310
# 92228      0.881944     0.851060
# 27204      3.515556     3.540074
# 128832     7.416111     6.994218
# 60422   3519.474167  3711.915420
# 22909     71.270278   764.025784
# 19141     20.374722    21.139028
# 2087       0.083056     0.081962
# 134149     0.197222     0.190060
# 2944       1.381111     1.416026
# 140451  3689.802500  3828.071062
# 123466     0.470278     0.465403
# 36856      0.043333     0.041530
# 35492     22.474444    22.263183
# 74483      1.397222     1.425737
# 61706      0.049722     0.049033
# 112715   119.564167   118.121426
# 12454     73.430278    72.103953
# 84132      0.523889     0.478019
# 52174      0.101389     0.101037
# 32917      8.252222     7.402724
# 6448       3.680278     3.557072
# 103918     0.296667     0.298509
# 2194     296.832778   652.752609
# 112615     9.647778     8.656155
# 85464   4109.033889  3872.887349
# 121588  3485.077500  3520.634824
# 121803   146.796667  2068.695168
# 62309   1935.725278  1602.311726
# 69192      0.370000     0.356691
# 67839     47.070278    46.453819
# 121561     0.626111     0.619227
# 128845     0.053611     0.050845
# 104178   168.624722   172.138388
# 33340      0.193889     0.182702
# 133001   141.620556   140.358251
# 127087     0.153611     0.152851
# 7064       0.080278     0.080064
# 110065     2.073611     2.161073
# 24568      7.906667     7.486986
# 32558    170.100000   171.560736
# 44159    770.111944   747.329006
# 33990    135.235278   139.794404
# 32948     25.619722    25.697164
# 100331    23.133056    22.583511
# 116899     0.212778     0.238481
# 121813   146.716389  2084.507326
# 91739      0.152778     0.154015
# 123826    71.046111    76.622302
# 10295      0.066111     0.066010
# 100874    18.905278    18.335604
# 101012     0.636944     0.645312
# 79626    307.494722   290.674349
# 123860   198.041667   201.540294
# 17359      0.737778     0.806077
# 2095       6.841111     6.968606
# 108194   188.921389   196.043129
# 94138      1.803611     1.795615
# 32839      4.108889     3.904179
# 137080    23.539444    23.734029
# 140808     0.059722     0.059642
# 100595     0.918333     0.930956
# 7395       0.281389     0.289715
# 28611    186.271389   183.368582
# 17282   3938.786111  3952.356654
# 78472      0.943889     0.932355
# 60525   3674.448056  3808.894217
# 86166    149.208889   150.723939
# 63238      2.795556     2.858066
# 135657    26.987778    27.894807
# 82255      0.085000     0.086233
# 126954    26.819722    28.185781
# 111207     2.793611     2.839438
# 67618    641.061111   791.707387
# 50306    379.435833   387.740498
# 27527      1.156944     1.130981
# 31979      0.055556     0.058782
# 88984     32.957778    31.826432
# 125562     0.178056     0.158042
# 49383    170.947222   173.243665
# 117248     2.332500     2.428425

# %% [markdown]
# ## Mean Absolute Error , Mean Squared Error R sqaured and Adjusted R squared

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test_1,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test_1,y_pred)))
# Out:
# MSE 68060.98742218656
# RMSE 260.8850080441315

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test_1,y_pred))
# Out:
# MAE 56.57771089947151

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test_1,y_pred)
print(r2)
# Out:
# 0.926709981652891

# %%
Adj_r2 = 1 - (1-r2_score(y_test_1, y_pred)) * (len(y1)-1)/(len(y1)-X1.shape[1]-1)
print(Adj_r2)
# Out:
# 0.9026216539444006

# %% [markdown]
# ###### Calculate the absolute errors ##
# errors = abs(y_pred - y_test_1)

# %%
errors = abs(y_pred - y_test_1)

# %%
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 56.58 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test_1)

# %%
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 67.3 %.

# %% [markdown]
# ## Random Forest Regression with mean missing value approach ##

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_train_1_modified_scaled,y_train_1)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
y_pred_1 = rf.predict(X_test_1_modified_scaled)

# %%
data2 = pd.DataFrame({'Actual': y_test_1, 'Predicted': y_pred_1})

# %%
data2
# Out:
#              Actual    Predicted
# 89813      1.415556     1.454835
# 66017      2.505556     2.444408
# 101844    47.686111    48.939244
# 66590      2.802222     2.556729
# 85433   4320.441667  3936.840273
# 118367     0.030278     0.029314
# 54720    110.670278   111.843529
# 73031      3.077222     3.113743
# 42964    144.569444   147.708499
# 111208     7.294167     7.036465
# 83385     12.380278    13.111585
# 125284     1.275278     1.284142
# 91023      0.117500     0.117230
# 82654      3.324444     3.324785
# 22575    305.258611   287.572655
# 66894     22.065556    21.904148
# 43307      2.038889     2.142640
# 32490   1029.796944  1030.498390
# 1641       2.130556     2.151963
# 54943      6.331389     6.593424
# 134173     0.120278     0.119158
# 121543     4.524444     4.237467
# 127757  1511.340556  1306.622564
# 60536      0.959167     0.961208
# 1885       2.266944     2.289534
# 43553      3.269444     3.340072
# 82384    139.738611   141.196045
# 36437    220.971389   217.572438
# 87105    314.307778   325.510606
# 1529       0.241111     0.240454
# 99890    213.186389   210.007358
# 51933     68.823611    68.569203
# 138832     2.140278     2.157533
# 27684      2.883056     2.970833
# 83481      3.166667     3.149956
# 137413    31.479167    29.534466
# 28415      2.127222     2.159195
# 126816     4.169444     4.080879
# 140418  4404.477778  4150.514250
# 64320      3.444722     3.477497
# 134161     0.279167     0.292223
# 109945   158.868611   159.861684
# 2939       2.382778     2.381672
# 52186      0.924444     0.931442
# 105892     0.041389     0.040439
# 64647      1.919444     1.874310
# 92228      0.881944     0.851060
# 27204      3.515556     3.540074
# 128832     7.416111     6.994218
# 60422   3519.474167  3711.915420
# 22909     71.270278   764.025784
# 19141     20.374722    21.139028
# 2087       0.083056     0.081962
# 134149     0.197222     0.190060
# 2944       1.381111     1.416026
# 140451  3689.802500  3828.071062
# 123466     0.470278     0.465403
# 36856      0.043333     0.041530
# 35492     22.474444    22.263183
# 74483      1.397222     1.425737
# 61706      0.049722     0.049033
# 112715   119.564167   118.121426
# 12454     73.430278    72.103953
# 84132      0.523889     0.478019
# 52174      0.101389     0.101037
# 32917      8.252222     7.402724
# 6448       3.680278     3.557072
# 103918     0.296667     0.298509
# 2194     296.832778   652.752609
# 112615     9.647778     8.656155
# 85464   4109.033889  3872.887349
# 121588  3485.077500  3520.634824
# 121803   146.796667  2068.695168
# 62309   1935.725278  1602.311726
# 69192      0.370000     0.356691
# 67839     47.070278    46.453819
# 121561     0.626111     0.619227
# 128845     0.053611     0.050845
# 104178   168.624722   172.138388
# 33340      0.193889     0.182702
# 133001   141.620556   140.358251
# 127087     0.153611     0.152851
# 7064       0.080278     0.080064
# 110065     2.073611     2.161073
# 24568      7.906667     7.486986
# 32558    170.100000   171.560736
# 44159    770.111944   747.329006
# 33990    135.235278   139.794404
# 32948     25.619722    25.697164
# 100331    23.133056    22.583511
# 116899     0.212778     0.238481
# 121813   146.716389  2084.507326
# 91739      0.152778     0.154015
# 123826    71.046111    76.622302
# 10295      0.066111     0.066010
# 100874    18.905278    18.335604
# 101012     0.636944     0.645312
# 79626    307.494722   290.674349
# 123860   198.041667   201.540294
# 17359      0.737778     0.806077
# 2095       6.841111     6.968606
# 108194   188.921389   196.043129
# 94138      1.803611     1.795615
# 32839      4.108889     3.904179
# 137080    23.539444    23.734029
# 140808     0.059722     0.059642
# 100595     0.918333     0.930956
# 7395       0.281389     0.289715
# 28611    186.271389   183.368582
# 17282   3938.786111  3952.356654
# 78472      0.943889     0.932355
# 60525   3674.448056  3808.894217
# 86166    149.208889   150.723939
# 63238      2.795556     2.858066
# 135657    26.987778    27.894807
# 82255      0.085000     0.086233
# 126954    26.819722    28.185781
# 111207     2.793611     2.839438
# 67618    641.061111   791.707387
# 50306    379.435833   387.740498
# 27527      1.156944     1.130981
# 31979      0.055556     0.058782
# 88984     32.957778    31.826432
# 125562     0.178056     0.158042
# 49383    170.947222   173.243665
# 117248     2.332500     2.428425

# %% [markdown]
# ## Mean Absolute Error , Mean Squared Error R sqaured and Adjusted R squared

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test_1,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test_1,y_pred)))
# Out:
# MSE 68060.98742218656
# RMSE 260.8850080441315

# %%
# Calculate the absolute errors
errors = abs(y_pred_1 - y_test_1)

# %%
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 56.58 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test_1)

# %%
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 67.3 %.

# %% [markdown]
# ## Feature Importance ##

# %%
feature_list = list(X_train_1_new.columns)

# %%
features = np.array(X_train_1_new)

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: create_resolved_days Importance: 0.1
# Variable: open_closed_days     Importance: 0.1
# Variable: open_resolved_days   Importance: 0.09
# Variable: create_closed_days   Importance: 0.09
# Variable: create_resolved_seconds Importance: 0.07
# Variable: business_duration_mins Importance: 0.07
# Variable: open_resolved_seconds Importance: 0.06
# Variable: open_closed_seconds  Importance: 0.06
# Variable: create_closed_seconds Importance: 0.06
# Variable: calendar_duration_mins Importance: 0.06
# Variable: create_lastupdated_days Importance: 0.03
# Variable: open_lastupdated_seconds Importance: 0.02
# Variable: open_lastupdated_days Importance: 0.02
# Variable: create_lastupdated_seconds Importance: 0.02
# Variable: open_extracted_seconds Importance: 0.02
# Variable: open_extracted_days  Importance: 0.02
# Variable: create_extracted_seconds Importance: 0.02
# Variable: create_extracted_days Importance: 0.02
# Variable: sys_mod_count        Importance: 0.01
# Variable: month_of_created     Importance: 0.01
# Variable: month_of_opened      Importance: 0.01
# Variable: _score               Importance: 0.0
# Variable: u_qs_times_reassigned Importance: 0.0
# Variable: u_qs_major_incident  Importance: 0.0
# Variable: u_end_of_support_No Support Importance: 0.0
# Variable: u_end_of_support_Unknown Importance: 0.0
# Variable: u_end_of_support_Yes Importance: 0.0
# Variable: u_end_of_support_No  Importance: 0.0
# Variable: u_qs_opened_by_group_No Group Importance: 0.0
# Variable: u_qs_opened_by_group_IBM-SD-India SD L1-Rail Importance: 0.0
# Variable: u_qs_opened_by_group_BT-IBM-APPR-SAP-Basis-Rail Importance: 0.0
# Variable: u_qs_opened_by_group_BT-IBM-SI-Asset Governance-Rail Importance: 0.0
# Variable: u_qs_opened_by_group_IBM-SD-IN Importance: 0.0
# Variable: u_qs_opened_by_group_IBM-SD-Italy Turin SD L1-Rail Importance: 0.0
# Variable: u_qs_opened_by_group_IBM-SD-French-Aero Importance: 0.0
# Variable: u_qs_opened_by_group_IBM-AP-Asset Management Importance: 0.0
# Variable: u_qs_opened_by_group_IBM-SD-India CTS-Rail Importance: 0.0
# Variable: u_qs_opened_by_group_IBM-SD-Italy Naples SD L1-Rail Importance: 0.0
# Variable: u_qs_opened_by_group_IBM-AP-COTS-Maximo-Rail Importance: 0.0
# Variable: u_warranty_expired_No Warranty Importance: 0.0
# Variable: u_warranty_expired_No Importance: 0.0
# Variable: u_warranty_expired_Unknown Importance: 0.0
# Variable: u_warranty_expired_Yes Importance: 0.0
# Variable: u_lan_bank_of_hours  Importance: 0.0
# Variable: u_qs_fcresolve       Importance: 0.0
# Variable: knowledge            Importance: 0.0
# Variable: cmdb_ci_Unknown      Importance: 0.0
# Variable: cmdb_ci_BTIS1000096836 Importance: 0.0
# Variable: cmdb_ci_McAfee Complete Data Protection Importance: 0.0
# Variable: cmdb_ci_iPhone       Importance: 0.0
# Variable: cmdb_ci_windows      Importance: 0.0
# Variable: cmdb_ci_a010065p211  Importance: 0.0
# Variable: cmdb_ci_eMail Service Importance: 0.0
# Variable: cmdb_ci_MSAF@IDM0018 Importance: 0.0
# Variable: cmdb_ci_Computer Hardware Importance: 0.0
# Variable: cmdb_ci_Finance Monthly Closing Importance: 0.0
# Variable: cmdb_ci_Other Quality d/b Importance: 0.0
# Variable: cmdb_ci_SAP DWA/VCM-Finance PROD Importance: 0.0
# Variable: cmdb_ci_a010357p210  Importance: 0.0
# Variable: cmdb_ci_Computer Software Importance: 0.0
# Variable: cmdb_ci_Active Directory Certificate Services Importance: 0.0
# Variable: cmdb_ci_Application / System Access Management Importance: 0.0
# Variable: cmdb_ci_MAXIMO BT EMEA PROD Importance: 0.0
# Variable: cmdb_ci_Enovia       Importance: 0.0
# Variable: cmdb_ci_P2178047     Importance: 0.0
# Variable: cmdb_ci_Concur Interface Importance: 0.0
# Variable: cmdb_ci_ServiceNow Dev Importance: 0.0
# Variable: cmdb_ci_a010760p100  Importance: 0.0
# Variable: cmdb_ci_P2126922     Importance: 0.0
# Variable: cmdb_ci_LL210306010  Importance: 0.0
# Variable: cmdb_ci_Mobile Pass - (Cloud SAS) Importance: 0.0
# Variable: cmdb_ci_Meetings / Video Conferencing / Webex Importance: 0.0
# Variable: cmdb_ci_Bombardier Aerospace Importance: 0.0
# Variable: cmdb_ci_Email and Calendar Importance: 0.0
# Variable: cmdb_ci_PulseSecure  Importance: 0.0
# Variable: cmdb_ci_Epayable PROD Importance: 0.0
# Variable: cmdb_ci_mtlbdirect10 Importance: 0.0
# Variable: cmdb_ci_DBP - SAP IMPULS PROD Importance: 0.0
# Variable: cmdb_ci_Team         Importance: 0.0
# Variable: cmdb_ci_Phone and Mobile Importance: 0.0
# Variable: cmdb_ci_Baan  - Vaesteras PROD Importance: 0.0
# Variable: cmdb_ci_Printing and Fax Services Importance: 0.0
# Variable: cmdb_ci_iflybombardier.com Importance: 0.0
# Variable: cmdb_ci_A011262P017  Importance: 0.0
# Variable: cmdb_ci_Phone and Mobile Offerings Importance: 0.0
# Variable: cmdb_ci_Computer Hardware Offerings Importance: 0.0
# Variable: cmdb_ci_MAXIMO BT APAC PROD Importance: 0.0
# Variable: cmdb_ci_Office Online Importance: 0.0
# Variable: cmdb_ci_BUSPLB02FWD00 Importance: 0.0
# Variable: cmdb_ci_ServiceNow PROD Importance: 0.0
# Variable: cmdb_ci_Windows      Importance: 0.0
# Variable: cmdb_ci_Planner      Importance: 0.0
# Variable: cmdb_ci_BGBDXY01SWA00-0 Importance: 0.0
# Variable: cmdb_ci_P2127356     Importance: 0.0
# Variable: cmdb_ci_Other        Importance: 0.0
# Variable: cmdb_ci_Interflex - Brugges Importance: 0.0
# Variable: cmdb_ci_Computer Software Offerings Importance: 0.0
# Variable: cmdb_ci_0003901990EX2200 RT Importance: 0.0
# Variable: cmdb_ci_iaa0001      Importance: 0.0
# Variable: cmdb_ci_SAP - GUI    Importance: 0.0
# Variable: cmdb_ci_(Automation Only) Access Authorisation Tool Offerings Importance: 0.0
# Variable: cmdb_ci_supplier.aero.bombardier.com Importance: 0.0
# Variable: cmdb_ci_SAP PSI Global Importance: 0.0
# Variable: cmdb_ci_TUCWPRINT001 Importance: 0.0
# Variable: cmdb_ci_BGBMBY01SWA01 Importance: 0.0
# Variable: cmdb_ci_MTLCICON701  Importance: 0.0
# Variable: cmdb_ci_P2190298     Importance: 0.0
# Variable: cmdb_ci_eRAF - Request Authorization Database Importance: 0.0
# Variable: cmdb_ci_Metalag PROD Importance: 0.0
# Variable: cmdb_ci_LOTUS NOTES PROD Importance: 0.0
# Variable: cmdb_ci_Alstom-Password reset Importance: 0.0
# Variable: cmdb_ci_Service Now  Importance: 0.0
# Variable: cmdb_ci_Email Offerings Importance: 0.0
# Variable: cmdb_ci_SAP BASIS PROD Importance: 0.0
# Variable: cmdb_ci_Network      Importance: 0.0
# Variable: cmdb_ci_Application / System Access Management Offerings Importance: 0.0
# Variable: cmdb_ci_Alstom-PC Refresh Importance: 0.0
# Variable: cmdb_ci_Baan Australia PROD Importance: 0.0
# Variable: cmdb_ci_BTIS1000067892 Importance: 0.0
# Variable: cmdb_ci_sFTP PROD    Importance: 0.0
# Variable: cmdb_ci_McAfee Endpoint Protection, Advanced Suite Importance: 0.0
# Variable: cmdb_ci_DHDCAM       Importance: 0.0
# Variable: cmdb_ci_P2180894     Importance: 0.0
# Variable: cmdb_ci_Enterprise   Importance: 0.0
# Variable: cmdb_ci_MTLLASMS001  Importance: 0.0
# Variable: cmdb_ci_BTIS1000004321 Importance: 0.0
# Variable: cmdb_ci_iem0000      Importance: 0.0
# Variable: cmdb_ci_Information Technology Management Importance: 0.0
# Variable: cmdb_ci_dorca-023-dr03.bombardier Importance: 0.0
# Variable: cmdb_ci_P2183541     Importance: 0.0
# Variable: cmdb_ci_Teams        Importance: 0.0
# Variable: cmdb_ci_BTalent      Importance: 0.0
# Variable: cmdb_ci_IZM0119      Importance: 0.0
# Variable: cmdb_ci_P2175112     Importance: 0.0
# Variable: cmdb_ci_a010357p302  Importance: 0.0
# Variable: cmdb_ci_ServiceNow Instance - PROD Importance: 0.0
# Variable: cmdb_ci_Mobile Pass - LDAP Importance: 0.0
# Variable: cmdb_ci_Catia 3Dcom DEV Importance: 0.0
# Variable: cmdb_ci_Maximo for Aviation PROD Importance: 0.0
# Variable: cmdb_ci_Internet and Network Importance: 0.0
# Variable: cmdb_ci_BBTSWHBRU002_2 Importance: 0.0
# Variable: cmdb_ci_bdefra00lic02 Importance: 0.0
# Variable: cmdb_ci_SAP PR2 Interface Importance: 0.0
# Variable: cmdb_ci_ BTIS1000007049 Importance: 0.0
# Variable: cmdb_ci_Lotus Notes  Importance: 0.0
# Variable: cmdb_ci_MobilePass Cloud Service Importance: 0.0
# Variable: cmdb_ci_Alstom -APP Office 365 Importance: 0.0
# Variable: cmdb_ci_sunpa016     Importance: 0.0
# Variable: cmdb_ci_FAB6         Importance: 0.0
# Variable: cmdb_ci_PASSWORD MANAGER Importance: 0.0
# Variable: cmdb_ci_BTIS1000091084 Importance: 0.0
# Variable: cmdb_ci_Sharepoint EU PROD Importance: 0.0
# Variable: cmdb_ci_Kronos       Importance: 0.0
# Variable: cmdb_ci_BTIS1000007376 Importance: 0.0
# Variable: cmdb_ci_P2126988     Importance: 0.0
# Variable: cmdb_ci_PSR - SAP eBuy PROD Importance: 0.0
# Variable: cmdb_ci_Print and Fax Offerings Importance: 0.0
# Variable: cmdb_ci_Rational_SYNERGY_PROD Importance: 0.0
# Variable: cmdb_ci_a011179p300  Importance: 0.0
# Variable: cmdb_ci_Others       Importance: 0.0
# Variable: cmdb_ci_ZIA - Zscaler  - BT Importance: 0.0
# Variable: cmdb_ci_eRoom_01-CommunityAdministration-QA@MTLSQLERM501 Importance: 0.0
# Variable: cmdb_ci_P2155924     Importance: 0.0
# Variable: cmdb_ci_P2184372     Importance: 0.0
# Variable: cmdb_ci_Makino PROD  Importance: 0.0
# Variable: impact_1 - Extensive/Widespread Importance: 0.0
# Variable: impact_2 - Significant/Large Importance: 0.0
# Variable: active               Importance: 0.0
# Variable: business_duration_3 Minutes Importance: 0.0
# Variable: business_duration_0 Seconds Importance: 0.0
# Variable: business_duration_9 Days 16 Hours Importance: 0.0
# Variable: business_duration_2 Minutes Importance: 0.0
# Variable: business_duration_6 Hours 24 Minutes Importance: 0.0
# Variable: business_duration_39 Days 8 Hours Importance: 0.0
# Variable: business_duration_16 Minutes Importance: 0.0
# Variable: business_duration_6 Days 16 Hours Importance: 0.0
# Variable: business_duration_30 Days 5 Hours 6 Minutes Importance: 0.0
# Variable: business_duration_16 Hours Importance: 0.0
# Variable: business_duration_2 Days 1 Hour 20 Minutes Importance: 0.0
# Variable: business_duration_1 Day Importance: 0.0
# Variable: business_duration_8 Hours Importance: 0.0
# Variable: business_duration_5 Hours 28 Minutes Importance: 0.0
# Variable: business_duration_1 Day 8 Hours Importance: 0.0
# Variable: business_duration_1 Day 16 Hours Importance: 0.0
# Variable: business_duration_12 Hours 35 Minutes Importance: 0.0
# Variable: business_duration_2 Days 8 Hours Importance: 0.0
# Variable: business_duration_4 Minutes Importance: 0.0
# Variable: business_duration_11 Days 16 Hours Importance: 0.0
# Variable: business_duration_9 Minutes Importance: 0.0
# Variable: business_duration_13 Minutes Importance: 0.0
# Variable: business_duration_2 Hours 32 Minutes Importance: 0.0
# Variable: business_duration_38 Days 16 Hours Importance: 0.0
# Variable: business_duration_2 Hours 57 Minutes Importance: 0.0
# Variable: business_duration_8 Minutes Importance: 0.0
# Variable: business_duration_2 Days 7 Hours 44 Minutes Importance: 0.0
# Variable: business_duration_6 Hours 19 Minutes Importance: 0.0
# Variable: business_duration_5 Hours 30 Minutes Importance: 0.0
# Variable: business_duration_14 Days 8 Hours 29 Minutes Importance: 0.0
# Variable: business_duration_6 Hours 40 Minutes Importance: 0.0
# Variable: business_duration_14 Minutes Importance: 0.0
# Variable: business_duration_5 Days 17 Hours 29 Minutes Importance: 0.0
# Variable: business_duration_20 Hours 43 Minutes Importance: 0.0
# Variable: business_duration_37 Minutes Importance: 0.0
# Variable: business_duration_1 Hour 18 Minutes Importance: 0.0
# Variable: business_duration_1 Hour 33 Minutes Importance: 0.0
# Variable: business_duration_5 Hours 35 Minutes Importance: 0.0
# Variable: business_duration_1 Hour 19 Minutes Importance: 0.0
# Variable: business_duration_5 Minutes Importance: 0.0
# Variable: business_duration_3 Hours 40 Minutes Importance: 0.0
# Variable: business_duration_2 Hours 7 Minutes Importance: 0.0
# Variable: business_duration_2 Days 16 Hours Importance: 0.0
# Variable: business_duration_4 Hours 3 Minutes Importance: 0.0
# Variable: business_duration_36 Days 8 Hours Importance: 0.0
# Variable: business_duration_17 Minutes Importance: 0.0
# Variable: business_duration_9 Hours 24 Minutes Importance: 0.0
# Variable: business_duration_2 Hours 26 Minutes Importance: 0.0
# Variable: business_duration_2 Days 7 Hours 43 Minutes Importance: 0.0
# Variable: business_duration_39 Days 8 Hours 16 Minutes Importance: 0.0
# Variable: business_duration_1 Day 18 Hours 28 Minutes Importance: 0.0
# Variable: business_duration_3 Days 6 Hours 15 Minutes Importance: 0.0
# Variable: business_duration_33 Days 8 Hours Importance: 0.0
# Variable: business_duration_4 Days Importance: 0.0
# Variable: business_duration_1 Day 5 Hours 16 Minutes Importance: 0.0
# Variable: business_duration_5 Days 19 Hours 2 Minutes Importance: 0.0
# Variable: business_duration_2 Days 1 Hour 32 Minutes Importance: 0.0
# Variable: business_duration_18 Days 19 Hours 26 Minutes Importance: 0.0
# Variable: business_duration_1 Hour 31 Minutes Importance: 0.0
# Variable: business_duration_1 Day 9 Hours 18 Minutes Importance: 0.0
# Variable: business_duration_4 Days 5 Hours 55 Minutes Importance: 0.0
# Variable: business_duration_1 Day 3 Hours 26 Minutes Importance: 0.0
# Variable: business_duration_79 Days Importance: 0.0
# Variable: business_duration_6 Minutes Importance: 0.0
# Variable: business_duration_21 Hours 5 Minutes Importance: 0.0
# Variable: business_duration_1 Hour 2 Minutes Importance: 0.0
# Variable: business_duration_1 Hour 22 Minutes Importance: 0.0
# Variable: business_duration_48 Days 8 Hours 23 Minutes Importance: 0.0
# Variable: business_duration_2 Days 5 Hours 17 Minutes Importance: 0.0
# Variable: business_duration_3 Hours 7 Minutes Importance: 0.0
# Variable: business_duration_1 Minute Importance: 0.0
# Variable: business_duration_11 Days Importance: 0.0
# Variable: business_duration_3 Days 11 Hours 15 Minutes Importance: 0.0
# Variable: business_duration_56 Minutes Importance: 0.0
# Variable: business_duration_3 Days 8 Hours Importance: 0.0
# Variable: business_duration_2 Hours 5 Minutes Importance: 0.0
# Variable: business_duration_2 Hours 22 Minutes Importance: 0.0
# Variable: business_duration_9 Hours 54 Minutes Importance: 0.0
# Variable: business_duration_14 Hours 30 Minutes Importance: 0.0
# Variable: business_duration_1 Hour 13 Minutes Importance: 0.0
# Variable: business_duration_7 Minutes Importance: 0.0
# Variable: business_duration_1 Hour 48 Minutes Importance: 0.0
# Variable: business_duration_7 Days 11 Hours 7 Minutes Importance: 0.0
# Variable: business_duration_39 Minutes Importance: 0.0
# Variable: business_duration_12 Hours 24 Minutes Importance: 0.0
# Variable: business_duration_27 Minutes Importance: 0.0
# Variable: business_duration_28 Minutes Importance: 0.0
# Variable: business_duration_55 Minutes Importance: 0.0
# Variable: business_duration_21 Minutes Importance: 0.0
# Variable: business_duration_2 Days 15 Hours Importance: 0.0
# Variable: business_duration_7 Hours Importance: 0.0
# Variable: service_offering_Computer Hardware Offerings Importance: 0.0
# Variable: service_offering_Email Offerings Importance: 0.0
# Variable: service_offering_Security Offerings Importance: 0.0
# Variable: service_offering_Enterprise Business Application Offerings Importance: 0.0
# Variable: service_offering_Application / System Access Management Offerings Importance: 0.0
# Variable: service_offering_Other Issues or Requests Importance: 0.0
# Variable: service_offering_(Automation Only) Access Authorisation Tool Offerings Importance: 0.0
# Variable: service_offering_Computer Software Offerings Importance: 0.0
# Variable: service_offering_Network, VPN and Wifi Access Offerings Importance: 0.0
# Variable: service_offering_Meetings / Video Conference / Webex Offerings Importance: 0.0
# Variable: service_offering_Phone and Mobile Offerings Importance: 0.0
# Variable: service_offering_Print and Fax Offerings Importance: 0.0
# Variable: service_offering_Backup and Restoration Offerings Importance: 0.0
# Variable: service_offering_IT Service Management Offerings Importance: 0.0
# Variable: u_sla_held           Importance: 0.0
# Variable: reassignment_count   Importance: 0.0
# Variable: assigned_to_Sébastien St-Denis (IBM-BA) Importance: 0.0
# Variable: assigned_to_Reema SHARMA (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Manikandan Sakthivelu (IBM-BT) Importance: 0.0
# Variable: assigned_to_David Ferrante (Innovaway spa-BA) Importance: 0.0
# Variable: assigned_to_Hitesh Patel (IBM-BA) Importance: 0.0
# Variable: assigned_to_Srinivas SAILA (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Pranita Ralla (IBM-BA) Importance: 0.0
# Variable: assigned_to_Kamo St-Dic (IBM-BA) Importance: 0.0
# Variable: assigned_to_External Tool Assignment (IBM-BA) Importance: 0.0
# Variable: assigned_to_Filipe leite REIS (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Sebastian Wagenbreth (NTT-BT) Importance: 0.0
# Variable: assigned_to_Codruta ALEXANDRU (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Varsha Bose (IBM-BA) Importance: 0.0
# Variable: assigned_to_Tushar Tiwari (IBM-BA) Importance: 0.0
# Variable: assigned_to_Rajesh Reddy Santhakudlur (IBM-BT) Importance: 0.0
# Variable: assigned_to_Mark Thompson (NTT-BA) Importance: 0.0
# Variable: assigned_to_Snigdha Verma (IBM-BA) Importance: 0.0
# Variable: assigned_to_Bankova ATANASKA (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Deepak Rana (IBM-BA) Importance: 0.0
# Variable: assigned_to_Christopher O'Neill (IBM-BA) Importance: 0.0
# Variable: assigned_to_Teodora Paula Ciulu (IBM-BT) Importance: 0.0
# Variable: assigned_to_Naresh Rajoju (IBM-BA) Importance: 0.0
# Variable: assigned_to_Milosz KOWALSKI (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Ilaria Rossi (Innovaway spa-BA) Importance: 0.0
# Variable: assigned_to_Botev PLAMEN (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Grishma RAJ (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Richa Satsangi (IBM-BA) Importance: 0.0
# Variable: assigned_to_Kashyap Mishra (IBM-BA) Importance: 0.0
# Variable: assigned_to_Claude Dekany (IBM-BA) Importance: 0.0
# Variable: assigned_to_Puran Dudhane (IBM-BA) Importance: 0.0
# Variable: assigned_to_Rishi DIWAN (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Krzysztof OGRODNIK (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Joseph McDonough (IBM-BA) Importance: 0.0
# Variable: assigned_to_Damodharan M (IBM-BT) Importance: 0.0
# Variable: assigned_to_Harish Chikkamuniswamappa (IBM-BA) Importance: 0.0
# Variable: assigned_to_Abhishek Reddy Gangireddy (IBM-BT) Importance: 0.0
# Variable: assigned_to_Wing Hong Yau (IBM-BA) Importance: 0.0
# Variable: assigned_to_Sreekala KC (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Ankit JAIN (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Nagaraju Pitla (IBM-BA) Importance: 0.0
# Variable: assigned_to_Sumit Nautiyal (IBM-BA) Importance: 0.0
# Variable: assigned_to_Tushar TIWARI (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Mahesh Gopal (IBM-BA) Importance: 0.0
# Variable: assigned_to_Brian Speas (IBM-BA) Importance: 0.0
# Variable: assigned_to_Ciprian BOGOIU (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Tomasz MARCINISZYN (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Mahanthesh PATIL (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Neetu SINGH (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Shagun Yadav (IBM-BA) Importance: 0.0
# Variable: assigned_to_Debjit Bhowmick (IBM-BA) Importance: 0.0
# Variable: assigned_to_Alexander Crigler (IBM-BA) Importance: 0.0
# Variable: assigned_to_Abhishek Kumar (IBM-BA) Importance: 0.0
# Variable: assigned_to_Armando Chioccarelli (IBM-BA) Importance: 0.0
# Variable: assigned_to_Akash Sharma (TCS-BT) Importance: 0.0
# Variable: assigned_to_Nandan Devadas Jois (IBM-BA) Importance: 0.0
# Variable: assigned_to_Anil Kumar (IBM-BA) Importance: 0.0
# Variable: assigned_to_Yathish K S (IBM-BT) Importance: 0.0
# Variable: assigned_to_Ernest DUDA (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Irina Talpan (IBM-BT) Importance: 0.0
# Variable: assigned_to_Mihai COSTIN (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Vincenzo Pettograsso (Innovaway spa-BA) Importance: 0.0
# Variable: assigned_to_Umberto Vigliano (IBM-BT) Importance: 0.0
# Variable: assigned_to_Priya DODEJA (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Amala Shruti Joseph (IBM-BT) Importance: 0.0
# Variable: assigned_to_Ravi Gaureddy (IBM-BA) Importance: 0.0
# Variable: assigned_to_Pratap M Phani (IBM-BA) Importance: 0.0
# Variable: assigned_to_James Huggins (Bombardier - Aerospace) Importance: 0.0
# Variable: assigned_to_Mahesh Singamsetty (IBM-BT) Importance: 0.0
# Variable: assigned_to_Gurpreet Singh2 (NTT-BT) Importance: 0.0
# Variable: assigned_to_Nithyananda J S (IBM-BT) Importance: 0.0
# Variable: assigned_to_Frank WEILAND (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Melodie Boudreau (Bombardier - Aerospace) Importance: 0.0
# Variable: assigned_to_Non_Assigned Importance: 0.0
# Variable: assigned_to_Przemysław GRZYBOWSKI (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Bhimesh M (IBM-BT) Importance: 0.0
# Variable: assigned_to_Armando CHIOCCARELLI (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Hareesh Yerrajennu (IBM-BA) Importance: 0.0
# Variable: assigned_to_Tomasz Marciniszyn (IBM-BA) Importance: 0.0
# Variable: assigned_to_Lucia Cinzia Massimo (Innovaway spa-BA) Importance: 0.0
# Variable: assigned_to_Rituparna Mitra (IBM-BA) Importance: 0.0
# Variable: assigned_to_Lukasz ANDRASIAK (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Waleed Abou Waleed Abou (IBM-BT) Importance: 0.0
# Variable: assigned_to_Prashanth Gudipati (IBM-BA) Importance: 0.0
# Variable: assigned_to_Praful Raikar (IBM-BA) Importance: 0.0
# Variable: assigned_to_Rupal Raj (IBM-BA) Importance: 0.0
# Variable: assigned_to_Praween POOMIEIAM (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Lalit Raina (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Deepika Choubey (IBM-BA) Importance: 0.0
# Variable: assigned_to_Sangeetha N (IBM-BT) Importance: 0.0
# Variable: assigned_to_Egavinti SHRAVAN KUMAR (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Dharmarajan Sundaresan (IBM-BA) Importance: 0.0
# Variable: assigned_to_Vanshika MADHOK (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Divya Bakshi (IBM-BA) Importance: 0.0
# Variable: assigned_to_Alan Miller (Bombardier - Aerospace) Importance: 0.0
# Variable: assigned_to_Venkata Satya Krishna Prasad Eranki (IBM-BA) Importance: 0.0
# Variable: assigned_to_Heloisa Gobi (IBM-BT) Importance: 0.0
# Variable: assigned_to_Filip TSEDRYK (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Eleonora Gambardella (Innovaway spa-BA) Importance: 0.0
# Variable: assigned_to_Mansi Srivastav (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Isaac ZONUNMAWIA (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Ajit ANTO (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Mounica Yallapragada (IBM-BA) Importance: 0.0
# Variable: assigned_to_Arun Prasad (IBM-BA) Importance: 0.0
# Variable: assigned_to_Padmashree Patil (IBM-BA) Importance: 0.0
# Variable: assigned_to_Anju PRABHAKARAN (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Alexandra BALBAE (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Dipankar SOME (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Syed Ziauddin (IBM-BA) Importance: 0.0
# Variable: assigned_to_Mohammed Basha (IBM-BA) Importance: 0.0
# Variable: assigned_to_Ritu Raj (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Indira Sahai (IBM-BA) Importance: 0.0
# Variable: assigned_to_Giuseppe DI MATTEO (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Pani PDP (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Milosz Kowalski (IBM-BA) Importance: 0.0
# Variable: assigned_to_Avinash Kumar Thakur (IBM-BA) Importance: 0.0
# Variable: assigned_to_Ilaria Pareti (Innovaway spa-BA) Importance: 0.0
# Variable: assigned_to_Filip MALISZAK (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Haridoss Sithambaram (IBM-BA) Importance: 0.0
# Variable: assigned_to_Krishna Petkar (IBM-BA) Importance: 0.0
# Variable: assigned_to_Jürgen TEMPEL (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Vikas Mehta (Bombardier - Aerospace) Importance: 0.0
# Variable: assigned_to_Muntaz BEGUM (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Arunima SRIVASTAVA (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Maratilov DRAGOMIR (Bombardier - Transportation) Importance: 0.0
# Variable: assigned_to_Giulia Rinaldi (IBM-BT) Importance: 0.0
# Variable: assigned_to_Gurdeep BANVAIT (Bombardier - Transportation) Importance: 0.0
# Variable: u_mio_invoked        Importance: 0.0
# Variable: u_escalation_level_2 Importance: 0.0
# Variable: made_sla             Importance: 0.0
# Variable: u_escalation_level_1 Importance: 0.0
# Variable: u_location_details_9th floor CA Importance: 0.0
# Variable: u_location_details_Derby Importance: 0.0
# Variable: u_location_details_182 - Siegen Importance: 0.0
# Variable: u_location_details_- Importance: 0.0
# Variable: u_location_details_506 - Dorval Administrative Centre (CA) Importance: 0.0
# Variable: u_location_details_CA Dorval Importance: 0.0
# Variable: u_location_details_CA, 8th floor Importance: 0.0
# Variable: u_location_details_remote Importance: 0.0
# Variable: u_location_details_Hortolândia/SP Importance: 0.0
# Variable: u_location_details_5th floor Importance: 0.0
# Variable: u_location_details_241 - Cebu Importance: 0.0
# Variable: u_location_details_551 - Casablanca Aeropole Importance: 0.0
# Variable: u_location_details_Home Office Importance: 0.0
# Variable: u_location_details_BT Importance: 0.0
# Variable: u_location_details_Bay 9, 2nd floor Importance: 0.0
# Variable: u_location_details_514 - Toronto De Havilland Inc. Importance: 0.0
# Variable: u_location_details_154 - Zurich Oerlikon Toro 1 Importance: 0.0
# Variable: u_location_details_Old oak common depot NW10 6DW LONDON Importance: 0.0
# Variable: u_location_details_Montreal Importance: 0.0
# Variable: u_location_details_9th floor Importance: 0.0
# Variable: u_location_details_Paris Importance: 0.0
# Variable: u_location_details_toronto  Importance: 0.0
# Variable: u_location_details_Toronto Importance: 0.0
# Variable: u_location_details_Bangalore Importance: 0.0
# Variable: u_location_details_WFH Importance: 0.0
# Variable: u_location_details_187 - Hennigsdorf Importance: 0.0
# Variable: u_location_details_Working from home Importance: 0.0
# Variable: u_location_details_Hennigsdorf Importance: 0.0
# Variable: u_location_details_from home Importance: 0.0
# Variable: u_location_details_4th floor Importance: 0.0
# Variable: u_location_details_1 Importance: 0.0
# Variable: u_location_details_Brasov Importance: 0.0
# Variable: u_location_details_mtl Importance: 0.0
# Variable: u_location_details_M43 R120 Importance: 0.0
# Variable: u_location_details_250 - Kuala Lumpur Importance: 0.0
# Variable: u_location_details_6G Importance: 0.0
# Variable: u_location_details_Cebu Philippines Importance: 0.0
# Variable: u_location_details_CA Importance: 0.0
# Variable: u_location_details_8th Floor Importance: 0.0
# Variable: u_location_details_520 - Wichita Learjet Importance: 0.0
# Variable: u_location_details_cairo Importance: 0.0
# Variable: u_location_details_N329-196-3e Importance: 0.0
# Variable: u_location_details_Admin Office Importance: 0.0
# Variable: u_location_details_working from home Importance: 0.0
# Variable: u_location_details_508 - Mirabel Manufacturing Importance: 0.0
# Variable: u_location_details_Plattsburgh Importance: 0.0
# Variable: u_location_details_9TH FLOOR CA Importance: 0.0
# Variable: u_location_details_Work From Home Importance: 0.0
# Variable: u_location_details_6th floor Importance: 0.0
# Variable: u_location_details_1-1079, cube 56 Importance: 0.0
# Variable: u_location_details_29e étage Importance: 0.0
# Variable: u_location_details_4B Importance: 0.0
# Variable: u_location_details_426 - Berlin New HQ Importance: 0.0
# Variable: u_location_details_Dandenong Importance: 0.0
# Variable: u_location_details_CA, 2nd floor, J9 23 02 Importance: 0.0
# Variable: u_location_details_Building 6G, 2nd floor Importance: 0.0
# Variable: u_location_details_Tucson Facility Importance: 0.0
# Variable: u_location_details_121 - Welby Asfordby Importance: 0.0
# Variable: u_location_details_Bombardier Aerospace Importance: 0.0
# Variable: u_location_details_Office. Importance: 0.0
# Variable: u_location_details_Exec Offices - top floor K Shop Main office block Importance: 0.0
# Variable: u_location_details_Vienna Importance: 0.0
# Variable: u_location_details_516 - Dorval Completion Centre Importance: 0.0
# Variable: u_location_details_Zurich Importance: 0.0
# Variable: u_location_details_Currently WFH Importance: 0.0
# Variable: u_location_details_200 Cote-Vertu Ouest, 3rd floor, Customer Response Center Importance: 0.0
# Variable: u_location_details_521 - Fort Lauderdale Importance: 0.0
# Variable: u_location_details_CA - 9th Floor Importance: 0.0
# Variable: u_location_details_Katrin Luger Importance: 0.0
# Variable: u_location_details_Gurgaon Importance: 0.0
# Variable: u_location_details_India Importance: 0.0
# Variable: u_location_details_Office Importance: 0.0
# Variable: u_location_details_L442 Importance: 0.0
# Variable: u_location_details_CA 7th floor E3-57-07 Importance: 0.0
# Variable: u_location_details_presidents office Importance: 0.0
# Variable: u_location_details_Bangkok sites Importance: 0.0
# Variable: u_location_details_3rd Floor Importance: 0.0
# Variable: u_location_details_Kolkata, India Importance: 0.0
# Variable: u_location_details_BA Importance: 0.0
# Variable: u_location_details_106 Gold Room  Importance: 0.0
# Variable: u_location_details_bt Importance: 0.0
# Variable: u_location_details_Berlin, HQ Importance: 0.0
# Variable: u_location_details_6G-2604 Importance: 0.0
# Variable: u_location_details_Dorval - CA Importance: 0.0
# Variable: u_location_details_236 - Bangkok Klongtoey Importance: 0.0
# Variable: u_location_details_147 - Derby Litchurch Lane Importance: 0.0
# Variable: u_location_details_7th floor - C side office F2-72-07 Importance: 0.0
# Variable: u_location_details_3B-022 Importance: 0.0
# Variable: u_location_details_INDIA  Importance: 0.0
# Variable: u_location_details_94 - St-Bruno Importance: 0.0
# Variable: u_location_details_Am Rathenaupark 1, @home Importance: 0.0
# Variable: u_location_details_Dallas sales Importance: 0.0
# Variable: u_location_details_Remote Importance: 0.0
# Variable: u_location_details_Gurugram Importance: 0.0
# Variable: u_location_details_crespin Importance: 0.0
# Variable: u_location_details_Working From home Importance: 0.0
# Variable: u_location_details_Service Desk Italy Turin -  Quality Team Importance: 0.0
# Variable: u_location_details_home office; Berlin HQ - 5th floor Importance: 0.0
# Variable: u_location_details_dorval Importance: 0.0
# Variable: u_location_details_189 - Hyderabad Engineering Center Importance: 0.0
# Variable: u_location_details_559 - Montreal Head Office Importance: 0.0
# Variable: u_location_details_Berlin  Importance: 0.0
# Variable: u_location_details_Client Section - Near Showroom Importance: 0.0
# Variable: u_location_details_Garches Importance: 0.0
# Variable: u_location_details_199 - Gurgaon (RCS & IS Hub) Importance: 0.0
# Variable: u_location_details_Eichhornstrasse 3, (4th and 5th floor) Importance: 0.0
# Variable: u_location_details_Mirabel Importance: 0.0
# Variable: u_location_details_banglore Importance: 0.0
# Variable: u_location_details_OPTO : 1st Floor Importance: 0.0
# Variable: u_location_details_Uk/ United Kingdome Importance: 0.0
# Variable: u_location_details_DERBY Importance: 0.0
# Variable: u_location_details_28e étage Importance: 0.0
# Variable: u_location_details_92 - Thunder Bay Importance: 0.0
# Variable: u_location_details_Next to Showroom - Client Section Importance: 0.0
# Variable: u_location_details_29 Importance: 0.0
# Variable: u_location_details_3 ieme étage Bureau N329-204-3E Importance: 0.0
# Variable: u_location_details_9TH FLOOR Importance: 0.0
# Variable: u_location_details_E6-58-04 Importance: 0.0
# Variable: u_location_details_Canada Importance: 0.0
# Variable: u_location_details_Mannheim Importance: 0.0
# Variable: u_location_details_426 Importance: 0.0
# Variable: u_location_details_185 Importance: 0.0
# Variable: u_location_details_Queens island Importance: 0.0
# Variable: u_location_details_Client Side - 4th Floor Importance: 0.0
# Variable: u_location_details_Bruges, Belgium Importance: 0.0
# Variable: u_location_details_521_Gold_Room_106 - Completion Center - Room 106 - Conference Importance: 0.0
# Variable: u_location_details_Derby, UK Importance: 0.0
# Variable: u_location_details_brasov Importance: 0.0
# Variable: u_location_details_Frankfurt Site Importance: 0.0
# Variable: u_location_details_Bautzen Importance: 0.0
# Variable: u_location_details_Organisation Materielle Importance: 0.0
# Variable: u_location_details_510 - Saint-Laurent BAN 2 Importance: 0.0
# Variable: child_incidents      Importance: 0.0
# Variable: resolved_by_Sébastien St-Denis (IBM-BA) Importance: 0.0
# Variable: resolved_by_Reema SHARMA (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Manikandan Sakthivelu (IBM-BT) Importance: 0.0
# Variable: resolved_by_David Ferrante (Innovaway spa-BA) Importance: 0.0
# Variable: resolved_by_Hitesh Patel (IBM-BA) Importance: 0.0
# Variable: resolved_by_SivaleelaKumari Katta (IBM-BT) Importance: 0.0
# Variable: resolved_by_Pranita Ralla (IBM-BA) Importance: 0.0
# Variable: resolved_by_Kamo St-Dic (IBM-BA) Importance: 0.0
# Variable: resolved_by_Bhavani Elangovan (IBM-BA) Importance: 0.0
# Variable: resolved_by_Filipe leite REIS (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Sebastian Wagenbreth (NTT-BT) Importance: 0.0
# Variable: resolved_by_Mayur PALHERKAR (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Varsha Bose (IBM-BA) Importance: 0.0
# Variable: resolved_by_Anusha SUNKARA (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Nithyananda J S (IBM-BT) Importance: 0.0
# Variable: resolved_by_Mark Thompson (NTT-BA) Importance: 0.0
# Variable: resolved_by_Snigdha Verma (IBM-BA) Importance: 0.0
# Variable: resolved_by_Bankova ATANASKA (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Deepak Rana (IBM-BA) Importance: 0.0
# Variable: resolved_by_Christopher O'Neill (IBM-BA) Importance: 0.0
# Variable: resolved_by_Teodora Paula Ciulu (IBM-BT) Importance: 0.0
# Variable: resolved_by_Naresh Rajoju (IBM-BA) Importance: 0.0
# Variable: resolved_by_Srinivas SAILA (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Milosz KOWALSKI (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Ilaria Rossi (Innovaway spa-BA) Importance: 0.0
# Variable: resolved_by_Botev PLAMEN (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Grishma RAJ (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Richa Satsangi (IBM-BA) Importance: 0.0
# Variable: resolved_by_Eleonora Gambardella (Innovaway spa-BA) Importance: 0.0
# Variable: resolved_by_Claude Dekany (IBM-BA) Importance: 0.0
# Variable: resolved_by_Puran Dudhane (IBM-BA) Importance: 0.0
# Variable: resolved_by_Rajesh Reddy Santhakudlur (IBM-BT) Importance: 0.0
# Variable: resolved_by_Rishi DIWAN (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Krzysztof OGRODNIK (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Joseph McDonough (IBM-BA) Importance: 0.0
# Variable: resolved_by_Shilpashree B S (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Harish Chikkamuniswamappa (IBM-BA) Importance: 0.0
# Variable: resolved_by_Abhishek Reddy Gangireddy (IBM-BT) Importance: 0.0
# Variable: resolved_by_Wing Hong Yau (IBM-BA) Importance: 0.0
# Variable: resolved_by_Nikhil TALWAR (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Anshika Dixit1 (TCS-BT) Importance: 0.0
# Variable: resolved_by_Nagaraju Pitla (IBM-BA) Importance: 0.0
# Variable: resolved_by_Sumit Nautiyal (IBM-BA) Importance: 0.0
# Variable: resolved_by_Ninad KSHIRSAGAR (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Brian Speas (IBM-BA) Importance: 0.0
# Variable: resolved_by_Ciprian BOGOIU (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Tomasz MARCINISZYN (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Mahanthesh PATIL (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Neetu SINGH (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Shagun Yadav (IBM-BA) Importance: 0.0
# Variable: resolved_by_Debjit Bhowmick (IBM-BA) Importance: 0.0
# Variable: resolved_by_Alexander Crigler (IBM-BA) Importance: 0.0
# Variable: resolved_by_Abhishek Kumar (IBM-BA) Importance: 0.0
# Variable: resolved_by_Armando Chioccarelli (IBM-BA) Importance: 0.0
# Variable: resolved_by_Geetika Saxena (TCS-BT) Importance: 0.0
# Variable: resolved_by_Nandan Devadas Jois (IBM-BA) Importance: 0.0
# Variable: resolved_by_Anil Kumar (IBM-BA) Importance: 0.0
# Variable: resolved_by_Sunil Kumar Thulasiramkrishnamurthy (IBM-BT) Importance: 0.0
# Variable: resolved_by_Ernest DUDA (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Irina Talpan (IBM-BT) Importance: 0.0
# Variable: resolved_by_Mihai COSTIN (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Luisa Ratti (Innovaway spa-BA) Importance: 0.0
# Variable: resolved_by_Umberto Vigliano (IBM-BT) Importance: 0.0
# Variable: resolved_by_Priya DODEJA (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Amala Shruti Joseph (IBM-BT) Importance: 0.0
# Variable: resolved_by_Ravi Gaureddy (IBM-BA) Importance: 0.0
# Variable: resolved_by_Kashyap Mishra (IBM-BA) Importance: 0.0
# Variable: resolved_by_Pratap M Phani (IBM-BA) Importance: 0.0
# Variable: resolved_by_James Huggins (Bombardier - Aerospace) Importance: 0.0
# Variable: resolved_by_Mahesh Singamsetty (IBM-BT) Importance: 0.0
# Variable: resolved_by_Mohit Sharma (NTT-BT) Importance: 0.0
# Variable: resolved_by_Frank WEILAND (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Melodie Boudreau (Bombardier - Aerospace) Importance: 0.0
# Variable: resolved_by_Automated ID for AT&T IPcenter - Aero (AT&T-BA) Importance: 0.0
# Variable: resolved_by_Przemysław GRZYBOWSKI (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Bhimesh M (IBM-BT) Importance: 0.0
# Variable: resolved_by_Armando CHIOCCARELLI (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Hareesh Yerrajennu (IBM-BA) Importance: 0.0
# Variable: resolved_by_Tomasz Marciniszyn (IBM-BA) Importance: 0.0
# Variable: resolved_by_Lucia Cinzia Massimo (Innovaway spa-BA) Importance: 0.0
# Variable: resolved_by_Rituparna Mitra (IBM-BA) Importance: 0.0
# Variable: resolved_by_Lukasz ANDRASIAK (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Yara MOHAMED (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Ahmed Abulibdeh (IBM-BA) Importance: 0.0
# Variable: resolved_by_Janardhan Kommineni (IBM-BA) Importance: 0.0
# Variable: resolved_by_Praful Raikar (IBM-BA) Importance: 0.0
# Variable: resolved_by_Rupal Raj (IBM-BA) Importance: 0.0
# Variable: resolved_by_Praween POOMIEIAM (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Lalit Raina (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Deepika Choubey (IBM-BA) Importance: 0.0
# Variable: resolved_by_Egavinti SHRAVAN KUMAR (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Dharmarajan Sundaresan (IBM-BA) Importance: 0.0
# Variable: resolved_by_Vanshika MADHOK (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Divya Bakshi (IBM-BA) Importance: 0.0
# Variable: resolved_by_Alan Miller (Bombardier - Aerospace) Importance: 0.0
# Variable: resolved_by_Yasir H Khan (IBM-BT) Importance: 0.0
# Variable: resolved_by_Sanket SHANKAR (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Tejaswini Lakshminarayana (IBM-BA) Importance: 0.0
# Variable: resolved_by_Heloisa Gobi (IBM-BT) Importance: 0.0
# Variable: resolved_by_Andrew FLETT (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Sumana R (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Mansi Srivastav (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Isaac ZONUNMAWIA (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Ajit ANTO (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Mounica Yallapragada (IBM-BA) Importance: 0.0
# Variable: resolved_by_Ramakrishna Chirumalla (IBM-BA) Importance: 0.0
# Variable: resolved_by_Prashanth Gudipati (IBM-BA) Importance: 0.0
# Variable: resolved_by_Padmashree Patil (IBM-BA) Importance: 0.0
# Variable: resolved_by_Automated ID for Dimension Data (IBM-BA) Importance: 0.0
# Variable: resolved_by_Anju PRABHAKARAN (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Alexandra BALBAE (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Dipankar SOME (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Syed Ziauddin (IBM-BA) Importance: 0.0
# Variable: resolved_by_Mohammed Basha (IBM-BA) Importance: 0.0
# Variable: resolved_by_Ritu Raj (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Indira Sahai (IBM-BA) Importance: 0.0
# Variable: resolved_by_Giuseppe DI MATTEO (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Prince KUMAR (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Milosz Kowalski (IBM-BA) Importance: 0.0
# Variable: resolved_by_Avinash Kumar Thakur (IBM-BA) Importance: 0.0
# Variable: resolved_by_Ilaria Pareti (Innovaway spa-BA) Importance: 0.0
# Variable: resolved_by_Filip MALISZAK (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Haridoss Sithambaram (IBM-BA) Importance: 0.0
# Variable: resolved_by_Codruta ALEXANDRU (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Krishna Petkar (IBM-BA) Importance: 0.0
# Variable: resolved_by_Jürgen TEMPEL (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Muntaz BEGUM (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Arunima SRIVASTAVA (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Maratilov DRAGOMIR (Bombardier - Transportation) Importance: 0.0
# Variable: resolved_by_Giulia Rinaldi (IBM-BT) Importance: 0.0
# Variable: resolved_by_Gurdeep BANVAIT (Bombardier - Transportation) Importance: 0.0
# Variable: calendar_stc         Importance: 0.0
# Variable: business_service_Computer Hardware Importance: 0.0
# Variable: business_service_Email and Calendar Importance: 0.0
# Variable: business_service_Security Importance: 0.0
# Variable: business_service_Enterprise Business Applications Importance: 0.0
# Variable: business_service_Application / System Access Management Importance: 0.0
# Variable: business_service_Computer Software Importance: 0.0
# Variable: business_service_Internet and Network Importance: 0.0
# Variable: business_service_Meetings / Video Conferencing / Webex Importance: 0.0
# Variable: business_service_Phone and Mobile Importance: 0.0
# Variable: business_service_Printing and Fax Services Importance: 0.0
# Variable: business_service_Backup and Restoration Importance: 0.0
# Variable: business_service_MTLCICON701 Importance: 0.0
# Variable: business_service_IT Service Management Importance: 0.0
# Variable: subcategory_Laptop - Issue / Error Importance: 0.0
# Variable: subcategory_Email - Issue / Error Importance: 0.0
# Variable: subcategory_Certificates/Encryption Importance: 0.0
# Variable: subcategory_General Application Support Issue / Error Importance: 0.0
# Variable: subcategory_Login / Password - Issue / Error Importance: 0.0
# Variable: subcategory_No Category Importance: 0.0
# Variable: subcategory_General Software - Issue / Error Importance: 0.0
# Variable: subcategory_Shared Folder / Network Drive - Issue / Error Importance: 0.0
# Variable: subcategory_Wireless Importance: 0.0
# Variable: subcategory_Application - Issue / Error Importance: 0.0
# Variable: subcategory_Application - All Other Issues Importance: 0.0
# Variable: subcategory_Meeting Room - Issue / Error Importance: 0.0
# Variable: subcategory_Active Directory - Password Reset Importance: 0.0
# Variable: subcategory_Login Issue  - User Access Importance: 0.0
# Variable: subcategory_Data Issue - Data Issue / Error Importance: 0.0
# Variable: subcategory_Workstation - Other Issue / Error Importance: 0.0
# Variable: subcategory_Desk / Conference Phone - Issue / Error Importance: 0.0
# Variable: subcategory_Availability - Application Not Available Importance: 0.0
# Variable: subcategory_Sharepoint - Issue / Error Importance: 0.0
# Variable: subcategory_iPhone - Issue / Error Importance: 0.0
# Variable: subcategory_VPN / 2FA - Issue / Error Importance: 0.0
# Variable: subcategory_Video Conferencing - Issue / Error Importance: 0.0
# Variable: subcategory_Network Security - Issue / Error Importance: 0.0
# Variable: subcategory_General Printer - Issue / Error Importance: 0.0
# Variable: subcategory_Monitor - Issue / Error Importance: 0.0
# Variable: subcategory_Web Browser / Internet - Issue / Error Importance: 0.0
# Variable: subcategory_Network Data - Issue / Error Importance: 0.0
# Variable: subcategory_Docking Station - Issue / Error Importance: 0.0
# Variable: subcategory_Interface Issues - Fix Interface Importance: 0.0
# Variable: subcategory_Network Printer - Error Importance: 0.0
# Variable: subcategory_Laptop - Performance Importance: 0.0
# Variable: subcategory_Desktop - Performance Importance: 0.0
# Variable: subcategory_Mobile e-Mail Client Assistance Importance: 0.0
# Variable: subcategory_Network Other - Issue / Error Importance: 0.0
# Variable: subcategory_Other General - Issue / Error Importance: 0.0
# Variable: subcategory_Performance - Application Slow Down Importance: 0.0
# Variable: subcategory_Availability - Application Outage Importance: 0.0
# Variable: subcategory_Desktop - Issue / Error Importance: 0.0
# Variable: subcategory_Application Installation - Issue / Error Importance: 0.0
# Variable: subcategory_Lan Cable - Issue / Error Importance: 0.0
# Variable: subcategory_Browser Chrome - Configuration Issue / Error Importance: 0.0
# Variable: subcategory_Active Directory - Account Locked Importance: 0.0
# Variable: subcategory_Voice - Issue / Error Importance: 0.0
# Variable: subcategory_Netcool Event Importance: 0.0
# Variable: subcategory_Intercall - Issue / Error Importance: 0.0
# Variable: subcategory_Browser Internet Explorer - Configuration Issue / Error Importance: 0.0
# Variable: subcategory_Job Failures - Web Transaction Issues Importance: 0.0
# Variable: u_vip_gold_room_service Importance: 0.0
# Variable: close_code_Solved (Permanently) Importance: 0.0
# Variable: close_code_Resolved (Under Monitoring) Importance: 0.0
# Variable: close_code_Closed/Resolved by Caller Importance: 0.0
# Variable: close_code_Solved (Work Around) Importance: 0.0
# Variable: close_code_Not an Incident Importance: 0.0
# Variable: assignment_group_IBM-DS-Platinum Support-CA-AERO Importance: 0.0
# Variable: assignment_group_IBM-SD-India SD Self Service-Rail Importance: 0.0
# Variable: assignment_group_IBM-AS-Malware Endpoints-Rail Importance: 0.0
# Variable: assignment_group_IBM-SD-French-Aero Importance: 0.0
# Variable: assignment_group_IBM-DS-Gold-Silver Support-CA-AERO Importance: 0.0
# Variable: assignment_group_IBM-AP-Unix-Rail Importance: 0.0
# Variable: assignment_group_IBM-SI-Asset Analyst Importance: 0.0
# Variable: assignment_group_VEN-DD-Dimension Data - Integration Importance: 0.0
# Variable: assignment_group_BT-IBM-APPR-SAP-Mastersaf_DW_NotaFiscal-Rail Importance: 0.0
# Variable: assignment_group_VEN-HEM-Staffed-Berlin-DE-RAIL Importance: 0.0
# Variable: assignment_group_IBM-AP-COTS-Finance  Others Apps-Rail Importance: 0.0
# Variable: assignment_group_IBM-SD-IN Importance: 0.0
# Variable: assignment_group_BT-IBM-SI-MIO-Dispute Resolution-Rail Importance: 0.0
# Variable: assignment_group_IBM-AP-Windows & VM-Rail Importance: 0.0
# Variable: assignment_group_IBM-DS-Downsview-CA-AERO Importance: 0.0
# Variable: assignment_group_IBM-SD-Italy Turin SD L1-Rail Importance: 0.0
# Variable: assignment_group_BA-IBM-DL-IMI-IN-Unix-Aero Importance: 0.0
# ...
# Variable: calendar_duration_5 Days 3 Hours 26 Minutes Importance: 0.0
# Variable: calendar_duration_330 Days 22 Hours 32 Minutes Importance: 0.0
# Variable: calendar_duration_4 Days 21 Hours 5 Minutes Importance: 0.0
# Variable: calendar_duration_2 Hours 13 Minutes Importance: 0.0
# Variable: calendar_duration_1 Hour 44 Minutes Importance: 0.0
# Variable: calendar_duration_203 Days 6 Hours 52 Minutes Importance: 0.0
# Variable: calendar_duration_8 Days 21 Hours 17 Minutes Importance: 0.0
# Variable: calendar_duration_1 Day 23 Hours 14 Minutes Importance: 0.0
# Variable: calendar_duration_1 Hour 1 Minute Importance: 0.0
# Variable: calendar_duration_11 Days 2 Hours 29 Minutes Importance: 0.0
# Variable: calendar_duration_22 Hours 2 Minutes Importance: 0.0
# Variable: calendar_duration_3 Hours 7 Minutes Importance: 0.0
# Variable: calendar_duration_5 Hours 22 Minutes Importance: 0.0
# Variable: calendar_duration_46 Days 22 Hours 46 Minutes Importance: 0.0
# Variable: calendar_duration_6 Days 18 Hours 31 Minutes Importance: 0.0
# Variable: calendar_duration_10 Days 5 Hours 58 Minutes Importance: 0.0
# Variable: calendar_duration_52 Minutes Importance: 0.0
# Variable: calendar_duration_14 Days 6 Hours 6 Minutes Importance: 0.0
# Variable: calendar_duration_13 Hours 51 Minutes Importance: 0.0
# Variable: calendar_duration_1 Day 48 Minutes Importance: 0.0
# Variable: calendar_duration_3 Hours 50 Minutes Importance: 0.0
# Variable: calendar_duration_3 Hours 23 Minutes Importance: 0.0
# Variable: calendar_duration_59 Minutes Importance: 0.0
# Variable: calendar_duration_14 Days 2 Hours 32 Minutes Importance: 0.0
# Variable: calendar_duration_2 Hours 21 Minutes Importance: 0.0
# Variable: calendar_duration_1 Day 6 Hours 8 Minutes Importance: 0.0
# Variable: calendar_duration_7 Hours 18 Minutes Importance: 0.0
# Variable: calendar_duration_2 Hours 22 Minutes Importance: 0.0
# Variable: calendar_duration_1 Day 1 Hour 54 Minutes Importance: 0.0
# Variable: calendar_duration_3 Hours 20 Minutes Importance: 0.0
# Variable: calendar_duration_1 Day 21 Hours Importance: 0.0
# Variable: calendar_duration_1 Day 12 Minutes Importance: 0.0
# Variable: calendar_duration_1 Hour 13 Minutes Importance: 0.0
# Variable: calendar_duration_1 Day 5 Hours 50 Minutes Importance: 0.0
# Variable: calendar_duration_1 Hour 6 Minutes Importance: 0.0
# Variable: calendar_duration_53 Minutes Importance: 0.0
# Variable: calendar_duration_1 Hour 30 Minutes Importance: 0.0
# Variable: calendar_duration_12 Days 30 Minutes Importance: 0.0
# Variable: calendar_duration_1 Day 3 Hours 38 Minutes Importance: 0.0
# Variable: calendar_duration_17 Hours 35 Minutes Importance: 0.0
# Variable: calendar_duration_3 Hours 38 Minutes Importance: 0.0
# Variable: calendar_duration_6 Hours 8 Minutes Importance: 0.0
# Variable: calendar_duration_2 Hours 24 Minutes Importance: 0.0
# Variable: calendar_duration_30 Days 4 Hours 59 Minutes Importance: 0.0
# Variable: calendar_duration_5 Days 21 Hours 48 Minutes Importance: 0.0
# Variable: calendar_duration_39 Minutes Importance: 0.0
# Variable: calendar_duration_1 Day 10 Hours 1 Minute Importance: 0.0
# Variable: calendar_duration_27 Minutes Importance: 0.0
# Variable: calendar_duration_6 Hours 13 Minutes Importance: 0.0
# Variable: calendar_duration_28 Days 43 Minutes Importance: 0.0
# Variable: calendar_duration_5 Hours 1 Minute Importance: 0.0
# Variable: calendar_duration_38 Minutes Importance: 0.0
# Variable: calendar_duration_6 Hours 31 Minutes Importance: 0.0
# Variable: calendar_duration_21 Minutes Importance: 0.0
# Variable: calendar_duration_9 Days 22 Hours 25 Minutes Importance: 0.0
# Variable: calendar_duration_1 Day 3 Hours 15 Minutes Importance: 0.0
# Variable: calendar_duration_2 Days 22 Hours 58 Minutes Importance: 0.0
# Variable: calendar_duration_20 Hours 47 Minutes Importance: 0.0
# Variable: calendar_duration_6 Days 5 Hours 14 Minutes Importance: 0.0
# Variable: calendar_duration_1 Hour 37 Minutes Importance: 0.0
# Variable: calendar_duration_2 Hours 17 Minutes Importance: 0.0
# Variable: contact_type_Self-service Importance: 0.0
# Variable: contact_type_IT Support Importance: 0.0
# Variable: contact_type_Phone   Importance: 0.0
# Variable: contact_type_Chat    Importance: 0.0
# Variable: u_qs_rca_required    Importance: 0.0
# Variable: urgency_1 - Critical Importance: 0.0
# Variable: urgency_2 - High     Importance: 0.0
# Variable: u_preferred_language_English Importance: 0.0
# Variable: u_preferred_language_French Canadian Importance: 0.0
# Variable: u_preferred_language_Portuguese Importance: 0.0
# Variable: u_preferred_language_German Importance: 0.0
# Variable: u_preferred_language_Dutch Importance: 0.0
# Variable: u_preferred_language_Thai Importance: 0.0
# Variable: company_Unknown      Importance: 0.0
# Variable: company_Bombardier - Aerospace Importance: 0.0
# Variable: company_Bombardier - Transportation Importance: 0.0
# Variable: u_callback_netcool   Importance: 0.0
# Variable: u_qs_times_reopened  Importance: 0.0
# Variable: u_cause_Access       Importance: 0.0
# Variable: u_cause_AntiVirus    Importance: 0.0
# Variable: u_cause_Knowledge/training related Importance: 0.0
# Variable: u_cause_Others       Importance: 0.0
# Variable: u_cause_Application  Importance: 0.0
# Variable: u_cause_Server - Configuration Importance: 0.0
# Variable: u_cause_Local System Importance: 0.0
# Variable: u_cause_Database     Importance: 0.0
# Variable: u_cause_Server - Service Importance: 0.0
# Variable: u_cause_No Cause     Importance: 0.0
# Variable: u_cause_Component issue Importance: 0.0
# Variable: u_cause_Telephone    Importance: 0.0
# Variable: u_cause_e-mail and messaging Importance: 0.0
# Variable: u_cause_Printer      Importance: 0.0
# Variable: u_cause_Security     Importance: 0.0
# Variable: u_cause_Connectivity WAN - Configuration Importance: 0.0
# Variable: u_cause_Connectivity LAN - hardware Importance: 0.0
# Variable: u_cause_Power failure - Unplanned Importance: 0.0
# Variable: u_cause_Connectivity LAN - Configuration Importance: 0.0
# Variable: u_cause_Backup hardware Importance: 0.0
# Variable: u_cause_Connectivity LAN - utilization Importance: 0.0
# Variable: u_cause_Server - Hardware Importance: 0.0
# Variable: u_cause_Capacity related Importance: 0.0
# Variable: reopen_count         Importance: 0.0
# Variable: location_559 - Montreal Head Office Importance: 0.0
# Variable: location_147 - Derby Litchurch Lane Importance: 0.0
# Variable: location_182 - Siegen Importance: 0.0
# Variable: location_506 - Dorval Administrative Centre (CA) Importance: 0.0
# Variable: location_508 - Mirabel Manufacturing Importance: 0.0
# Variable: location_Bombardier Transportation Importance: 0.0
# Variable: location_240 - Hortolandia Importance: 0.0
# Variable: location_187 - Hennigsdorf Importance: 0.0
# Variable: location_241 - Cebu  Importance: 0.0
# Variable: location_551 - Casablanca Aeropole Importance: 0.0
# Variable: location_24 - Cluj-Napoca PBC Importance: 0.0
# Variable: location_514 - Toronto De Havilland Inc. Importance: 0.0
# Variable: location_154 - Zurich Oerlikon Toro 1 Importance: 0.0
# Variable: location_433 - London Old Oak Common Depot Importance: 0.0
# Variable: location_509 - Saint-Laurent BAN 1 Importance: 0.0
# Variable: location_19 - Crespin Importance: 0.0
# Variable: location_521_Gold_Room_233 - Completion Center - Room 233 - Conference Importance: 0.0
# Variable: location_449 - Bangalore Quest (3rd Party) Importance: 0.0
# Variable: location_426_Gold_Room_Presidents_Board_Room - Berlin New HQ Importance: 0.0
# Variable: location_505 - Dorval Plant 3 Importance: 0.0
# Variable: location_181 - Kassel Importance: 0.0
# Variable: location_250 - Kuala Lumpur Importance: 0.0
# Variable: location_520 - Wichita Learjet Importance: 0.0
# Variable: location_671 - Giza 6-Oct Line Depot Importance: 0.0
# Variable: location_516 - Dorval Completion Centre Importance: 0.0
# Variable: location_510 - Saint-Laurent BAN 2 Importance: 0.0
# Variable: location_294 - West Melbourne Importance: 0.0
# Variable: location_60 - Plattsburgh Importance: 0.0
# Variable: location_123 - Derby Etches Park Importance: 0.0
# Variable: location_426 - Berlin New HQ Importance: 0.0
# Variable: location_323 - London Pancras Square Importance: 0.0
# Variable: location_64 - Bruges Importance: 0.0
# Variable: location_521_Gold_Room_227 - Completion Center - Room 227 - Conference Importance: 0.0
# Variable: location_289 - Dandenong Importance: 0.0
# Variable: location_521_Gold_Room_107 - Completion Center - Room 107 - Conference Importance: 0.0
# Variable: location_528 - Tucson Importance: 0.0
# Variable: location_121 - Welby Asfordby Importance: 0.0
# Variable: location_Bombardier Aerospace Importance: 0.0
# Variable: location_377 - Wulkuraka Importance: 0.0
# Variable: location_95 - Vienna Importance: 0.0
# Variable: location_152 - Zurich Oerlikon PowerLab Importance: 0.0
# Variable: location_521 - Fort Lauderdale Importance: 0.0
# Variable: location_236 - Bangkok Klongtoey Importance: 0.0
# Variable: location_199 - Gurgaon (RCS & IS Hub) Importance: 0.0
# Variable: location_200 - Savli (Vadodara) Importance: 0.0
# Variable: location_94 - St-Bruno Importance: 0.0
# Variable: location_521_Gold_Room_221 - Completion Center - Room 221 - Conference Importance: 0.0
# Variable: location_521_Gold_Room_106 - Completion Center - Room 106 - Conference Importance: 0.0
# Variable: location_T14 - Montreal Viger Data Centre Importance: 0.0
# Variable: location_549 - Bangalore ESO Importance: 0.0
# Variable: location_523 - Dallas Learjet (Love Field) Importance: 0.0
# Variable: location_189 - Hyderabad Engineering Center Importance: 0.0
# Variable: location_511 - Saint-Laurent OPTO Importance: 0.0
# Variable: location_532 - Belfast Queens Island Importance: 0.0
# Variable: location_92 - Thunder Bay Importance: 0.0
# Variable: location_506_Gold_Room_003 - Administrative Centre - Room 003 Importance: 0.0
# Variable: location_185 - Mannheim Importance: 0.0
# Variable: location_521_Gold_Room_104 - Completion Center - Room 104 - Conference Importance: 0.0
# Variable: location_531 - Frankfurt Gross-Gerau Importance: 0.0
# Variable: location_183 - Bautzen Importance: 0.0
# Variable: location_503 - Saint-Laurent Marcel-Laurin Importance: 0.0
# Variable: category_Hardware    Importance: 0.0
# Variable: category_Email       Importance: 0.0
# Variable: category_Security Control Failure Importance: 0.0
# Variable: category_Application - Issues / Requests Importance: 0.0
# Variable: category_Access - Issues / Requests Importance: 0.0
# Variable: category_No Category Importance: 0.0
# Variable: category_Software    Importance: 0.0
# Variable: category_Network     Importance: 0.0
# Variable: category_Video Conferencing / Webex Importance: 0.0
# Variable: category_Enterprise Phone Importance: 0.0
# Variable: category_Mobile Devices Importance: 0.0
# Variable: category_Printer and Fax Importance: 0.0
# Variable: category_General     Importance: 0.0
# Variable: category_Notification Alert Importance: 0.0
# Variable: open_lastupdated_age_4 to 7 days Importance: 0.0
# Variable: open_lastupdated_age_Over 2 weeks Importance: 0.0
# Variable: open_lastupdated_age_8 to 14 days Importance: 0.0
# Variable: create_lastupdated_age_4 to 7 days Importance: 0.0
# Variable: create_lastupdated_age_Over 2 weeks Importance: 0.0
# Variable: create_lastupdated_age_8 to 14 days Importance: 0.0
# Variable: hour_of_day_created  Importance: 0.0
# Variable: day_of_week_created_Wednesday Importance: 0.0
# Variable: day_of_week_created_Tuesday Importance: 0.0
# Variable: day_of_week_created_Thursday Importance: 0.0
# Variable: day_of_week_created_Monday Importance: 0.0
# Variable: day_of_week_created_Saturday Importance: 0.0
# Variable: day_of_week_created_Sunday Importance: 0.0
# Variable: day_of_week_created_Friday Importance: 0.0
# Variable: day_of_month_created Importance: 0.0
# Variable: year_of_created      Importance: 0.0
# Variable: month_year_created_Jul 2021 Importance: 0.0
# Variable: month_year_created_Aug 2021 Importance: 0.0
# Variable: month_year_created_Jun 2021 Importance: 0.0
# Variable: month_year_created_Mar 2021 Importance: 0.0
# Variable: month_year_created_May 2021 Importance: 0.0
# Variable: month_year_created_Jan 2021 Importance: 0.0
# Variable: month_year_created_Apr 2021 Importance: 0.0
# Variable: month_year_created_Sep 2020 Importance: 0.0
# Variable: hour_of_day_opened   Importance: 0.0
# Variable: day_of_week_opened_Wednesday Importance: 0.0
# Variable: day_of_week_opened_Tuesday Importance: 0.0
# Variable: day_of_week_opened_Thursday Importance: 0.0
# Variable: day_of_week_opened_Monday Importance: 0.0
# Variable: day_of_week_opened_Saturday Importance: 0.0
# Variable: day_of_week_opened_Sunday Importance: 0.0
# Variable: day_of_week_opened_Friday Importance: 0.0
# Variable: day_of_month_opened  Importance: 0.0
# Variable: year_of_opened       Importance: 0.0
# Variable: month_year_opened_Jul 2021 Importance: 0.0
# Variable: month_year_opened_Aug 2021 Importance: 0.0
# Variable: month_year_opened_Jun 2021 Importance: 0.0
# Variable: month_year_opened_Mar 2021 Importance: 0.0
# Variable: month_year_opened_May 2021 Importance: 0.0
# Variable: month_year_opened_Jan 2021 Importance: 0.0
# Variable: month_year_opened_Apr 2021 Importance: 0.0
# Variable: month_year_opened_Sep 2020 Importance: 0.0
# Variable: hour_of_day_resolved Importance: 0.0
# Variable: day_of_week_resolved_Wednesday Importance: 0.0
# Variable: day_of_week_resolved_Tuesday Importance: 0.0
# Variable: day_of_week_resolved_Monday Importance: 0.0
# Variable: day_of_week_resolved_Friday Importance: 0.0
# Variable: day_of_week_resolved_Sunday Importance: 0.0
# Variable: day_of_week_resolved_Thursday Importance: 0.0
# Variable: day_of_week_resolved_Saturday Importance: 0.0
# Variable: day_of_month_resolved Importance: 0.0
# Variable: month_of_resolved    Importance: 0.0
# Variable: year_of_resolved     Importance: 0.0
# Variable: month_year_resolved_Jul 2021 Importance: 0.0
# Variable: month_year_resolved_Aug 2021 Importance: 0.0
# Variable: month_year_resolved_Apr 2021 Importance: 0.0
# Variable: month_year_resolved_Jun 2021 Importance: 0.0
# Variable: month_year_resolved_May 2021 Importance: 0.0
# Variable: month_year_resolved_Jan 2021 Importance: 0.0
# Variable: hour_of_day_closed   Importance: 0.0
# Variable: day_of_week_closed_Monday Importance: 0.0
# Variable: day_of_week_closed_Sunday Importance: 0.0
# Variable: day_of_week_closed_Saturday Importance: 0.0
# Variable: day_of_week_closed_Wednesday Importance: 0.0
# Variable: day_of_week_closed_Friday Importance: 0.0
# Variable: day_of_week_closed_Tuesday Importance: 0.0
# Variable: day_of_week_closed_Thursday Importance: 0.0
# Variable: day_of_month_closed  Importance: 0.0
# Variable: month_of_closed      Importance: 0.0
# Variable: year_of_closed       Importance: 0.0
# Variable: month_year_closed_Jul 2021 Importance: 0.0
# Variable: month_year_closed_Aug 2021 Importance: 0.0
# Variable: month_year_closed_Apr 2021 Importance: 0.0
# Variable: month_year_closed_Jun 2021 Importance: 0.0
# Variable: month_year_closed_Jan 2021 Importance: 0.0
# Variable: month_year_closed_May 2021 Importance: 0.0
# Variable: reopen_count_range_0 Importance: 0.0
# Variable: reopen_count_range_1 Importance: 0.0
# Variable: reopen_count_range_2 Importance: 0.0
# Variable: reassignment_count_range_1 Importance: 0.0
# Variable: reassignment_count_range_0 Importance: 0.0
# Variable: reassignment_count_range_2 Importance: 0.0
# Variable: reassignment_count_range_More than 10 Importance: 0.0
# Variable: reassignment_count_range_3 to 10 Importance: 0.0
# Variable: open_resolved_age_0 to 3 days Importance: 0.0
# Variable: open_resolved_age_Over 2 weeks Importance: 0.0
# Variable: open_resolved_age_8 to 14 days Importance: 0.0
# Variable: open_resolved_age_4 to 7 days Importance: 0.0
# Variable: create_resolved_age_0 to 3 days Importance: 0.0
# Variable: create_resolved_age_Over 2 weeks Importance: 0.0
# Variable: create_resolved_age_8 to 14 days Importance: 0.0
# Variable: create_resolved_age_4 to 7 days Importance: 0.0
# Variable: open_closed_age_4 to 7 days Importance: 0.0
# Variable: open_closed_age_Over 2 weeks Importance: 0.0
# Variable: open_closed_age_8 to 14 days Importance: 0.0
# Variable: create_closed_age_4 to 7 days Importance: 0.0
# Variable: create_closed_age_Over 2 weeks Importance: 0.0
# Variable: create_closed_age_8 to 14 days Importance: 0.0

# %% [markdown]
# ## High Category ##

# %%
dataframe_p2 = dataframe_p2.drop(['number','sys_created_by','task_effective_number','sys_updated_by','opened_by','sys_created_on','caller_id','u_qs_reported_by','sys_id','activity_due','xtracted_on','diff_seconds','diff_seconds_1','sys_updated_on','opened_at','resolved_at','work_end','work_start','closed_at'],axis=1)
dataframe_p2 = dataframe_p2.drop(['_index','_type','upon_reject','state','priority','sys_domain_path','u_qs_type','notify','sys_class_name','sla_due','u_escalation','escalation','upon_approval','u_sc_escalation','sys_domain','incident_state','severity','approval','account_prefix','account_name','account_domain','open_extracted_age','create_extracted_age'],axis=1)

# %%
## Splitting the dataframe based on training and testing ##
X2 = dataframe_p2[[i for i in list(dataframe_p2.columns) if i!='MTTR']]
y2 = dataframe_p2['MTTR']

# %%
## Split into train and test sets ##
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X2, y2, test_size=0.33, random_state=1)
X_train_2.shape,X_test_2.shape, y_train_2.shape, y_test_2.shape
# Out:
# ((2193, 94), (1081, 94), (2193,), (1081,))

# %%
#Create object for one-hot encoding
encoder=ce.OneHotEncoder(cols=['u_end_of_support','u_qs_opened_by_group','u_warranty_expired','cmdb_ci','impact','business_duration','service_offering','assigned_to','u_location_details','resolved_by','business_service','subcategory','close_code','assignment_group','calendar_duration','contact_type','urgency','u_preferred_language','company','u_cause','location','category','open_lastupdated_age','create_lastupdated_age','day_of_week_created','month_year_created','day_of_week_opened','month_year_opened','day_of_week_resolved','month_year_resolved','day_of_week_closed','month_year_closed','reopen_count_range','reassignment_count_range','open_resolved_age','create_resolved_age','open_closed_age','create_closed_age'],handle_unknown='return_nan',return_df=True,use_cat_names=True)
X_train_2_new = encoder.fit_transform(X_train_2)
X_test_2_new = encoder.transform(X_test_2)

# %%
X_train_2_new.columns[X_train_2_new.isna().any()].tolist()
# Out:
# []

# %%
X_test_2_new.columns[X_test_2_new.isna().any()].tolist()
# Out:
# ['u_qs_opened_by_group_No Group',
#  'u_qs_opened_by_group_IBM-SD-India SD L1-Rail',
#  'u_qs_opened_by_group_IBM-AP-Asset Management',
#  'u_qs_opened_by_group_IBM-SD-Italy Turin SD L1-Rail',
#  'u_qs_opened_by_group_IBM-MF-US-CONSOLE-OPS',
#  'u_qs_opened_by_group_IBM-SD-IN',
#  'u_qs_opened_by_group_IBM-SD-French-Aero',
#  'u_qs_opened_by_group_IBM-SD-Italy Naples SD L1-Rail',
#  'u_qs_opened_by_group_VEN-AP-SIMS-Rail',
#  'u_qs_opened_by_group_IBM-SD-Spanish',
#  'u_qs_opened_by_group_VEN-NTT-DS-Hemmersbach-Madrid-Staffed-ES-RAIL',
#  'u_qs_opened_by_group_IBM-AP-COTS-Maximo-Rail',
#  'u_qs_opened_by_group_APPR-BIS-APPL-CAB',
#  'u_qs_opened_by_group_BA-IBM-DL-IMI-IN-Wintel',
#  'u_qs_opened_by_group_IBM-AP-PDE CECC Projects-Aero',
#  'u_qs_opened_by_group_IBM-AS-PKI Mgmt-Rail',
#  'u_qs_opened_by_group_IBM-AP-ServiceNowAdmin-Rail',
#  'u_qs_opened_by_group_BT-IBM-APPR-SAP-Basis-Rail',
#  'u_qs_opened_by_group_BA-VEN-NTT-DS-Mirabel-MTL-AERO',
#  'u_qs_opened_by_group_PC Refresh-IBM-SD-Naples-Rail',
#  'u_qs_opened_by_group_BT-IBM-SI-Asset Governance-Rail',
#  'u_qs_opened_by_group_BA-VEN-NTT-DS-HQ-MTL-AERO',
#  'u_qs_opened_by_group_IBM-AP-PDE CECC Sustainment-Aero',
#  'u_qs_opened_by_group_BIS-AP-BBA Portal Support',
#  'u_qs_opened_by_group_IBM-AP-TECH-Tech Tower-Rail',
#  'cmdb_ci_AMERPS1013',
#  'cmdb_ci_A011252P000',
#  'cmdb_ci_bdedus00mos01',
#  'cmdb_ci_Unknown',
#  'cmdb_ci_Security',
#  'cmdb_ci_iaa0011',
#  'cmdb_ci_bgbrdn00swa00',
#  'cmdb_ci_qroem-idf-es01.bombardier',
#  'cmdb_ci_IFM0883',
#  'cmdb_ci_bphceb00fwd01',
#  'cmdb_ci_BBTSRVBPT017',
#  'cmdb_ci_A010600P200',
#  'cmdb_ci_Metaweb',
#  'cmdb_ci_BBTWAPMUK1',
#  'cmdb_ci_Other Quality d/b',
#  'cmdb_ci_BBTRTRLOD96.bt.bombardier.net',
#  'cmdb_ci_bbrhtl00fwd00',
#  'cmdb_ci_iea0680',
#  'cmdb_ci_A011484P006',
#  'cmdb_ci_SharePoint Sites',
#  'cmdb_ci_MAXIMO BT APAC PROD',
#  'cmdb_ci_IFM0923',
#  'cmdb_ci_BBTRTRDWD001',
#  'cmdb_ci_iha0020',
#  'cmdb_ci_iaa0891',
#  'cmdb_ci_ifm0674',
#  'cmdb_ci_sam0011',
#  'cmdb_ci_BBTSWHGCD001.bt.bombardier.net',
#  'cmdb_ci_a010760p101',
#  'cmdb_ci_a011588p000',
#  'cmdb_ci_iea0660',
#  'cmdb_ci_BTIS1000061781',
#  'cmdb_ci_IFM0097',
#  'cmdb_ci_a010525p101',
#  'cmdb_ci_iaa0004',
#  'cmdb_ci_BBTSRVCR1004',
#  'cmdb_ci_bbtswhant2',
#  'cmdb_ci_Tomcat@a028189d001',
#  'cmdb_ci_IFA0336',
#  'cmdb_ci_iza1010',
#  'cmdb_ci_a010626p200',
#  'cmdb_ci_IDA1230',
#  'cmdb_ci_IFM0773',
#  'cmdb_ci_iea0206',
#  'cmdb_ci_MTLLASMS001',
#  'cmdb_ci_IFM0155',
#  'cmdb_ci_Atlels2008',
#  'cmdb_ci_bbtswhlu21',
#  'cmdb_ci_BBTSRVCR1008',
#  'cmdb_ci_Alstom-PC Refresh',
#  'cmdb_ci_IFM0692',
#  'cmdb_ci_a010065p211',
#  'cmdb_ci_Internet and Network',
#  'cmdb_ci_IFM0723',
#  'cmdb_ci_iha0010',
#  'cmdb_ci_IDM0037',
#  'cmdb_ci_Lotus Notes CTS',
#  'cmdb_ci_SAP HRSP QAS System,',
#  'cmdb_ci_IDM0054',
#  'cmdb_ci_Windows',
#  'cmdb_ci_Voice Service - Other',
#  'cmdb_ci_Application / System Access Management',
#  'cmdb_ci_IDA0265',
#  'cmdb_ci_Alstom-Password reset',
#  'cmdb_ci_saa3001',
#  'cmdb_ci_iea0620',
#  'cmdb_ci_a010357p201',
#  'cmdb_ci_Security Offerings',
#  'cmdb_ci_A010647P001',
#  'cmdb_ci_IFM0812',
#  'cmdb_ci_iga0730',
#  'cmdb_ci_IFM0852',
#  'cmdb_ci_ICA3003',
#  'cmdb_ci_IFA0337',
#  'cmdb_ci_PASSWORD MANAGER',
#  'cmdb_ci_A011414P001',
#  'cmdb_ci_sam0012',
#  'cmdb_ci_BDEFRA00PBI00',
#  'cmdb_ci_Rational_SYNERGY_PROD',
#  'cmdb_ci_Microsoft Acces',
#  'cmdb_ci_SAP MM PROD',
#  'cmdb_ci_SalesForce',
#  'cmdb_ci_IDM0135',
#  'cmdb_ci_BTIS1000083966',
#  'cmdb_ci_ifm0215',
#  'cmdb_ci_BCNWHI00FWD01',
#  'cmdb_ci_beshms00fwd00',
#  'cmdb_ci_a010357p051',
#  'cmdb_ci_iea1360',
#  'cmdb_ci_iea1090',
#  'cmdb_ci_iza0014',
#  'cmdb_ci_a010357p301',
#  'cmdb_ci_ATLEPS1008',
#  'cmdb_ci_A011201P000',
#  'cmdb_ci_DataLink CSALP PROD',
#  'cmdb_ci_IFA0189',
#  'cmdb_ci_IDA1380',
#  'cmdb_ci_IFM0882',
#  'cmdb_ci_SAPLTP01',
#  'cmdb_ci_bbtaptnd101.bt.bombardier.net',
#  'cmdb_ci_iea1200',
#  'cmdb_ci_A011262P004',
#  'cmdb_ci_ifm0682',
#  'cmdb_ci_Other Issues or Requests',
#  'cmdb_ci_IFA0317',
#  'cmdb_ci_IZA0632',
#  'cmdb_ci_BBTRTRLO6203',
#  'cmdb_ci_IFM0676',
#  'cmdb_ci_BBTFLRVA302',
#  'cmdb_ci_bbtrtrmuv1.bt.bombardier.net',
#  'cmdb_ci_iaa0010',
#  'cmdb_ci_Bdehnf00wap252',
#  'cmdb_ci_BBTAPTTH15.bt.bombardier.net',
#  'cmdb_ci_ndefra00aa06',
#  'cmdb_ci_citrixdeu2@IDM0038',
#  'cmdb_ci_IFM1013',
#  'cmdb_ci_ica0306',
#  'cmdb_ci_Other',
#  'cmdb_ci_P2117283',
#  'cmdb_ci_ICA0078',
#  'cmdb_ci_BBTSTSCRE2',
#  'cmdb_ci_iaa0921',
#  'cmdb_ci_IFM0872',
#  'cmdb_ci_iaa0821',
#  'cmdb_ci_ifm0046',
#  'cmdb_ci_ATLESS0001',
#  'cmdb_ci_bgblon20fwd00',
#  'cmdb_ci_a011430p012',
#  'cmdb_ci_IFA0469',
#  'cmdb_ci_IFM0532',
#  'cmdb_ci_CONEMP0005',
#  'cmdb_ci_LOTUS NOTES PROD',
#  'cmdb_ci_CrossTrack',
#  'cmdb_ci_bitnap00fwd00',
#  'cmdb_ci_iza0930',
#  'cmdb_ci_BINBUR00SWC00',
#  'cmdb_ci_a011440p100',
#  'cmdb_ci_iea0480',
#  'cmdb_ci_iza1170',
#  'cmdb_ci_iaa0881',
#  'cmdb_ci_ APIN0305',
#  'cmdb_ci_iem0001',
#  'cmdb_ci_Zscaler v2.1.2.10',
#  'cmdb_ci_iea1190',
#  'cmdb_ci_a010065d210',
#  'cmdb_ci_a011430p013',
#  'cmdb_ci_Concur Travel & Expense',
#  'cmdb_ci_Alstom-Azure AD',
#  'cmdb_ci_A011262S008',
#  'cmdb_ci_A036475P007',
#  'cmdb_ci_IFM0492',
#  'cmdb_ci_IPS1230',
#  'cmdb_ci_IFA0415',
#  'cmdb_ci_bmxcsg00swa06',
#  'cmdb_ci_BTIS1000066520',
#  'cmdb_ci_sFTP PROD',
#  'cmdb_ci_iea0530',
#  'cmdb_ci_IBMPLMSB1320',
#  'cmdb_ci_A010011P200',
#  'cmdb_ci_a015512p101',
#  'cmdb_ci_bphceb00wap03',
#  'cmdb_ci_bestra00fwd00',
#  'cmdb_ci_ifm0255',
#  'cmdb_ci_bsevst00wap03',
#  'cmdb_ci_a010357p210',
#  'cmdb_ci_bchzrh01fwd00',
#  'cmdb_ci_a010635p105',
#  'cmdb_ci_SAP AFTER MARKET PROD',
#  'cmdb_ci_bbtrtrnd102.bt.bombardier.net',
#  'cmdb_ci_IFM0010',
#  'cmdb_ci_a011430p006',
#  'cmdb_ci_iha0021',
#  'cmdb_ci_a010357p200',
#  'cmdb_ci_IFM0653',
#  'cmdb_ci_a011557p003',
#  'cmdb_ci_iea0890',
#  'cmdb_ci_iflybombardier.com',
#  'cmdb_ci_A011430P018',
#  'cmdb_ci_ifa0344',
#  'cmdb_ci_IFM0533',
#  'cmdb_ci_ATLEPS1002',
#  'cmdb_ci_Conels2014',
#  'cmdb_ci_iea0490',
#  'cmdb_ci_IFM0683',
#  'cmdb_ci_Mobile Pass - (Cloud SAS)',
#  'cmdb_ci_iza0790',
#  'cmdb_ci_BBTSWHBAR4.bt.bombardier.net',
#  'cmdb_ci_ICA0114',
#  'cmdb_ci_bcasbo01swa00',
#  'cmdb_ci_File share server',
#  'cmdb_ci_IHA0001',
#  'cmdb_ci_IFA0425',
#  'cmdb_ci_IFM0732',
#  'cmdb_ci_BBTRTRGEY129',
#  'cmdb_ci_windows',
#  'cmdb_ci_IFM0612',
#  'cmdb_ci_IFM1112',
#  'cmdb_ci_AMERMP0002',
#  'cmdb_ci_BIEM PROD',
#  'cmdb_ci_BBTRTRMIL1.bt.bombardier.net',
#  'cmdb_ci_IFM1153',
#  'cmdb_ci_McAfee Complete Data Protection',
#  'cmdb_ci_P2184403',
#  'cmdb_ci_A004456P007',
#  'cmdb_ci_Catia 3Dcom PROD',
#  'cmdb_ci_BTIS1000098153',
#  'cmdb_ci_bfrcln00fwd00',
#  'cmdb_ci_A010731T001',
#  'cmdb_ci_bmxcsg00swa47',
#  'cmdb_ci_CESWAP37',
#  'cmdb_ci_Enovia',
#  'cmdb_ci_BBTSWHSP61.bt.bombardier.net',
#  'cmdb_ci_IFM1183',
#  'cmdb_ci_P2107176',
#  'cmdb_ci_a010357p057',
#  'cmdb_ci_bthbkk00fwd01',
#  'cmdb_ci_A004456P006',
#  'cmdb_ci_Enovia LCA PROD',
#  'cmdb_ci_iaa1081',
#  'cmdb_ci_iaa0491',
#  'cmdb_ci_ifm0216',
#  'cmdb_ci_Alstom -APP Office 365',
#  'cmdb_ci_BBTSWHDWD001',
#  'cmdb_ci_IFA0024',
#  'cmdb_ci_Active Directory Certificate Services',
#  'cmdb_ci_IFM0160',
#  'cmdb_ci_ica0003',
#  'cmdb_ci_Office 365 - BA',
#  'cmdb_ci_Baan Australia PROD',
#  'cmdb_ci_IFM0832',
#  'cmdb_ci_dormir-sysco04-es01.net.aero.bombardier.net.bombardier',
#  'cmdb_ci_SAP BASIS PROD',
#  'cmdb_ci_bitmil01fwd00',
#  'cmdb_ci_SAP Global Authorization',
#  'cmdb_ci_BTIS1000066390',
#  'cmdb_ci_IDM0144',
#  'cmdb_ci_BTIS1000005867',
#  'cmdb_ci_CAPP  D',
#  'cmdb_ci_A010626D001',
#  'cmdb_ci_a010357p053',
#  'cmdb_ci_Mobile Pass - LDAP',
#  'cmdb_ci_bdefra00usl00',
#  'cmdb_ci_BINBUR00FWD00',
#  'cmdb_ci_BBTRTRLYO93.bt.bombardier.net',
#  'cmdb_ci_a010357p020',
#  'cmdb_ci_BBTSWHCR1221.bt.bombardier.net',
#  'cmdb_ci_A015303P100',
#  'cmdb_ci_BBTRTRBW41.bt.bombardier.net',
#  'cmdb_ci_Application / System Access Management Offerings',
#  'cmdb_ci_BCZCES00FLR01',
#  'cmdb_ci_IDM0136',
#  'cmdb_ci_iea0650',
#  'cmdb_ci_iea0400',
#  'cmdb_ci_Teams',
#  'cmdb_ci_ica0008',
#  'cmdb_ci_Backup and Restoration',
#  'cmdb_ci_A011170P000',
#  'cmdb_ci_P2117226',
#  'cmdb_ci_case004',
#  'cmdb_ci_BBTSWHKI1600.bt.bombardier.net',
#  'cmdb_ci_dormir-a2u16-u02.bombardier',
#  'cmdb_ci_IFM0712',
#  'cmdb_ci_BZACPT00FWD00',
#  'cmdb_ci_BBTFLRSDC02',
#  'cmdb_ci_ICA0085',
#  'cmdb_ci_iea0940',
#  'cmdb_ci_a011430p003',
#  'cmdb_ci_A015668P001',
#  'cmdb_ci_bitast00fwd00',
#  'cmdb_ci_IDG0400',
#  'cmdb_ci_Computer Software',
#  'cmdb_ci_BNET Employee Portal',
#  'cmdb_ci_bbtswhbsg019.bt.bombardier.net',
#  'cmdb_ci_SAP PLM PROD',
#  'cmdb_ci_Citrix CSALP',
#  'cmdb_ci_BBTSWHTO2200.bt.bombardier.net',
#  'cmdb_ci_bdefra00flr00',
#  'cmdb_ci_BBTFLRSDC01',
#  'cmdb_ci_CHIPR083',
#  'cmdb_ci_A010011Q201',
#  'cmdb_ci_IFM0582',
#  'cmdb_ci_Windows, SAP and VB Scripting',
#  'cmdb_ci_IFM1082',
#  'cmdb_ci_bdelfl00fwd00',
#  'cmdb_ci_APACPS1018',
#  'cmdb_ci_SJOUP-MDF-WL01',
#  'cmdb_ci_es-bom-san0s-ce-01',
#  'cmdb_ci_IFM0283',
#  'cmdb_ci_SGM',
#  'cmdb_ci_IFM0136',
#  'cmdb_ci_Network',
#  'cmdb_ci_McAfee Endpoint Protection, Advanced Suite',
#  'cmdb_ci_ica0202',
#  'cmdb_ci_iea0730',
#  'cmdb_ci_iaa0561',
#  'cmdb_ci_Solochain - PROD',
#  'cmdb_ci_IFA0471',
#  'cmdb_ci_IGM0046',
#  'cmdb_ci_A010731P001',
#  'cmdb_ci_a010357p016',
#  'cmdb_ci_IFM0182',
#  'cmdb_ci_MTLLWSTPMGT002',
#  'cmdb_ci_AHMS for BCA',
#  'cmdb_ci_IDA0460',
#  'cmdb_ci_IBMPLMHYD800',
#  'cmdb_ci_IFM0085',
#  'cmdb_ci_IFA0441',
#  'cmdb_ci_bbusnyc00fwd00',
#  'cmdb_ci_IEA0046',
#  'cmdb_ci_a010635p102',
#  'cmdb_ci_iea0760',
#  'cmdb_ci_ATLEAS0012',
#  'cmdb_ci_A011155P004',
#  'cmdb_ci_BTIS1000012126',
#  'cmdb_ci_ips0201',
#  'cmdb_ci_PCT - SAP CRM PROD',
#  'cmdb_ci_BTIS1000084285',
#  'cmdb_ci_BFRRPI00FLR01',
#  'cmdb_ci_BUSPIT00FLR02',
#  'cmdb_ci_A011430P002',
#  'cmdb_ci_SAP HR GLOBAL PROD',
#  'cmdb_ci_iea0610',
#  'cmdb_ci_BCAWTL00FWD00',
#  'cmdb_ci_binbom02fwd00',
#  'cmdb_ci_iza0880',
#  'cmdb_ci_iza3002',
#  'cmdb_ci_iea0690',
#  'cmdb_ci_ndedus00gm09',
#  'cmdb_ci_IFM0163',
#  'cmdb_ci_P2176046',
#  'cmdb_ci_BBTSWHMAT04.bt.bombardier.net',
#  'cmdb_ci_Baan  - Vaesteras PROD',
#  'cmdb_ci_BBTRTRLEV99.bt.bombardier.net',
#  'cmdb_ci_IFM0059',
#  'cmdb_ci_IFM0713',
#  'cmdb_ci_SAP PSI Global',
#  'cmdb_ci_ifm0067',
#  'cmdb_ci_Rational_JAZZ_QA',
#  'cmdb_ci_ict06-s2021-es01.bombardier',
#  'cmdb_ci_ifm0190',
#  'cmdb_ci_IFM0403',
#  'cmdb_ci_IDA1110',
#  'cmdb_ci_BBTSVLBPT001',
#  'cmdb_ci_ICA0083',
#  'cmdb_ci_IGM0019',
#  'cmdb_ci_iea0550',
#  'cmdb_ci_BBTSRVCR1009',
#  'cmdb_ci_BBTSVHBPT001',
#  'cmdb_ci_A011155P005',
#  'cmdb_ci_Email and Calendar',
#  'cmdb_ci_amerls2002',
#  'cmdb_ci_BBTBCKSBR001',
#  'cmdb_ci_a010357p015',
#  'cmdb_ci_IFM0662',
#  'cmdb_ci_a010065p210',
#  'cmdb_ci_casns2-mdf-wa01.bombardier',
#  'cmdb_ci_BBTAPTME220.bt.bombardier.net',
#  'cmdb_ci_A015579P100',
#  'cmdb_ci_IFM1172',
#  'cmdb_ci_A11631Q100',
#  'cmdb_ci_IFA0181',
#  'cmdb_ci_IFA0422',
#  'cmdb_ci_IFM0198',
#  'cmdb_ci_a010357p300',
#  'cmdb_ci_iaa0541',
#  'cmdb_ci_iza0500',
#  'cmdb_ci_DCAM - DCAM ? Shop Floor Prod',
#  'cmdb_ci_iaa0661',
#  'cmdb_ci_iaa0551',
#  'cmdb_ci_BTIS1000090500',
#  'cmdb_ci_A004456P004',
#  'cmdb_ci_BPELIM00FWD00',
#  'cmdb_ci_A011432P001',
#  'cmdb_ci_IDM0039',
#  'cmdb_ci_BBTSWHDWD002',
#  'cmdb_ci_BBTSRVVIE3',
#  'cmdb_ci_IDA0016',
#  'cmdb_ci_a010357p310',
#  'cmdb_ci_BBTRTRBW31.bt.bombardier.net',
#  'cmdb_ci_MTLWAICR001',
#  'cmdb_ci_iea0500',
#  'cmdb_ci_IFM1222',
#  'cmdb_ci_a015154p002',
#  'cmdb_ci_Lotus Notes Mail',
#  'cmdb_ci_iea1060',
#  'cmdb_ci_A011204P100',
#  'cmdb_ci_ifm0047',
#  'cmdb_ci_ica3002',
#  'cmdb_ci_IFM0135',
#  'cmdb_ci_MTLCICON701',
#  'cmdb_ci_iea0040',
#  'cmdb_ci_iea0034',
#  'cmdb_ci_ifm0028',
#  'cmdb_ci_a015512p300',
#  'cmdb_ci_a020393p001',
#  'cmdb_ci_CATIA V5 PROD',
#  'cmdb_ci_a010357p302',
#  'cmdb_ci_iaa0681',
#  'cmdb_ci_NCMS',
#  'cmdb_ci_A011262P007',
#  'cmdb_ci_a011712p001',
#  'cmdb_ci_iea0830',
#  'cmdb_ci_IFM0703',
#  'cmdb_ci_sjoviesx001',
#  'cmdb_ci_BBA Salesforce-Aero',
#  'cmdb_ci_AMERPS1030',
#  'cmdb_ci_igm0000',
#  'cmdb_ci_AMERPS1015',
#  'cmdb_ci_BBTSRVCR1010',
#  'cmdb_ci_FLEXNET PROD',
#  'cmdb_ci_iza0620',
#  'cmdb_ci_BT02SSCN05',
#  'cmdb_ci_1099 IC580 Portal PROD',
#  'cmdb_ci_MobilePass Cloud Service',
#  'cmdb_ci_bcasbo00sws00',
#  'cmdb_ci_A004456P003',
#  'cmdb_ci_PPI-SAP Basis PI PRD',
#  'cmdb_ci_IFM0552',
#  'cmdb_ci_iha0009',
#  'cmdb_ci_IFA0423',
#  'cmdb_ci_a010357p017',
#  'cmdb_ci_iea0036',
#  'cmdb_ci_bbtfwdchn1',
#  'cmdb_ci_ifm1032',
#  'cmdb_ci_IFM1143',
#  'cmdb_ci_iea0700',
#  'cmdb_ci_BINBDQ04FWD01',
#  'cmdb_ci_IFA0427',
#  'cmdb_ci_iea0860',
#  'cmdb_ci_IFA0291',
#  'cmdb_ci_iaa0461',
#  'cmdb_ci_IDA1140',
#  'cmdb_ci_ica0007',
#  'cmdb_ci_a010525p301',
#  'cmdb_ci_bsesto00fwd01',
#  'cmdb_ci_PulseSecure',
#  'cmdb_ci_IFM0542',
#  'cmdb_ci_BAAN1_Physical',
#  'cmdb_ci_BFRRPI00FLR00',
#  'cmdb_ci_ICA0112',
#  'cmdb_ci_BBTSTSCRE1',
#  'cmdb_ci_ifm0213',
#  'cmdb_ci_bdefra00dbs00',
#  'cmdb_ci_IFM0593',
#  'cmdb_ci_IFA0351',
#  'cmdb_ci_IMB0201',
#  'cmdb_ci_binbdq00wap45',
#  'cmdb_ci_IFA0302',
#  'cmdb_ci_BBTRTRWA301.bt.bombardier.net',
#  'cmdb_ci_BT02SSIN02NEW',
#  'cmdb_ci_BBTAPTCR1082.bt.bombardier.net',
#  'cmdb_ci_iea0460',
#  'cmdb_ci_IFM0643',
#  'cmdb_ci_ICA0006',
#  'cmdb_ci_IDM0038',
#  'cmdb_ci_IDM0145',
#  'cmdb_ci_P2176780',
#  'cmdb_ci_Computer Hardware',
#  'cmdb_ci_IFM1093',
#  'cmdb_ci_IFM1142',
#  'cmdb_ci_iza0400',
#  'cmdb_ci_BISPRIBTPRD01',
#  'cmdb_ci_Sharepoint EU PROD',
#  'cmdb_ci_besbcn03fwd00',
#  'cmdb_ci_Enterprise Business Applications',
#  'cmdb_ci_iea0740',
#  'cmdb_ci_DBP - SAP IMPULS PROD',
#  'cmdb_ci_bitmil02fwd00',
#  'cmdb_ci_baucab00fwd00',
#  'cmdb_ci_dords-146sw-es01.bombardier',
#  'cmdb_ci_PULSE PROD',
#  'cmdb_ci_a011550p007',
#  'cmdb_ci_A015638P200',
#  'cmdb_ci_IFA0380',
#  'cmdb_ci_P2115788',
#  'cmdb_ci_Maximo BT AMER PROD',
#  'cmdb_ci_IFM1232',
#  'cmdb_ci_ATLEMP0002',
#  'cmdb_ci_Auto Magic Number - Pittsburgh',
#  'cmdb_ci_IFM0842',
#  'cmdb_ci_Metaphase PROD',
#  'cmdb_ci_bbrsao01swc00',
#  'cmdb_ci_A011262Q020',
#  'cmdb_ci_BBTAPTDUD1',
#  'cmdb_ci_buahrk00swc00',
#  'cmdb_ci_iaa0531',
#  'cmdb_ci_iea0630',
#  'cmdb_ci_BINBDQ04WAP00',
#  'cmdb_ci_idf0002',
#  'cmdb_ci_iea0300',
#  'cmdb_ci_IDA1040',
#  'cmdb_ci_IFM0922',
#  'cmdb_ci_iha0012',
#  'cmdb_ci_a011500p001',
#  'cmdb_ci_iea3000',
#  'cmdb_ci_ifm0003',
#  'cmdb_ci_TORB01-LC05-ES01.bombardier',
#  'cmdb_ci_IDA0880',
#  'cmdb_ci_saa3000',
#  'cmdb_ci_BBTSRVCES002',
#  'cmdb_ci_A010014Q003',
#  'cmdb_ci_IFM0863',
#  'cmdb_ci_Printing and Fax Services',
#  'cmdb_ci_IFM0423',
#  'cmdb_ci_mtlbdirect10',
#  'cmdb_ci_iea0590',
#  'cmdb_ci_A004456P002',
#  'cmdb_ci_a010357p021',
#  'cmdb_ci_iea1170',
#  'cmdb_ci_EDIMS PROD',
#  'cmdb_ci_IFM1362',
#  'cmdb_ci_iaa0861',
#  'cmdb_ci_IFA0006',
#  'cmdb_ci_iea1030',
#  'cmdb_ci_MTLWACON001',
#  'cmdb_ci_dorca-023-dr03.bombardier',
#  'cmdb_ci_BTIS1000011207',
#  'cmdb_ci_Citrix Catia Farm for External Partners',
#  'cmdb_ci_IFA0354',
#  'cmdb_ci_a011430D037',
#  'cmdb_ci_Enterprise Business Application Offerings',
#  'cmdb_ci_iza0402',
#  'cmdb_ci_a011430p001',
#  'cmdb_ci_Dimensions PROD',
#  'cmdb_ci_IFA0090',
#  'cmdb_ci_Printer Zebra 105',
#  'cmdb_ci_BomThun11C',
#  'cmdb_ci_IFA0458',
#  'cmdb_ci_IHA0003',
#  'cmdb_ci_IFA0328',
#  'cmdb_ci_IFM1203',
#  'cmdb_ci_a010357p019',
#  'cmdb_ci_binsavswa24',
#  'cmdb_ci_baumbh00fwd00',
#  'cmdb_ci_Rational_JAZZ_PROD',
#  'cmdb_ci_iaa1171',
#  'cmdb_ci_IFM0583',
#  'cmdb_ci_AMERAS0006',
#  'cmdb_ci_IFM0622',
#  'cmdb_ci_BBTSTSMAN001',
#  'cmdb_ci_IFM0553',
#  'cmdb_ci_bdedus00otp01',
#  'cmdb_ci_a011182p201',
#  'cmdb_ci_iaa1071',
#  'cmdb_ci_Amerls2006',
#  'cmdb_ci_bmxcsg00swa36',
#  'cmdb_ci_IFA0307',
#  'cmdb_ci_Others',
#  'cmdb_ci_P2175853',
#  'cmdb_ci_A010626Q104',
#  'cmdb_ci_SAP Impuls -HR PROD',
#  'cmdb_ci_SAP DWA Authorization',
#  'cmdb_ci_BBTSVCRSERTCMS',
#  'cmdb_ci_IFA0306',
#  'cmdb_ci_IFA0324',
#  'cmdb_ci_IFA0340',
#  'cmdb_ci_IDM0058',
#  'cmdb_ci_iea0810',
#  'cmdb_ci_Riverbed Steelhead 5050 Series',
#  'cmdb_ci_besbcn01swa00',
#  'cmdb_ci_BTIS1000096545',
#  'cmdb_ci_BAUWFD00SWC00',
#  'cmdb_ci_FTP Queries',
#  'cmdb_ci_BCAKIN00WAP01',
#  'cmdb_ci_A036475P002',
#  'cmdb_ci_A011316P200',
#  'cmdb_ci_sappbw',
#  'cmdb_ci_a036475p014',
#  'cmdb_ci_A004456P001',
#  'cmdb_ci_BT02SSPL06',
#  'cmdb_ci_BBTSVLBPT002',
#  'cmdb_ci_IDM0130',
#  'cmdb_ci_BBTRTRVE11.bt.bombardier.net',
#  'cmdb_ci_IDA0014',
#  'cmdb_ci_Pulse Secure SSL VPN & Radius - BA',
#  'cmdb_ci_ACCELION     Appliance                            ',
#  'cmdb_ci_ATLEPS1005',
#  'cmdb_ci_IFA0326',
#  'cmdb_ci_A013102P000',
#  'cmdb_ci_BTIS1000011427',
#  'cmdb_ci_BBTRTRST81.bt.bombardier.net',
#  'cmdb_ci_bfrcln00swc00',
#  'cmdb_ci_iza0630',
#  'cmdb_ci_P2142342',
#  'cmdb_ci_0003901948AP6034',
#  'cmdb_ci_IDA0890',
#  'cmdb_ci_P2145521',
#  'cmdb_ci_ndedus00tac01',
#  'cmdb_ci_iaa1231',
#  'cmdb_ci_conels2002',
#  'cmdb_ci_sba0001a',
#  'cmdb_ci_binbdq03swa01',
#  'cmdb_ci_iza0592',
#  'cmdb_ci_P2114565',
#  'cmdb_ci_a011440p101',
#  'cmdb_ci_AMERPS1002',
#  'cmdb_ci_apacls2008',
#  'cmdb_ci_Accellion',
#  'cmdb_ci_BTIS1000038760',
#  'cmdb_ci_baubne00flr00',
#  'cmdb_ci_iea0280',
#  'cmdb_ci_BINVA1SWA05',
#  'cmdb_ci_IFM0702',
#  'cmdb_ci_BINBOM01FWD00',
#  'cmdb_ci_iza0530',
#  'cmdb_ci_A010014D001',
#  'cmdb_ci_ica0315',
#  'cmdb_ci_ida1300',
#  'cmdb_ci_iea1380',
#  'cmdb_ci_BEGCAI00FWD01',
#  'cmdb_ci_Navigator IETP (v2.3)',
#  'cmdb_ci_SAP PP PROD',
#  'cmdb_ci_BTIS1000068074',
#  'cmdb_ci_A004456P000',
#  'cmdb_ci_IFA0327',
#  'cmdb_ci_iha0007',
#  'cmdb_ci_BBTSWHMAT06.bt.bombardier.net',
#  'cmdb_ci_BBTRTRAT12',
#  'cmdb_ci_BTIS1000011976',
#  'cmdb_ci_IGA0000',
#  'cmdb_ci_Rational_DOORS_PROD',
#  'cmdb_ci_IFA0305',
#  'cmdb_ci_bmxcsg00swa38',
#  'cmdb_ci_IFA0472',
#  'cmdb_ci_ifm0208',
#  'cmdb_ci_A00036097P000',
#  'cmdb_ci_AMERPS1006',
#  'cmdb_ci_IFM0240',
#  'cmdb_ci_IDA0720',
#  'cmdb_ci_A010890D000',
#  'cmdb_ci_bbtwapmat02',
#  'cmdb_ci_BINBDQ03WAP001',
#  'cmdb_ci_iaa0631',
#  'cmdb_ci_IFM0493',
#  'cmdb_ci_IDA0450',
#  'cmdb_ci_IFM0613',
#  'cmdb_ci_A011484P005',
#  'cmdb_ci_MTLWISPL001',
#  'cmdb_ci_A036475P010',
#  'cmdb_ci_a010357p050',
#  'cmdb_ci_bauarg00fwd00',
#  'cmdb_ci_A011484P007',
#  'cmdb_ci_iCare/Default@mtlwdsql609',
#  'cmdb_ci_torb09-la35-es01.bombardier',
#  'cmdb_ci_ifm0259',
#  'cmdb_ci_A011312P000',
#  'cmdb_ci_APACFS0003',
#  'cmdb_ci_A015668Q001',
#  'cmdb_ci_ICA0004',
#  'cmdb_ci_BTIS1000002856',
#  'cmdb_ci_bdegdl00fwd00',
#  'cmdb_ci_IFA0433',
#  'cmdb_ci_ifm0106',
#  'cmdb_ci_dorbc-cfas-es01.bombardier',
#  'cmdb_ci_P1204467',
#  'cmdb_ci_a011430p005',
#  'cmdb_ci_COMMIT Prod',
#  'cmdb_ci_IFM1012',
#  'cmdb_ci_a011384p300',
#  'cmdb_ci_BBTSVHBPT002',
#  'cmdb_ci_BBTAPTVLI11.bt.bombardier.net',
#  'cmdb_ci_a015512p304',
#  'cmdb_ci_Salesforce Finance (Costa Rica Service Center)',
#  'cmdb_ci_iza0600',
#  'cmdb_ci_AMERAS0055',
#  'cmdb_ci_bcavan03fwd00',
#  'cmdb_ci_ibm3000',
#  'cmdb_ci_SAP eWM PROD',
#  'cmdb_ci_iaa1011',
#  'cmdb_ci_Lotus Notes',
#  'cmdb_ci_AMERMP0003',
#  'cmdb_ci_ServiceNow Instance - PROD',
#  'cmdb_ci_iaa0271',
#  'cmdb_ci_A011213P300',
#  'cmdb_ci_iea1180',
#  'cmdb_ci_EPIC PROD',
#  'cmdb_ci_HLMCCM01',
#  'cmdb_ci_a015512p102',
#  'cmdb_ci_besbcn02swc00',
#  'cmdb_ci_IFM0632',
#  'cmdb_ci_ICA0049',
#  'cmdb_ci_iaa0006',
#  'cmdb_ci_IJA0000',
#  'cmdb_ci_ICA3010',
#  'cmdb_ci_Bdehnf00wap83',
#  'cmdb_ci_Team Center',
#  'cmdb_ci_bmxcsg00swa39',
#  'cmdb_ci_a010357p313',
#  'cmdb_ci_iea1230',
#  'cmdb_ci_CONEMP0008',
#  'cmdb_ci_iaa0261',
#  'cmdb_ci_A036097P301',
#  'cmdb_ci_IFM0482',
#  'cmdb_ci_AOG Database',
#  'cmdb_ci_bbtantlap754',
#  'cmdb_ci_IFA0417',
#  'cmdb_ci_P2138686',
#  'cmdb_ci_iea0470',
#  'cmdb_ci_IFA0349',
#  'cmdb_ci_BATVIE00FLR00',
#  'cmdb_ci_Adobe Acrobat Professional',
#  'cmdb_ci_IFA0445',
#  'cmdb_ci_IFM0677',
#  'cmdb_ci_BTIS1000068259',
#  'cmdb_ci_a015262p000',
#  'cmdb_ci_bitvrn00wap00',
#  'cmdb_ci_sam0001',
#  'cmdb_ci_Bomfact_PROD',
#  'cmdb_ci_beshms00swc00',
#  'cmdb_ci_iaa0200',
#  'cmdb_ci_IDA0830',
#  'cmdb_ci_DELMIA-BA Mexico',
#  'cmdb_ci_BBTSRVBAU11',
#  'cmdb_ci_IDM0081',
#  'cmdb_ci_iha0013',
#  'cmdb_ci_IFM1152',
#  'cmdb_ci_bitmil02swc00',
#  'cmdb_ci_C0PMTL01',
#  'cmdb_ci_BBTRTRAT41.bt.bombardier.net',
#  'cmdb_ci_IDA0260',
#  'cmdb_ci_AMERPS1001',
#  'cmdb_ci_STORHL04',
#  'cmdb_ci_BESALC00FWD00',
#  'cmdb_ci_BTIS1000012235',
#  'cmdb_ci_Maximo for Aviation PROD',
#  'cmdb_ci_a010635p101',
#  'cmdb_ci_IFA0316',
#  'cmdb_ci_ifm0218',
#  'cmdb_ci_IFM1062',
#  'cmdb_ci_dords-vss-dr01.bombardier',
#  'cmdb_ci_A015474P001',
#  'cmdb_ci_BBTSWHBRV01.bt.bombardier.net',
#  'cmdb_ci_BBTSRVSDC415',
#  'cmdb_ci_IFM1052',
#  'cmdb_ci_IFM1043',
#  'cmdb_ci_BBTSRVSDC208',
#  'cmdb_ci_CONEPS1006',
#  'cmdb_ci_P2122586',
#  'cmdb_ci_IFM0679',
#  'cmdb_ci_IFM0401',
#  'cmdb_ci_IFA0440',
#  'cmdb_ci_IFM0503',
#  'cmdb_ci_MBOM',
#  'cmdb_ci_P2151120',
#  'cmdb_ci_P2102002',
#  'cmdb_ci_A015374P001',
#  'cmdb_ci_a010803p500',
#  'cmdb_ci_BBTRTRBAR1.bt.bombardier.net',
#  'cmdb_ci_MTLSVRW050',
#  'cmdb_ci_BZAPLZ00FWD00',
#  'cmdb_ci_Service Now',
#  'cmdb_ci_Mackie Move',
#  'cmdb_ci_ifm0286',
#  'cmdb_ci_BINSAVSWA17',
#  'cmdb_ci_a010357p018',
#  'cmdb_ci_BINICD01SWA00',
#  'cmdb_ci_iaa1311',
#  'cmdb_ci_a010357p008',
#  'cmdb_ci_IFM0742',
#  'cmdb_ci_iea1280',
#  'cmdb_ci_IFM0441',
#  'cmdb_ci_bbtswhmuv1.bt.bombardier.net',
#  'cmdb_ci_ICA0113',
#  'cmdb_ci_IFM0234',
#  'cmdb_ci_busunc01fwd00',
#  'cmdb_ci_NDEBRP00DM00',
#  'cmdb_ci_A011262Q004',
#  'cmdb_ci_BAU32S00FWD00',
#  'cmdb_ci_Pulse Secure SSL VPN & Radius - BT',
#  'cmdb_ci_IDA1050',
#  'cmdb_ci_a011550p006',
#  'cmdb_ci_binbom02swc00',
#  'cmdb_ci_IFM1182',
#  'cmdb_ci_CONEMP0004',
#  'cmdb_ci_ifm0033',
#  'cmdb_ci_P2118099',
#  'cmdb_ci_a011500p002',
#  'cmdb_ci_A010600P015',
#  'cmdb_ci_A011432T001',
#  'cmdb_ci_CHIWPRINT001',
#  'cmdb_ci_iza0540',
#  'cmdb_ci_CESWAP16',
#  'cmdb_ci_iga0083',
#  'cmdb_ci_bfrcre00fwd00',
#  'cmdb_ci_ida0200',
#  'cmdb_ci_IFM0158',
#  'cmdb_ci_idg0003',
#  'cmdb_ci_iea0820',
#  'cmdb_ci_iea0004',
#  'cmdb_ci_ifa0055',
#  'cmdb_ci_SAPPR201',
#  'cmdb_ci_AMERPS1012',
#  'cmdb_ci_P2182414',
#  'cmdb_ci_BCAMTR05WAP00',
#  'cmdb_ci_Print and Fax Offerings',
#  'cmdb_ci_ITIM (Identity Management) - application',
#  'cmdb_ci_IFA0436',
#  'cmdb_ci_BESBCN01WAP00',
#  'cmdb_ci_IDA1150',
#  'cmdb_ci_BBTSWHWA303.bt.bombardier.net',
#  'cmdb_ci_BINGGN00FWD00',
#  'cmdb_ci_SIMS',
#  'cmdb_ci_IFA0444',
#  'cmdb_ci_iea0920',
#  'cmdb_ci_IFM0932',
#  'cmdb_ci_BTIS1000004521',
#  'cmdb_ci_BBTSWHTO7200.bt.bombardier.net',
#  'cmdb_ci_IFA0104',
#  'cmdb_ci_bbtswhmuv2.bt.bombardier.net',
#  'cmdb_ci_ICA0061',
#  'cmdb_ci_IFM0443',
#  'cmdb_ci_BDEBAU00WAP167',
#  'cmdb_ci_busxhe00fwd00',
#  'cmdb_ci_MTLWZJMP001',
#  'cmdb_ci_iaa0831',
#  'cmdb_ci_Access System 2000 DLS2100',
#  'cmdb_ci_ifm0032',
#  'cmdb_ci_iea0044',
#  'cmdb_ci_MTLWILIC002',
#  'cmdb_ci_Viadat Goerlitz PROD',
#  'cmdb_ci_iea1370',
#  'cmdb_ci_BTIS1000008836',
#  'cmdb_ci_IFA0294',
#  'cmdb_ci_ICA3013',
#  'cmdb_ci_CONEPS1015',
#  'cmdb_ci_IBMPLMPI2461',
#  'cmdb_ci_P2100118',
#  'cmdb_ci_IFM0833',
#  'cmdb_ci_Aircraft Configuration Management Database PROD',
#  'cmdb_ci_IFA0466',
#  'cmdb_ci_APACPS1020',
#  'cmdb_ci_BBTSRVBPT016',
#  'cmdb_ci_Alstom-APP IAM New Passport',
#  'cmdb_ci_BBTFLRMIL01',
#  'cmdb_ci_iha0017',
#  'cmdb_ci_MTLWAJTCM004',
#  'cmdb_ci_bdedus00scs00',
#  'cmdb_ci_iea0005',
#  'cmdb_ci_iaa0001',
#  'cmdb_ci_IFA0353',
#  'cmdb_ci_SharePoint_AdminContent_04027d73-8dd1-43a9-a318-cf567184e7fd/Default@WICWDSPS313',
#  'cmdb_ci_ifm0153',
#  'cmdb_ci_bdedus00flr00',
#  'cmdb_ci_A010626S002',
#  'cmdb_ci_A10357S000',
#  'cmdb_ci_bbrsao01fwd00',
#  'cmdb_ci_BDEORA00FWD00 ',
#  'cmdb_ci_A004456P008',
#  'cmdb_ci_IDM0133',
#  'cmdb_ci_a011179p202',
#  'cmdb_ci_IFM0543',
#  'cmdb_ci_a011179p300',
#  'cmdb_ci_iza1070',
#  'cmdb_ci_OPEN PDM_PROD',
#  'cmdb_ci_A011262P023',
#  'cmdb_ci_C0FMTL50',
#  'cmdb_ci_IFM0743',
#  'cmdb_ci_bdedui00fwd00',
#  'cmdb_ci_IFA3001',
#  'cmdb_ci_IFA0331',
#  'cmdb_ci_IFM0623',
#  'cmdb_ci_iza0980',
#  'cmdb_ci_iha0006',
#  'cmdb_ci_BT02SSSG01NEW',
#  'cmdb_ci_IFM0762',
#  'cmdb_ci_IFA0334',
#  'cmdb_ci_OPO CSR for BCA',
#  'cmdb_ci_ICA0076',
#  'cmdb_ci_Baan Portugal',
#  'cmdb_ci_IFM0483',
#  'cmdb_ci_a011430q002',
#  'cmdb_ci_BBTSRVVIE4',
#  'cmdb_ci_AMERPS1018',
#  'cmdb_ci_A004456D001',
#  'cmdb_ci_iab3001',
#  'cmdb_ci_A011442P001',
#  'cmdb_ci_BBTFLRST101',
#  'cmdb_ci_ida3002',
#  'cmdb_ci_iza0260',
#  'cmdb_ci_BBTSRVVA379',
#  'cmdb_ci_iea1110',
#  'cmdb_ci_Email Offerings',
#  'cmdb_ci_IFA0371',
#  'cmdb_ci_MCCFWD001',
#  'cmdb_ci_IFM0843',
#  'cmdb_ci_IFM0722',
#  'cmdb_ci_sappon01',
#  'cmdb_ci_IDM0120',
#  'cmdb_ci_FXTORPRD@mtlora2clu402',
#  'cmdb_ci_ATLEPS1029',
#  'cmdb_ci_CONEPS1005',
#  'cmdb_ci_a00011811p000',
#  'cmdb_ci_BTIS1000085801',
#  'cmdb_ci_iaa0741',
#  'cmdb_ci_iaa0851',
#  'cmdb_ci_DVX - SAP VCM Global - Template DEV',
#  'cmdb_ci_IFM1072',
#  'cmdb_ci_P2117147',
#  'cmdb_ci_iaa0521',
#  'cmdb_ci_BAUWMU01SWA00',
#  'cmdb_ci_AMERFS0040',
#  'cmdb_ci_A015228P300',
#  'cmdb_ci_DataLink Global PROD',
#  'cmdb_ci_nem0005',
#  'cmdb_ci_ERA SQL',
#  'cmdb_ci_iza0830',
#  'cmdb_ci_a015512p303',
#  'cmdb_ci_ICA0119',
#  'cmdb_ci_bauept01fwd00',
#  'cmdb_ci_IGM0011',
#  'cmdb_ci_bdehnf00fwd00-0',
#  'cmdb_ci_bmypja00fwd00',
#  'cmdb_ci_BINHYD01SWS00-0',
#  'cmdb_ci_busral00swc00',
#  'cmdb_ci_iza0552',
#  'cmdb_ci_iea0770',
#  'cmdb_ci_bgbsyn00fwd00',
#  'cmdb_ci_P2142345',
#  'cmdb_ci_apacls2006',
#  'cmdb_ci_iaa0441',
#  'cmdb_ci_Bdehnf00wap21',
#  'cmdb_ci_AMERAS0014',
#  'cmdb_ci_iea0420',
#  'cmdb_ci_ifm0716',
#  'cmdb_ci_bplwro00wap22',
#  'cmdb_ci_CESWAP70',
#  'cmdb_ci_IFA0352',
#  'cmdb_ci_ifa0361',
#  'cmdb_ci_bt.bombardier.net',
#  'cmdb_ci_A016188D000',
#  'cmdb_ci_IHA0002',
#  'cmdb_ci_ATLELS1005',
#  'cmdb_ci_IFA0412',
#  'cmdb_ci_BBTSRVVA378',
#  'cmdb_ci_A011439P000',
#  'cmdb_ci_iea0930',
#  'cmdb_ci_iea0029',
#  'cmdb_ci_iza1360',
#  'cmdb_ci_iha0024',
#  'cmdb_ci_iea0850',
#  'cmdb_ci_iaa0401',
#  'cmdb_ci_IFM0421',
#  'cmdb_ci_IDS0530',
#  'cmdb_ci_P2174981',
#  'cmdb_ci_OPO for BBA',
#  'cmdb_ci_IDM0036',
#  'cmdb_ci_P2085830',
#  'cmdb_ci_P2200394',
#  'cmdb_ci_BTIS1000004308',
#  'cmdb_ci_IFM0693',
#  'cmdb_ci_IFA0341',
#  'cmdb_ci_SAP VCM Authorization',
#  'cmdb_ci_iaa1051',
#  'cmdb_ci_IDA1010',
#  'cmdb_ci_AMERPS1008',
#  'cmdb_ci_nem0200',
#  'cmdb_ci_ICA0281',
#  'cmdb_ci_BBTSWHCR1168.bt.bombardier.net',
#  'cmdb_ci_ifm0203',
#  'cmdb_ci_a011430q046',
#  'cmdb_ci_Rational_DOORS_QA',
#  'cmdb_ci_ATLEPS1007',
#  'cmdb_ci_Backup',
#  'cmdb_ci_P2174152',
#  'cmdb_ci_10.68.4.20',
#  'cmdb_ci_SAP SNC PROD',
#  'cmdb_ci_A011328P000',
#  'cmdb_ci_a010357p323',
#  'cmdb_ci_BINHYD01SWA06-0',
#  'cmdb_ci_IDA1170',
#  'cmdb_ci_BBTWAPGLZ001',
#  'cmdb_ci_McAfee',
#  'cmdb_ci_A011335P001',
#  'cmdb_ci_IFA0462',
#  'cmdb_ci_CONEMP0002',
#  ...]

# %%
X_test_2_new = X_test_2_new.fillna(X_test_2_new.mean())

# %% [markdown]
# ## Standardization ##

# %%
X_train_2_new_scaled = scaler.fit_transform(X_train_2_new)
X_test_2_new_scaled = scaler.transform(X_test_2_new)

# %% [markdown]
# ## Random Forest ##

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_train_2_new_scaled,y_train_2)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
y_pred = rf.predict(X_test_2_new_scaled)

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test_2,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test_2,y_pred)))
# Out:
# MSE 28206.296958574625
# RMSE 167.94730411225606

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test_2,y_pred))
# Out:
# MAE 9.134395433964785

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test_2,y_pred)
print(r2)
# Out:
# 0.8552984292681609

# %%
Adj_r2 = 1 - (1-r2_score(y_test_2, y_pred)) * (len(y2)-1)/(len(y2)-X2.shape[1]-1)
print(Adj_r2)
# Out:
# 0.8510197417410162

# %%
# Calculate the absolute errors
errors = abs(y_pred - y_test_2)

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test_2)

# %%
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 77.02 %.
